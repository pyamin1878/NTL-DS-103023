# %% [markdown]
# ![more_data](data:image/png;base64,...)

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# - Load and explore a .json file in Python
# - Create a clean data structure from a .json file
# - Conduct descriptive analysis
# - Visualize the results

# %% [markdown]
# Part of being a good data scientist is having the capacity to work with data in many different forms. Much data online is stored in JSON format. So let's see if we can conduct a descriptive analysis of data when it's given to us in that form!

# %% [markdown]
# ## What is JSON?
#
# JSON stands for Java Script Object Notation.
#
# JSON objects are one common way that data is transmitted over the web.  It is notable for being lightweight, which makes it [preferred](https://stackoverflow.com/questions/383692/what-is-json-and-why-would-i-use-it), generally, over XML.

# %% [markdown]
# ```json
# {"menu": {
#   "id": 12412,
#   "istest": true,
#   "value": "File",
#   "popup": {
#     "menuitem": [
#       {"value": "New", "onclick": "CreateNewDoc()"},
#       {"value": "Open", "onclick": "OpenDoc()"},
#       {"value": "Close", "onclick": "CloseDoc()"}
#     ]
#   }
# }}
# ```

# %% [markdown]
# ## JSON Format

# %% [markdown]
# JSON objects store data in a format similar to a nested Python dictionary. The JSON format makes it easy to store as a file, transfer between users, and use in other languages.
#
# For more information about the syntax of JSON files, check out this [link](https://www.json.org/json-en.html) to the JSON website.

# %% [markdown]
# Can have these types in it (all relatable to Python types):
#
# |JavaScript|JS Example               |Python Equivalent|Python Example           |
# |----------|-------------------------|-----------------|-------------------------|
# |Objects   |`{'key0':'v12','v':1}`   |Dictionaries     |`{'key0':'v12','v':1}`   |
# |Arrays    |`[1, 'one', 'two', 3, 5]`|Lists            |`[1, 'one', 'two', 3, 5]`|
# |Strings   |`'One'` or `"Two"`       |Strings          |`'One'` or `"Two"`       |
# |Numbers   |`1234.5` or `8675309`    |Numbers          |`1234.5` or `8675309`    |
# |Boolean   |`true` or `false`        |Boolean          |`True` or `False`        |
# |Null Value|`null`                   |None Value       |`None`                   |

# %% [markdown]
# # Loading a JSON File

# %% [markdown]
# For this example, we've created a `new_releases.json` file containing data on 20 newly released music albums. We got this from the Spotify API - we'll explain what this means later.
#
# Let's begin by importing the `json` package, opening a file with python's `open()` function, and then loading that data from the JSON file into a new `data` object.

# %%
# We'll need to import the json package first
import json

# %%
# Now use with open to load the file
with open('data/new_releases.json') as file:
    data = json.load(file)

# %%
open_file = open('data/new_releases.json')
data = json.load(open_file)
open_file.close()

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#     'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#     'id': '4bNPOFOzxGhF5jhfIK6lit',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#       'width': 64}],
#     'name': 'High Off Life',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#       'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#       'id': '23fqKkggKUBHNkbKtXEls4',
#       'name': 'Kygo',
#       'type': 'artist',
#       'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#     'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#     'id': '3LhriqAiHJYw7rxvtlkvQc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#       'width': 64}],
#     'name': 'Lose Somebody',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#     'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#     'id': '2Zg5xZo3WwIoAZys8OcUpG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#       'width': 64}],
#     'name': 'SCOOB! The Album',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#     'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#     'id': '2m5J1DUH7hJpPSOromIqpN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#       'width': 64}],
#     'name': 'Daisies',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#       'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#       'id': '6AgTAQt8XS6jRWi4sX7w49',
#       'name': 'Polo G',
#       'type': 'artist',
#       'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#     'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#     'id': '39xhYyNNDatQtgKw2KdXMz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#       'width': 64}],
#     'name': 'THE GOAT',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#     'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#     'id': '0i96PtPJV65ddxsfMfo45F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#       'width': 64}],
#     'name': 'XV',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#       'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#       'id': '25uiPmTg16RbhZWAqwLBy5',
#       'name': 'Charli XCX',
#       'type': 'artist',
#       'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#     'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#     'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#       'width': 64}],
#     'name': "how i'm feeling now",
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#       'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#       'id': '2jku7tDXc6XoB6MO2hFuqg',
#       'name': 'Tory Lanez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#     'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#     'id': '3lalGt6k7JM3tIji1Xbgmk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#       'width': 64}],
#     'name': 'Temperature Rising',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#       'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#       'id': '2ueoLVCXQ948OfhVvAy3Nn',
#       'name': 'Perfume Genius',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#     'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#     'id': '6daEdTBi1hyFQgmsnR7oRr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#       'width': 64}],
#     'name': 'Set My Heart On Fire Immediately',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#       'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#       'id': '7rkW85dBwwrJtlHRDkJDAC',
#       'name': 'NAV',
#       'type': 'artist',
#       'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#     'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#     'id': '2kx4l1OQNT2JXLld9HJDIh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#       'width': 64}],
#     'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#     'release_date': '2020-05-11',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#       'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#       'id': '6oMuImdp5ZcFhWP0ESe6mG',
#       'name': 'Migos',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#     'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#     'id': '3PASWLvNfvfMF68dDznEgK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#       'width': 64}],
#     'name': 'Racks 2 Skinny',
#     'release_date': '2020-05-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#       'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#       'id': '5Zq7R5qmi58ByYyBQTlNuk',
#       'name': 'Lee Brice',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#     'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#     'id': '5LK5cCx0XdniivfZ91vOSv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#       'width': 64}],
#     'name': 'One Of Them Girls',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#     'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#     'id': '6CIslPQSknp875cigkhKJC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#       'width': 64}],
#     'name': 'The London Sessions',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#       'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#       'id': '6pBNfggcZZDCmb0p92OnGn',
#       'name': 'Chase Rice',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#     'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#     'id': '5XvXf3mdhShyLZhoJYR74q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#       'width': 64}],
#     'name': 'The Album, Pt. II',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#       'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#       'id': '1caBfBEapzw8z2Qz9q0OaQ',
#       'name': 'Asking Alexandria',
#       'type': 'artist',
#       'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#     'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#     'id': '5VKKXDvYuJmRc2UQHCwNQK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#       'width': 64}],
#     'name': 'Like A House On Fire',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#       'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#       'id': '7d3WFRME3vBY2cgoP38RDo',
#       'name': 'Lil Skies',
#       'type': 'artist',
#       'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#     'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#     'id': '3cVy1WTjSAVpzUc7MVCTLu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#       'width': 64}],
#     'name': 'Riot',
#     'release_date': '2020-05-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#       'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#       'id': '55fhWPvDiMpLnE4ZzNXZyW',
#       'name': 'Noah Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#     'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#     'id': '5Gn3fFzlWL89j0hGumtXb5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#       'width': 64}],
#     'name': 'THE END OF EVERYTHING',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#       'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#       'id': '6C1ohJrd5VydigQtaGy5Wa',
#       'name': 'Joyner Lucas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#       'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#       'id': '41qil2VaGbD194gaEcmmyx',
#       'name': 'Will Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#     'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#     'id': '3tOe6XM8LmRA5vDAaMqp8e',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#       'width': 64}],
#     'name': 'Will (Remix)',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#       'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#       'id': '6Xgp2XMz1fhVYe7i6yNAax',
#       'name': 'Trippie Redd',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#       'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#       'id': '2HPaUgqeutzr3jx5a9WyDV',
#       'name': 'PARTYNEXTDOOR',
#       'type': 'artist',
#       'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#     'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#     'id': '7rcMHNqNbQxF5TaPMHFoKu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#       'width': 64}],
#     'name': 'Excitement',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#       'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#       'id': '3NPpFNZtSTHheNBaWC82rB',
#       'name': 'X Ambassadors',
#       'type': 'artist',
#       'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#       'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#       'id': '0pCNk4D3E2xtszsm6hMsWr',
#       'name': 'K.Flay',
#       'type': 'artist',
#       'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#       'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#       'id': '4ZgQDCtRqZlhLswVS6MHN4',
#       'name': 'grandson',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#     'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#     'id': '2JQbWWpYG6kKppiD6z2FwL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#       'width': 64}],
#     'name': 'Zen (with K.Flay & grandson)',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %% [markdown]
# The Spotify API returned the data in the form of JSON object, which the `json` module transforms into a Python object.

# %% [markdown]
# ## Exploring JSON Schemas

# %% [markdown]
# Recall that JSON files have a nested structure. The deepest levels of our object will contain individual values: numbers, booleans or strings. These in turn will be stored in the equivalents of Python lists and dictionaries, usually with many levels of nesting.
#
# If you try to look at a raw JSON file, you will likely have a hard time understanding the structure. To more easily make sense of it, we will proceed through each level methodically.

# %%
# This will look messy
print(data)
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20', 'items': [{'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'}, 'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i', 'id': '1RyvyyTE3xzB2ZywiAwp0i', 'name': 'Future', 'type': 'artist', 'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'}, 'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit', 'id': '4bNPOFOzxGhF5jhfIK6lit', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e', 'width': 64}], 'name': 'High Off Life', 'release_date': '2020-05-15', 'release_date_precision': 'day', 'total_tracks': 21, 'type': 'album', 'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'}, {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'}, 'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4', 'id': '23fqKkggKUBHNkbKtXEls4', 'name': 'Kygo', 'type': 'artist', 'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'}, 'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ', 'id': '5Pwc4xIPtQLFEnJriah9YJ', 'name': 'OneRepublic', 'type': 'artist', 'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'}, 'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc', 'id': '3LhriqAiHJYw7rxvtlkvQc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704', 'width': 64}], 'name': 'Lose Somebody', 'release_date': '2020-05-15', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'}, {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', ...

# %%
# One way to make it easier to read
print(json.dumps(data, indent=2))
# Out:
# {
#   "albums": {
#     "href": "https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20",
#     "items": [
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i"
#             },
#             "href": "https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i",
#             "id": "1RyvyyTE3xzB2ZywiAwp0i",
#             "name": "Future",
#             "type": "artist",
#             "uri": "spotify:artist:1RyvyyTE3xzB2ZywiAwp0i"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit"
#         },
#         "href": "https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit",
#         "id": "4bNPOFOzxGhF5jhfIK6lit",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e",
#             "width": 64
#           }
#         ],
#         "name": "High Off Life",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 21,
#         "type": "album",
#         "uri": "spotify:album:4bNPOFOzxGhF5jhfIK6lit"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4"
#             },
#             "href": "https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4",
#             "id": "23fqKkggKUBHNkbKtXEls4",
#             "name": "Kygo",
#             "type": "artist",
#             "uri": "spotify:artist:23fqKkggKUBHNkbKtXEls4"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ"
#             },
#             "href": "https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ",
#             "id": "5Pwc4xIPtQLFEnJriah9YJ",
#             "name": "OneRepublic",
#             "type": "artist",
#             "uri": "spotify:artist:5Pwc4xIPtQLFEnJriah9YJ"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc"
#         },
#         "href": "https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc",
#         "id": "3LhriqAiHJYw7rxvtlkvQc",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704",
#             "width": 64
#           }
#         ],
#         "name": "Lose Somebody",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:3LhriqAiHJYw7rxvtlkvQc"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#             },
#             "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#             "id": "0LyfQWJT6nXafLPZqxe9Of",
#             "name": "Various Artists",
#             "type": "artist",
#             "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG"
#         },
#         "href": "https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG",
#         "id": "2Zg5xZo3WwIoAZys8OcUpG",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35",
#             "width": 64
#           }
#         ],
#         "name": "SCOOB! The Album",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 12,
#         "type": "album",
#         "uri": "spotify:album:2Zg5xZo3WwIoAZys8OcUpG"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X"
#             },
#             "href": "https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X",
#             "id": "6jJ0s89eD6GaHleKKya26X",
#             "name": "Katy Perry",
#             "type": "artist",
#             "uri": "spotify:artist:6jJ0s89eD6GaHleKKya26X"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN"
#         },
#         "href": "https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN",
#         "id": "2m5J1DUH7hJpPSOromIqpN",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3",
#             "width": 64
#           }
#         ],
#         "name": "Daisies",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:2m5J1DUH7hJpPSOromIqpN"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49"
#             },
#             "href": "https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49",
#             "id": "6AgTAQt8XS6jRWi4sX7w49",
#             "name": "Polo G",
#             "type": "artist",
#             "uri": "spotify:artist:6AgTAQt8XS6jRWi4sX7w49"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz"
#         },
#         "href": "https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz",
#         "id": "39xhYyNNDatQtgKw2KdXMz",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d",
#             "width": 64
#           }
#         ],
#         "name": "THE GOAT",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 16,
#         "type": "album",
#         "uri": "spotify:album:39xhYyNNDatQtgKw2KdXMz"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD"
#             },
#             "href": "https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD",
#             "id": "7gOdHgIoIKoe4i9Tta6qdD",
#             "name": "Jonas Brothers",
#             "type": "artist",
#             "uri": "spotify:artist:7gOdHgIoIKoe4i9Tta6qdD"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla"
#             },
#             "href": "https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla",
#             "id": "790FomKkXshlbRYZFtlgla",
#             "name": "KAROL G",
#             "type": "artist",
#             "uri": "spotify:artist:790FomKkXshlbRYZFtlgla"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F"
#         },
#         "href": "https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F",
#         "id": "0i96PtPJV65ddxsfMfo45F",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb",
#             "width": 64
#           }
#         ],
#         "name": "XV",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 2,
#         "type": "album",
#         "uri": "spotify:album:0i96PtPJV65ddxsfMfo45F"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5"
#             },
#             "href": "https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5",
#             "id": "25uiPmTg16RbhZWAqwLBy5",
#             "name": "Charli XCX",
#             "type": "artist",
#             "uri": "spotify:artist:25uiPmTg16RbhZWAqwLBy5"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu"
#         },
#         "href": "https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu",
#         "id": "3a9qH2VEsSiOZvMrjaS0Nu",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914",
#             "width": 64
#           }
#         ],
#         "name": "how i'm feeling now",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 11,
#         "type": "album",
#         "uri": "spotify:album:3a9qH2VEsSiOZvMrjaS0Nu"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg"
#             },
#             "href": "https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg",
#             "id": "2jku7tDXc6XoB6MO2hFuqg",
#             "name": "Tory Lanez",
#             "type": "artist",
#             "uri": "spotify:artist:2jku7tDXc6XoB6MO2hFuqg"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk"
#         },
#         "href": "https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk",
#         "id": "3lalGt6k7JM3tIji1Xbgmk",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc",
#             "width": 64
#           }
#         ],
#         "name": "Temperature Rising",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:3lalGt6k7JM3tIji1Xbgmk"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn"
#             },
#             "href": "https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn",
#             "id": "2ueoLVCXQ948OfhVvAy3Nn",
#             "name": "Perfume Genius",
#             "type": "artist",
#             "uri": "spotify:artist:2ueoLVCXQ948OfhVvAy3Nn"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr"
#         },
#         "href": "https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr",
#         "id": "6daEdTBi1hyFQgmsnR7oRr",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a",
#             "width": 64
#           }
#         ],
#         "name": "Set My Heart On Fire Immediately",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 13,
#         "type": "album",
#         "uri": "spotify:album:6daEdTBi1hyFQgmsnR7oRr"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC"
#             },
#             "href": "https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC",
#             "id": "7rkW85dBwwrJtlHRDkJDAC",
#             "name": "NAV",
#             "type": "artist",
#             "uri": "spotify:artist:7rkW85dBwwrJtlHRDkJDAC"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh"
#         },
#         "href": "https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh",
#         "id": "2kx4l1OQNT2JXLld9HJDIh",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d",
#             "width": 64
#           }
#         ],
#         "name": "Good Intentions (Brown Boy 2 Deluxe Version)",
#         "release_date": "2020-05-11",
#         "release_date_precision": "day",
#         "total_tracks": 32,
#         "type": "album",
#         "uri": "spotify:album:2kx4l1OQNT2JXLld9HJDIh"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG"
#             },
#             "href": "https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG",
#             "id": "6oMuImdp5ZcFhWP0ESe6mG",
#             "name": "Migos",
#             "type": "artist",
#             "uri": "spotify:artist:6oMuImdp5ZcFhWP0ESe6mG"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK"
#         },
#         "href": "https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK",
#         "id": "3PASWLvNfvfMF68dDznEgK",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b",
#             "width": 64
#           }
#         ],
#         "name": "Racks 2 Skinny",
#         "release_date": "2020-05-11",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:3PASWLvNfvfMF68dDznEgK"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk"
#             },
#             "href": "https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk",
#             "id": "5Zq7R5qmi58ByYyBQTlNuk",
#             "name": "Lee Brice",
#             "type": "artist",
#             "uri": "spotify:artist:5Zq7R5qmi58ByYyBQTlNuk"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv"
#         },
#         "href": "https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv",
#         "id": "5LK5cCx0XdniivfZ91vOSv",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268",
#             "width": 64
#           }
#         ],
#         "name": "One Of Them Girls",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 2,
#         "type": "album",
#         "uri": "spotify:album:5LK5cCx0XdniivfZ91vOSv"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z"
#             },
#             "href": "https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z",
#             "id": "2o5jDhtHVPhrJdv3cEQ99Z",
#             "name": "Ti\u00ebsto",
#             "type": "artist",
#             "uri": "spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/6CIslPQSknp875cigkhKJC"
#         },
#         "href": "https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC",
#         "id": "6CIslPQSknp875cigkhKJC",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3",
#             "width": 64
#           }
#         ],
#         "name": "The London Sessions",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 13,
#         "type": "album",
#         "uri": "spotify:album:6CIslPQSknp875cigkhKJC"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn"
#             },
#             "href": "https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn",
#             "id": "6pBNfggcZZDCmb0p92OnGn",
#             "name": "Chase Rice",
#             "type": "artist",
#             "uri": "spotify:artist:6pBNfggcZZDCmb0p92OnGn"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q"
#         },
#         "href": "https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q",
#         "id": "5XvXf3mdhShyLZhoJYR74q",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650",
#             "width": 64
#           }
#         ],
#         "name": "The Album, Pt. II",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 4,
#         "type": "album",
#         "uri": "spotify:album:5XvXf3mdhShyLZhoJYR74q"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ"
#             },
#             "href": "https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ",
#             "id": "1caBfBEapzw8z2Qz9q0OaQ",
#             "name": "Asking Alexandria",
#             "type": "artist",
#             "uri": "spotify:artist:1caBfBEapzw8z2Qz9q0OaQ"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK"
#         },
#         "href": "https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK",
#         "id": "5VKKXDvYuJmRc2UQHCwNQK",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d",
#             "width": 64
#           }
#         ],
#         "name": "Like A House On Fire",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 15,
#         "type": "album",
#         "uri": "spotify:album:5VKKXDvYuJmRc2UQHCwNQK"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo"
#             },
#             "href": "https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo",
#             "id": "7d3WFRME3vBY2cgoP38RDo",
#             "name": "Lil Skies",
#             "type": "artist",
#             "uri": "spotify:artist:7d3WFRME3vBY2cgoP38RDo"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu"
#         },
#         "href": "https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu",
#         "id": "3cVy1WTjSAVpzUc7MVCTLu",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818",
#             "width": 64
#           }
#         ],
#         "name": "Riot",
#         "release_date": "2020-05-13",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:3cVy1WTjSAVpzUc7MVCTLu"
#       },
#       {
#         "album_type": "album",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW"
#             },
#             "href": "https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW",
#             "id": "55fhWPvDiMpLnE4ZzNXZyW",
#             "name": "Noah Cyrus",
#             "type": "artist",
#             "uri": "spotify:artist:55fhWPvDiMpLnE4ZzNXZyW"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5"
#         },
#         "href": "https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5",
#         "id": "5Gn3fFzlWL89j0hGumtXb5",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692",
#             "width": 64
#           }
#         ],
#         "name": "THE END OF EVERYTHING",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 8,
#         "type": "album",
#         "uri": "spotify:album:5Gn3fFzlWL89j0hGumtXb5"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa"
#             },
#             "href": "https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa",
#             "id": "6C1ohJrd5VydigQtaGy5Wa",
#             "name": "Joyner Lucas",
#             "type": "artist",
#             "uri": "spotify:artist:6C1ohJrd5VydigQtaGy5Wa"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx"
#             },
#             "href": "https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx",
#             "id": "41qil2VaGbD194gaEcmmyx",
#             "name": "Will Smith",
#             "type": "artist",
#             "uri": "spotify:artist:41qil2VaGbD194gaEcmmyx"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e"
#         },
#         "href": "https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e",
#         "id": "3tOe6XM8LmRA5vDAaMqp8e",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e",
#             "width": 64
#           }
#         ],
#         "name": "Will (Remix)",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:3tOe6XM8LmRA5vDAaMqp8e"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax"
#             },
#             "href": "https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax",
#             "id": "6Xgp2XMz1fhVYe7i6yNAax",
#             "name": "Trippie Redd",
#             "type": "artist",
#             "uri": "spotify:artist:6Xgp2XMz1fhVYe7i6yNAax"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV"
#             },
#             "href": "https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV",
#             "id": "2HPaUgqeutzr3jx5a9WyDV",
#             "name": "PARTYNEXTDOOR",
#             "type": "artist",
#             "uri": "spotify:artist:2HPaUgqeutzr3jx5a9WyDV"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu"
#         },
#         "href": "https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu",
#         "id": "7rcMHNqNbQxF5TaPMHFoKu",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761",
#             "width": 64
#           }
#         ],
#         "name": "Excitement",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:7rcMHNqNbQxF5TaPMHFoKu"
#       },
#       {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB"
#             },
#             "href": "https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB",
#             "id": "3NPpFNZtSTHheNBaWC82rB",
#             "name": "X Ambassadors",
#             "type": "artist",
#             "uri": "spotify:artist:3NPpFNZtSTHheNBaWC82rB"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr"
#             },
#             "href": "https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr",
#             "id": "0pCNk4D3E2xtszsm6hMsWr",
#             "name": "K.Flay",
#             "type": "artist",
#             "uri": "spotify:artist:0pCNk4D3E2xtszsm6hMsWr"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4"
#             },
#             "href": "https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4",
#             "id": "4ZgQDCtRqZlhLswVS6MHN4",
#             "name": "grandson",
#             "type": "artist",
#             "uri": "spotify:artist:4ZgQDCtRqZlhLswVS6MHN4"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AR",
#           "AT",
#           "AU",
#           "BE",
#           "BG",
#           "BH",
#           "BO",
#           "BR",
#           "CA",
#           "CH",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DE",
#           "DK",
#           "DO",
#           "DZ",
#           "EC",
#           "EE",
#           "EG",
#           "ES",
#           "FI",
#           "FR",
#           "GB",
#           "GR",
#           "GT",
#           "HK",
#           "HN",
#           "HU",
#           "ID",
#           "IE",
#           "IL",
#           "IN",
#           "IS",
#           "IT",
#           "JO",
#           "JP",
#           "KW",
#           "LB",
#           "LI",
#           "LT",
#           "LU",
#           "LV",
#           "MA",
#           "MC",
#           "MT",
#           "MX",
#           "MY",
#           "NI",
#           "NL",
#           "NO",
#           "NZ",
#           "OM",
#           "PA",
#           "PE",
#           "PH",
#           "PL",
#           "PS",
#           "PT",
#           "PY",
#           "QA",
#           "RO",
#           "SA",
#           "SE",
#           "SG",
#           "SK",
#           "SV",
#           "TH",
#           "TN",
#           "TR",
#           "TW",
#           "US",
#           "UY",
#           "VN",
#           "ZA"
#         ],
#         "external_urls": {
#           "spotify": "https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL"
#         },
#         "href": "https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL",
#         "id": "2JQbWWpYG6kKppiD6z2FwL",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28",
#             "width": 64
#           }
#         ],
#         "name": "Zen (with K.Flay & grandson)",
#         "release_date": "2020-05-15",
#         "release_date_precision": "day",
#         "total_tracks": 1,
#         "type": "album",
#         "uri": "spotify:album:2JQbWWpYG6kKppiD6z2FwL"
#       }
#     ],
#     "limit": 20,
#     "next": "https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20",
#     "offset": 0,
#     "previous": null,
#     "total": 100
#   }
# }

# %%
# Using the default Jupyter Notebook's display() helps
#display(data) 
# Uncomment this to do the same as just displaying the last line
data

# %% [markdown]
# To start exploring, let's check the type of our new `data` object and start mapping out the hierarchy.

# %%
# How can we access the keys?
data.keys()
# Out:
# dict_keys(['albums'])

# %% [markdown]
# In this case, there is only a single key, 'albums', so we'll continue on down the pathway exploring and mapping out the hierarchy. Once again, let's start by checking the type of this nested data structure.

# %%
data['albums']
# Out:
# {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#  'items': [{'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#      'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#      'id': '1RyvyyTE3xzB2ZywiAwp0i',
#      'name': 'Future',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#    'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#    'id': '4bNPOFOzxGhF5jhfIK6lit',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#      'width': 64}],
#    'name': 'High Off Life',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#      'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#      'id': '23fqKkggKUBHNkbKtXEls4',
#      'name': 'Kygo',
#      'type': 'artist',
#      'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#      'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#      'id': '5Pwc4xIPtQLFEnJriah9YJ',
#      'name': 'OneRepublic',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#    'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#    'id': '3LhriqAiHJYw7rxvtlkvQc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#      'width': 64}],
#    'name': 'Lose Somebody',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#    'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#    'id': '2Zg5xZo3WwIoAZys8OcUpG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#      'width': 64}],
#    'name': 'SCOOB! The Album',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#    'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#    'id': '2m5J1DUH7hJpPSOromIqpN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#      'width': 64}],
#    'name': 'Daisies',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#      'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#      'id': '6AgTAQt8XS6jRWi4sX7w49',
#      'name': 'Polo G',
#      'type': 'artist',
#      'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#    'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#    'id': '39xhYyNNDatQtgKw2KdXMz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#      'width': 64}],
#    'name': 'THE GOAT',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#      'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#      'id': '7gOdHgIoIKoe4i9Tta6qdD',
#      'name': 'Jonas Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#    'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#    'id': '0i96PtPJV65ddxsfMfo45F',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#      'width': 64}],
#    'name': 'XV',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#      'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#      'id': '25uiPmTg16RbhZWAqwLBy5',
#      'name': 'Charli XCX',
#      'type': 'artist',
#      'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#    'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#    'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#      'width': 64}],
#    'name': "how i'm feeling now",
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#      'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#      'id': '2jku7tDXc6XoB6MO2hFuqg',
#      'name': 'Tory Lanez',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#    'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#    'id': '3lalGt6k7JM3tIji1Xbgmk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#      'width': 64}],
#    'name': 'Temperature Rising',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#      'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#      'id': '2ueoLVCXQ948OfhVvAy3Nn',
#      'name': 'Perfume Genius',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#    'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#    'id': '6daEdTBi1hyFQgmsnR7oRr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#      'width': 64}],
#    'name': 'Set My Heart On Fire Immediately',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#      'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#      'id': '7rkW85dBwwrJtlHRDkJDAC',
#      'name': 'NAV',
#      'type': 'artist',
#      'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#    'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#    'id': '2kx4l1OQNT2JXLld9HJDIh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#      'width': 64}],
#    'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 32,
#    'type': 'album',
#    'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#      'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#      'id': '6oMuImdp5ZcFhWP0ESe6mG',
#      'name': 'Migos',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#    'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#    'id': '3PASWLvNfvfMF68dDznEgK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#      'width': 64}],
#    'name': 'Racks 2 Skinny',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#      'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#      'id': '5Zq7R5qmi58ByYyBQTlNuk',
#      'name': 'Lee Brice',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#    'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#    'id': '5LK5cCx0XdniivfZ91vOSv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#      'width': 64}],
#    'name': 'One Of Them Girls',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#      'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#      'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#      'name': 'Tiësto',
#      'type': 'artist',
#      'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#    'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#    'id': '6CIslPQSknp875cigkhKJC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#      'width': 64}],
#    'name': 'The London Sessions',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#      'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#      'id': '6pBNfggcZZDCmb0p92OnGn',
#      'name': 'Chase Rice',
#      'type': 'artist',
#      'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#    'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#    'id': '5XvXf3mdhShyLZhoJYR74q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#      'width': 64}],
#    'name': 'The Album, Pt. II',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#      'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#      'id': '1caBfBEapzw8z2Qz9q0OaQ',
#      'name': 'Asking Alexandria',
#      'type': 'artist',
#      'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#    'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#    'id': '5VKKXDvYuJmRc2UQHCwNQK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#      'width': 64}],
#    'name': 'Like A House On Fire',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#      'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#      'id': '7d3WFRME3vBY2cgoP38RDo',
#      'name': 'Lil Skies',
#      'type': 'artist',
#      'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#    'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#    'id': '3cVy1WTjSAVpzUc7MVCTLu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#      'width': 64}],
#    'name': 'Riot',
#    'release_date': '2020-05-13',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#      'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#      'id': '55fhWPvDiMpLnE4ZzNXZyW',
#      'name': 'Noah Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#    'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#    'id': '5Gn3fFzlWL89j0hGumtXb5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#      'width': 64}],
#    'name': 'THE END OF EVERYTHING',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#      'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#      'id': '6C1ohJrd5VydigQtaGy5Wa',
#      'name': 'Joyner Lucas',
#      'type': 'artist',
#      'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#      'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#      'id': '41qil2VaGbD194gaEcmmyx',
#      'name': 'Will Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#    'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#    'id': '3tOe6XM8LmRA5vDAaMqp8e',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#      'width': 64}],
#    'name': 'Will (Remix)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#      'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#      'id': '6Xgp2XMz1fhVYe7i6yNAax',
#      'name': 'Trippie Redd',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#      'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#      'id': '2HPaUgqeutzr3jx5a9WyDV',
#      'name': 'PARTYNEXTDOOR',
#      'type': 'artist',
#      'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#    'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#    'id': '7rcMHNqNbQxF5TaPMHFoKu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#      'width': 64}],
#    'name': 'Excitement',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#      'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#      'id': '3NPpFNZtSTHheNBaWC82rB',
#      'name': 'X Ambassadors',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#      'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#      'id': '0pCNk4D3E2xtszsm6hMsWr',
#      'name': 'K.Flay',
#      'type': 'artist',
#      'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#      'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#      'id': '4ZgQDCtRqZlhLswVS6MHN4',
#      'name': 'grandson',
#      'type': 'artist',
#      'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#    'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#    'id': '2JQbWWpYG6kKppiD6z2FwL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#      'width': 64}],
#    'name': 'Zen (with K.Flay & grandson)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 100}

# %%
data.get('albums')
# Out:
# {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#  'items': [{'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#      'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#      'id': '1RyvyyTE3xzB2ZywiAwp0i',
#      'name': 'Future',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#    'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#    'id': '4bNPOFOzxGhF5jhfIK6lit',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#      'width': 64}],
#    'name': 'High Off Life',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#      'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#      'id': '23fqKkggKUBHNkbKtXEls4',
#      'name': 'Kygo',
#      'type': 'artist',
#      'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#      'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#      'id': '5Pwc4xIPtQLFEnJriah9YJ',
#      'name': 'OneRepublic',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#    'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#    'id': '3LhriqAiHJYw7rxvtlkvQc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#      'width': 64}],
#    'name': 'Lose Somebody',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#    'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#    'id': '2Zg5xZo3WwIoAZys8OcUpG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#      'width': 64}],
#    'name': 'SCOOB! The Album',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#    'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#    'id': '2m5J1DUH7hJpPSOromIqpN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#      'width': 64}],
#    'name': 'Daisies',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#      'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#      'id': '6AgTAQt8XS6jRWi4sX7w49',
#      'name': 'Polo G',
#      'type': 'artist',
#      'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#    'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#    'id': '39xhYyNNDatQtgKw2KdXMz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#      'width': 64}],
#    'name': 'THE GOAT',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#      'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#      'id': '7gOdHgIoIKoe4i9Tta6qdD',
#      'name': 'Jonas Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#    'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#    'id': '0i96PtPJV65ddxsfMfo45F',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#      'width': 64}],
#    'name': 'XV',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#      'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#      'id': '25uiPmTg16RbhZWAqwLBy5',
#      'name': 'Charli XCX',
#      'type': 'artist',
#      'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#    'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#    'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#      'width': 64}],
#    'name': "how i'm feeling now",
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#      'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#      'id': '2jku7tDXc6XoB6MO2hFuqg',
#      'name': 'Tory Lanez',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#    'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#    'id': '3lalGt6k7JM3tIji1Xbgmk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#      'width': 64}],
#    'name': 'Temperature Rising',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#      'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#      'id': '2ueoLVCXQ948OfhVvAy3Nn',
#      'name': 'Perfume Genius',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#    'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#    'id': '6daEdTBi1hyFQgmsnR7oRr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#      'width': 64}],
#    'name': 'Set My Heart On Fire Immediately',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#      'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#      'id': '7rkW85dBwwrJtlHRDkJDAC',
#      'name': 'NAV',
#      'type': 'artist',
#      'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#    'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#    'id': '2kx4l1OQNT2JXLld9HJDIh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#      'width': 64}],
#    'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 32,
#    'type': 'album',
#    'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#      'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#      'id': '6oMuImdp5ZcFhWP0ESe6mG',
#      'name': 'Migos',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#    'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#    'id': '3PASWLvNfvfMF68dDznEgK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#      'width': 64}],
#    'name': 'Racks 2 Skinny',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#      'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#      'id': '5Zq7R5qmi58ByYyBQTlNuk',
#      'name': 'Lee Brice',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#    'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#    'id': '5LK5cCx0XdniivfZ91vOSv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#      'width': 64}],
#    'name': 'One Of Them Girls',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#      'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#      'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#      'name': 'Tiësto',
#      'type': 'artist',
#      'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#    'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#    'id': '6CIslPQSknp875cigkhKJC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#      'width': 64}],
#    'name': 'The London Sessions',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#      'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#      'id': '6pBNfggcZZDCmb0p92OnGn',
#      'name': 'Chase Rice',
#      'type': 'artist',
#      'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#    'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#    'id': '5XvXf3mdhShyLZhoJYR74q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#      'width': 64}],
#    'name': 'The Album, Pt. II',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#      'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#      'id': '1caBfBEapzw8z2Qz9q0OaQ',
#      'name': 'Asking Alexandria',
#      'type': 'artist',
#      'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#    'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#    'id': '5VKKXDvYuJmRc2UQHCwNQK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#      'width': 64}],
#    'name': 'Like A House On Fire',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#      'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#      'id': '7d3WFRME3vBY2cgoP38RDo',
#      'name': 'Lil Skies',
#      'type': 'artist',
#      'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#    'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#    'id': '3cVy1WTjSAVpzUc7MVCTLu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#      'width': 64}],
#    'name': 'Riot',
#    'release_date': '2020-05-13',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#      'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#      'id': '55fhWPvDiMpLnE4ZzNXZyW',
#      'name': 'Noah Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#    'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#    'id': '5Gn3fFzlWL89j0hGumtXb5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#      'width': 64}],
#    'name': 'THE END OF EVERYTHING',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#      'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#      'id': '6C1ohJrd5VydigQtaGy5Wa',
#      'name': 'Joyner Lucas',
#      'type': 'artist',
#      'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#      'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#      'id': '41qil2VaGbD194gaEcmmyx',
#      'name': 'Will Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#    'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#    'id': '3tOe6XM8LmRA5vDAaMqp8e',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#      'width': 64}],
#    'name': 'Will (Remix)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#      'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#      'id': '6Xgp2XMz1fhVYe7i6yNAax',
#      'name': 'Trippie Redd',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#      'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#      'id': '2HPaUgqeutzr3jx5a9WyDV',
#      'name': 'PARTYNEXTDOOR',
#      'type': 'artist',
#      'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#    'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#    'id': '7rcMHNqNbQxF5TaPMHFoKu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#      'width': 64}],
#    'name': 'Excitement',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#      'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#      'id': '3NPpFNZtSTHheNBaWC82rB',
#      'name': 'X Ambassadors',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#      'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#      'id': '0pCNk4D3E2xtszsm6hMsWr',
#      'name': 'K.Flay',
#      'type': 'artist',
#      'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#      'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#      'id': '4ZgQDCtRqZlhLswVS6MHN4',
#      'name': 'grandson',
#      'type': 'artist',
#      'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#    'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#    'id': '2JQbWWpYG6kKppiD6z2FwL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#      'width': 64}],
#    'name': 'Zen (with K.Flay & grandson)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 100}

# %%
type(data.get('albums'))
# Out:
# dict

# %%
data.get('albums').keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# At this point, things are starting to look something like this:
#
# ![](images/json_diagram1.jpg)
#
# If we were to continue checking individual data types, we'd have a lot to go through. To simplify this, let's use a `for` loop:

# %%
for key, value in data['albums'].items():
    print(key, type(value))
# Out:
# href <class 'str'>
# items <class 'list'>
# limit <class 'int'>
# next <class 'str'>
# offset <class 'int'>
# previous <class 'NoneType'>
# total <class 'int'>

# %% [markdown]
# Adding this to our diagram, we now have something like this:
#
# ![](images/json_diagram2.jpg)
#
# Let's look at the `items` list - this contains the album information.

# %%
type(data['albums']['items'])
# Out:
# list

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# KeyError: 0

# %%
data['albums'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-85ba86768112> in <module>
# ----> 1 data['albums'][0]
#
# KeyError: 0

# %%
# How can I grab the first entry?
data['albums']['items'][2]
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#    'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#    'id': '0LyfQWJT6nXafLPZqxe9Of',
#    'name': 'Various Artists',
#    'type': 'artist',
#    'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#  'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#  'id': '2Zg5xZo3WwIoAZys8OcUpG',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#    'width': 64}],
#  'name': 'SCOOB! The Album',
#  'release_date': '2020-05-15',
#  'release_date_precision': 'day',
#  'total_tracks': 12,
#  'type': 'album',
#  'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'}

# %% [markdown]
# We access values as we would for nested lists or dictionaries in Python.

# %%
data['albums']['items'][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
# Lets get the artist name
data['albums']['bitems'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#   'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#   'id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'name': 'Future',
#   'type': 'artist',
#   'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}]

# %%
albums = data['albums']['items']

# %%
type(albums)
# Out:
# list

# %%
len(albums)
# Out:
# 20

# %%
type(data['albums']['items'][0]['artists'])
# Out:
# list

# %%
len(data['albums']['items'][0]['artists'])
# Out:
# 1

# %%
data['albums']['items'][0]['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# %%
# Name of 2nd album artist
data['albums']['items'][1]['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#  'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#  'id': '23fqKkggKUBHNkbKtXEls4',
#  'name': 'Kygo',
#  'type': 'artist',
#  'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}

# %%
data['albums']['items'][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
data['albums']['items'][1]['name']
# Out:
# 'Lose Somebody'

# %%
albums = data['albums']['items']

# %%
len(albums)
# Out:
# 20

# %%
albums[0]
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#    'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#    'id': '1RyvyyTE3xzB2ZywiAwp0i',
#    'name': 'Future',
#    'type': 'artist',
#    'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#  'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#  'id': '4bNPOFOzxGhF5jhfIK6lit',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#    'width': 64}],
#  'name': 'High Off Life',
#  'release_date': '2020-05-15',
#  'release_date_precision': 'day',
#  'total_tracks': 21,
#  'type': 'album',
#  'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'}

# %% [markdown]
# # Loading in Plant Data

# %% [markdown]
# Now that we have a handle on how to deal with data in JSON form, let's load in a new dataset and construct an analysis!

# %%
with open('data/plants.json') as f:
    plants = json.load(f)

# %% [markdown]
# This dataset was gathered with the [Trefle API](https://docs.trefle.io/). It contains information about 1000 plants in JSON form.

# %%
type(plants)
# Out:
# list

# %%
# How many entries should we have? We can sanity check
len(plants)
# Out:
# 1000

# %%
plants[0] # index first entry of plant data
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %% [markdown]
# ## What Information Do We Have?

# %% [markdown]
# Let's take a look at the first plant in our list to see what information is available.

# %%
# First plant
plants[0]
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %%
plants[0].keys()
# Out:
# dict_keys(['id', 'common_name', 'slug', 'scientific_name', 'year', 'bibliography', 'author', 'status', 'rank', 'family_common_name', 'genus_id', 'image_url', 'synonyms', 'genus', 'family', 'links'])

# %% [markdown]
# You can find more information about these fields [here](https://docs.trefle.io/docs/advanced/plants-fields).

# %% [markdown]
# ## Plant Families

# %% [markdown]
# Let's start by seeing what botanical families are represented in our data. We'll build a dictionary that counts the plants by family. We'll use the common names for this purpose.

# %%
# Let's use a default dict for this - need to import it first!
from collections import defaultdict

# %%
plant_dict = defaultdict(int)
plant_dict
# Out:
# defaultdict(int, {})

# %%
family_names = [plant['family_common_name'] for plant in plants]
family_names
# Out:
# ['Beech family',
#  'Nettle family',
#  'Grass family',
#  'Plantain family',
#  'Beech family',
#  'Grass family',
#  'Buttercup family',
#  'Grass family',
#  'Pea family',
#  'Olive family',
#  'Rose family',
#  'Pea family',
#  'Buttercup family',
#  'Birch family',
#  'Beech family',
#  'Rush family',
#  'Buckwheat family',
#  'Grass family',
#  'Rose family',
#  'Soapberry family',
#  'Plantain family',
#  'Grass family',
#  'Pine family',
#  'Pea family',
#  'Grass family',
#  'Mint family',
#  'Rose family',
#  'Madder family',
#  None,
#  'Grass family',
#  'Pink family',
#  'Birch family',
#  'Grass family',
#  'Birch family',
#  'Carrot family',
#  'Geranium family',
#  'Grass family',
#  'Rose family',
#  'Grass family',
#  'Mint family',
#  'Grass family',
#  'Grass family',
#  None,
#  'Rose family',
#  'Aster family',
#  'Aster family',
#  'Beech family',
#  'Carrot family',
#  'Carrot family',
#  'Aster family',
#  'Horsetail family',
#  'Rose family',
#  'Pine family',
#  'Grass family',
#  'Plantain family',
#  'Heath family',
#  'Loosestrife family',
#  'Grass family',
#  'Aster family',
#  'Bracken Fern family',
#  'Mustard family',
#  'Buckwheat family',
#  'Pea family',
#  'Evening Primrose family',
#  'Buckwheat family',
#  'Rose family',
#  'Willow family',
#  'Polypody family',
#  'Dogwood family',
#  'Olive family',
#  'Honeysuckle family',
#  'Grass family',
#  'Pea family',
#  'Buckwheat family',
#  'Pine family',
#  'Madder family',
#  'Soapberry family',
#  'Rose family',
#  'Morning-glory family',
#  'Aster family',
#  'Rose family',
#  'Grass family',
#  'Pea family',
#  'Iris family',
#  'Buckwheat family',
#  'Rose family',
#  'Pea family',
#  'Buttercup family',
#  'Evening Primrose family',
#  'Rose family',
#  'Birch family',
#  'Aster family',
#  'Spleenwort family',
#  'Birch family',
#  'Aster family',
#  'Amaranth family',
#  'Sedge family',
#  'Aster family',
#  'Buckthorn family',
#  'Buttercup family',
#  'Pink family',
#  'Holly family',
#  'Potato family',
#  'Bellflower family',
#  'Aster family',
#  'Rose family',
#  'Aster family',
#  'Mint family',
#  'Grass family',
#  'Grass family',
#  'Morning-glory family',
#  'Rush family',
#  'Soapberry family',
#  'Mint family',
#  'Rush family',
#  'Aster family',
#  'Aster family',
#  'Madder family',
#  'Mustard family',
#  'Pea family',
#  'Buttercup family',
#  'Grass family',
#  'Wood-Sorrel family',
#  'Mint family',
#  'Aster family',
#  'Pea family',
#  'Aster family',
#  'Pea family',
#  'Pine family',
#  'Aster family',
#  'Pine family',
#  None,
#  'Plantain family',
#  'Mint family',
#  'Pink family',
#  'Borage family',
#  'Bittersweet family',
#  'Primrose family',
#  'Polypody family',
#  'Honeysuckle family',
#  'Honeysuckle family',
#  'Grass family',
#  'Aster family',
#  'Horsetail family',
#  'Grass family',
#  'Grass family',
#  'Carrot family',
#  'Grass family',
#  'Rush family',
#  'Plantain family',
#  'Honeysuckle family',
#  'Buttercup family',
#  'Plantain family',
#  'Aster family',
#  'Primrose family',
#  'Poppy family',
#  'Rose family',
#  'Aster family',
#  'Mint family',
#  'Grass family',
#  'Grass family',
#  'Horsetail family',
#  'Grass family',
#  'Pea family',
#  'Sedge family',
#  'Plantain family',
#  'Polypody family',
#  'Borage family',
#  'Aster family',
#  'Beech family',
#  'Heath family',
#  'Grass family',
#  'Buttercup family',
#  'Sedge family',
#  'Mint family',
#  'Rush family',
#  'Geranium family',
#  'Spurge family',
#  'Buckwheat family',
#  'Borage family',
#  'Pea family',
#  'Cat-tail family',
#  'Beech family',
#  'Mint family',
#  'Arum family',
#  'Olive family',
#  'Pink family',
#  'Water-plantain family',
#  'Mint family',
#  'Borage family',
#  'Pea family',
#  'Rose family',
#  'Pink family',
#  'Mustard family',
#  'Buckwheat family',
#  'Aster family',
#  'Rose family',
#  'Grass family',
#  'Hemp family',
#  'Honeysuckle family',
#  'Grass family',
#  'Rush family',
#  None,
#  'Grass family',
#  'Sumac family',
#  'Aster family',
#  'Touch-me-not family',
#  'Sedge family',
#  'Geranium family',
#  None,
#  'Pea family',
#  'Polypody family',
#  'Potato family',
#  'Mustard family',
#  'Rush family',
#  'Heath family',
#  'Broom-rape family',
#  'Evening Primrose family',
#  None,
#  'Pink family',
#  'Plantain family',
#  'Elm family',
#  'Pea family',
#  'Heath family',
#  None,
#  'Spurge family',
#  'Plantain family',
#  'Primrose family',
#  None,
#  'Flax family',
#  'Buttercup family',
#  None,
#  None,
#  'Mustard family',
#  'Geranium family',
#  'Rush family',
#  'Arum family',
#  'Pink family',
#  'Stonecrop family',
#  'Grass family',
#  'Rose family',
#  'Pine family',
#  'Aster family',
#  'Brachythecium moss family',
#  'Broom-rape family',
#  'Heath family',
#  'Pea family',
#  'Rock-rose family',
#  'Plantain family',
#  'Mallow family',
#  'Rose family',
#  'Aster family',
#  'Buckbean family',
#  'Cat-tail family',
#  'Rush family',
#  'Birch family',
#  'Buckwheat family',
#  'Aster family',
#  'Rose family',
#  'Spurge family',
#  'Carrot family',
#  'Grass family',
#  None,
#  None,
#  'Pink family',
#  'Pea family',
#  'Aster family',
#  None,
#  'Mint family',
#  'Pea family',
#  'Mustard family',
#  'Sundew family',
#  'Elm family',
#  'Evening Primrose family',
#  'Aster family',
#  'Aster family',
#  None,
#  'Grass family',
#  'Mint family',
#  'Sedge family',
#  'Pea family',
#  'Horsetail family',
#  'Pea family',
#  'Beech family',
#  'Carrot family',
#  'Milkwort family',
#  'Evening Primrose family',
#  'Mint family',
#  'Mustard family',
#  'Buttercup family',
#  'Mint family',
#  'Cypress family',
#  'Pine family',
#  'Mint family',
#  'Evening Primrose family',
#  None,
#  'Willow family',
#  'Mint family',
#  'Rose family',
#  'Plantain family',
#  'Madder family',
#  'Mint family',
#  None,
#  'Sedge family',
#  'Myrtle family',
#  'Evening Primrose family',
#  'Grass family',
#  'Mint family',
#  'Madder family',
#  'Verbena family',
#  'Buttercup family',
#  'Spurge family',
#  'Grass family',
#  'Ginseng family',
#  'Mint family',
#  'Bittersweet family',
#  'Pea family',
#  'Mint family',
#  'Aster family',
#  'Pink family',
#  'Rose family',
#  'Pea family',
#  None,
#  'Aster family',
#  'Mustard family',
#  None,
#  'Pea family',
#  'Buckwheat family',
#  'Rose family',
#  'Mint family',
#  None,
#  'Rush family',
#  'Rock-rose family',
#  'Sedge family',
#  'Currant family',
#  'Aster family',
#  'Spleenwort family',
#  'Stonecrop family',
#  'Heath family',
#  'Carrot family',
#  'Wood-Sorrel family',
#  'Poppy family',
#  'Bellflower family',
#  'Amaranth family',
#  'Sandalwood family',
#  None,
#  'Heath family',
#  'Rose family',
#  'Aster family',
#  'Mint family',
#  'Pink family',
#  'Pondweed family',
#  'Pea family',
#  'Water-lily family',
#  'Madder family',
#  'Mallow family',
#  'Cypress family',
#  'Sedge family',
#  'Pea family',
#  'Sedge family',
#  'Pea family',
#  'Amaranth family',
#  'Spurge family',
#  'Gentian family',
#  'Aster family',
#  'Mustard family',
#  'Rose family',
#  'Rose family',
#  None,
#  'Rose family',
#  'Potato family',
#  'Currant family',
#  'Borage family',
#  'Buckthorn family',
#  'Rose family',
#  'Amaranth family',
#  None,
#  'Carrot family',
#  'Yam family',
#  'Soapberry family',
#  'Rose family',
#  'Heath family',
#  'Rush family',
#  'Sedge family',
#  'Mustard family',
#  'Pine family',
#  'Pink family',
#  'Myrtle family',
#  'Heath family',
#  'Honeysuckle family',
#  'Walnut family',
#  None,
#  'Brachythecium moss family',
#  'Rose family',
#  'Plantain family',
#  'Boxwood family',
#  'Plantain family',
#  'Pea family',
#  'Dogbane family',
#  'Pea family',
#  'Rock-rose family',
#  None,
#  'Grass family',
#  'Grass family',
#  'Geranium family',
#  'Dogbane family',
#  None,
#  'Mignonette family',
#  'Spleenwort family',
#  'Buttercup family',
#  'Grass family',
#  'Buttercup family',
#  'Mint family',
#  'Bladderwort family',
#  'Buckwheat family',
#  'Evening Primrose family',
#  None,
#  'Buttercup family',
#  'Spleenwort family',
#  'Melastome family',
#  'Grass family',
#  'Plantain family',
#  'Aster family',
#  'Pondweed family',
#  'Primrose family',
#  'Buckwheat family',
#  'Saxifrage family',
#  'Primrose family',
#  'Rush family',
#  'Grass family',
#  'Mustard family',
#  'Beech family',
#  'Purslane family',
#  'Rose family',
#  'Aster family',
#  'Pea family',
#  'Grape family',
#  'Spleenwort family',
#  'Sedge family',
#  'Pokeweed family',
#  'Mint family',
#  'Pea family',
#  'Mezereum family',
#  'Mustard family',
#  'Spurge family',
#  'Beech family',
#  'Sedge family',
#  'Willow family',
#  'Sedge family',
#  None,
#  'Bellflower family',
#  'Potato family',
#  'Grass family',
#  'Heath family',
#  'Pea family',
#  None,
#  'Pink family',
#  'Poppy family',
#  'Rush family',
#  None,
#  'Dogbane family',
#  'Aster family',
#  'Rock-rose family',
#  'Bayberry family',
#  'Soapberry family',
#  'Mallow family',
#  'Carrot family',
#  None,
#  None,
#  'Heath family',
#  'Grass family',
#  'Mint family',
#  'Buckwheat family',
#  'Grass family',
#  'Geranium family',
#  'Aster family',
#  'Rose family',
#  'Grass family',
#  'Sedge family',
#  None,
#  'Grass family',
#  'Arum family',
#  None,
#  None,
#  'Club-moss family',
#  'Arum family',
#  'Arum family',
#  'Aster family',
#  'Carrot family',
#  'Mint family',
#  'Grass family',
#  'Potato family',
#  'Primrose family',
#  'Grass family',
#  None,
#  'Carrot family',
#  'Sedge family',
#  'Aster family',
#  'Primrose family',
#  'Hornwort family',
#  'Carrot family',
#  'Honeysuckle family',
#  'Pea family',
#  'Pea family',
#  None,
#  None,
#  'Pink family',
#  None,
#  'Pea family',
#  'Geranium family',
#  None,
#  'Sedge family',
#  None,
#  'Bellflower family',
#  None,
#  'Mustard family',
#  'Rush family',
#  'Nettle family',
#  'Pink family',
#  'Mint family',
#  'Leadwort family',
#  'Pea family',
#  'Touch-me-not family',
#  'Mallow family',
#  None,
#  'Bellflower family',
#  'Grass family',
#  'Aster family',
#  'Arrow-grass family',
#  None,
#  'Rose family',
#  None,
#  'Pink family',
#  'Amaranth family',
#  'Stonecrop family',
#  'Cucumber family',
#  'Currant family',
#  'Aster family',
#  'Rose family',
#  'Carrot family',
#  None,
#  'Water Milfoil family',
#  'Honeysuckle family',
#  None,
#  'Madder family',
#  'Rush family',
#  'Rush family',
#  'Sedge family',
#  'Carrot family',
#  'Arum family',
#  'Grass family',
#  'Madder family',
#  'Potato family',
#  'Arum family',
#  'Pink family',
#  'Mint family',
#  'Broom-rape family',
#  'Birch family',
#  'Carrot family',
#  'Heath family',
#  'Mint family',
#  'Aster family',
#  None,
#  'Plantain family',
#  None,
#  'Primrose family',
#  'Bellflower family',
#  'Carrot family',
#  'Bellflower family',
#  'Tape-grass family',
#  'Grass family',
#  'Primrose family',
#  'Mustard family',
#  'Aster family',
#  None,
#  None,
#  'Rose family',
#  'Rose family',
#  'Aster family',
#  'Grass family',
#  'Touch-me-not family',
#  'Tape-grass family',
#  'Rose family',
#  'Borage family',
#  'Broom-rape family',
#  'Plantain family',
#  'Broom-rape family',
#  'Tape-grass family',
#  'Aster family',
#  'Pondweed family',
#  'Broom-rape family',
#  'Pea family',
#  'Tape-grass family',
#  'Sedge family',
#  'Carrot family',
#  'Water-lily family',
#  'Buttercup family',
#  'Mallow family',
#  'Rose family',
#  'Aster family',
#  'Tape-grass family',
#  'Tape-grass family',
#  'Manatee-grass family',
#  'Tape-grass family',
#  'Eel-grass family',
#  'Manatee-grass family',
#  'Tape-grass family',
#  'Manatee-grass family',
#  'Flowering Rush family',
#  'Manatee-grass family',
#  'Grass family',
#  'Horsetail family',
#  'Sedge family',
#  'Tape-grass family',
#  'Tape-grass family',
#  None,
#  None,
#  None,
#  'Saxifrage family',
#  'Club-moss family',
#  'Grass family',
#  'Grass family',
#  'Cat-tail family',
#  'Pink family',
#  None,
#  'Pink family',
#  None,
#  None,
#  'Grass family',
#  'Buttercup family',
#  'Geranium family',
#  'Lily family',
#  None,
#  'Plantain family',
#  'Grass family',
#  'Verbena family',
#  'Pea family',
#  'Cat-tail family',
#  'Broom-rape family',
#  'Aster family',
#  'Heath family',
#  None,
#  'Pea family',
#  None,
#  'Bellflower family',
#  'Rose family',
#  'Mustard family',
#  'Aster family',
#  'Plantain family',
#  'Aster family',
#  'Arrow-grass family',
#  'Aster family',
#  'Grass family',
#  'Spike-moss family',
#  'Sedge family',
#  None,
#  None,
#  'Mezereum family',
#  'Brachythecium moss family',
#  'Potato family',
#  'Aster family',
#  'Heath family',
#  None,
#  'Sedge family',
#  'Borage family',
#  'Grass family',
#  'Mint family',
#  'Rose family',
#  'Heath family',
#  'Currant family',
#  'Pea family',
#  None,
#  'Pea family',
#  'Carrot family',
#  None,
#  'Pea family',
#  None,
#  'Sedge family',
#  'Grass family',
#  'Borage family',
#  'Pea family',
#  'Aster family',
#  None,
#  None,
#  None,
#  'Rose family',
#  'Barberry family',
#  "Adder's-tongue family",
#  'Buckwheat family',
#  'Mint family',
#  'Oleaster family',
#  'Pea family',
#  'Pea family',
#  'Spurge family',
#  'Aster family',
#  None,
#  'Aster family',
#  'Geranium family',
#  'Plantain family',
#  'Plantain family',
#  'Saxifrage family',
#  'Olive family',
#  'Mint family',
#  None,
#  'Pea family',
#  'Pine family',
#  None,
#  'Gentian family',
#  'Grass family',
#  'Rush family',
#  'Pondweed family',
#  'Sedge family',
#  'Mint family',
#  'Aster family',
#  'Aster family',
#  'Mustard family',
#  None,
#  'Grass family',
#  'Buttercup family',
#  'Mignonette family',
#  'Pea family',
#  None,
#  None,
#  None,
#  'Pondweed family',
#  'Mint family',
#  'Rose family',
#  None,
#  None,
#  'Borage family',
#  None,
#  None,
#  'Geranium family',
#  'Carrot family',
#  'Broom-rape family',
#  'Palm family',
#  'Borage family',
#  'Rose family',
#  'Aster family',
#  'Sedge family',
#  'Mint family',
#  'Aster family',
#  'Mustard family',
#  'Grass family',
#  'Stonecrop family',
#  None,
#  None,
#  'Rose family',
#  None,
#  'Rose family',
#  'Borage family',
#  'Rose family',
#  'Buckthorn family',
#  'Carrot family',
#  'Madder family',
#  'Horsetail family',
#  'Grape family',
#  None,
#  'Mint family',
#  'Aster family',
#  'Pea family',
#  'Mustard family',
#  'Evening Primrose family',
#  'Mint family',
#  'Gentian family',
#  'Carrot family',
#  'Sedge family',
#  'Grass family',
#  'Grass family',
#  'Flax family',
#  None,
#  'Stonecrop family',
#  'Spleenwort family',
#  'Pondweed family',
#  'Gentian family',
#  None,
#  'Mustard family',
#  'Soapberry family',
#  'Pink family',
#  None,
#  'Sedge family',
#  'Sedge family',
#  'Mint family',
#  'Grass family',
#  None,
#  'Pea family',
#  'Spurge family',
#  'Buckwheat family',
#  'Mint family',
#  'Heath family',
#  'Spleenwort family',
#  'Gentian family',
#  'Aster family',
#  'Dogwood family',
#  'Rose family',
#  'Pea family',
#  'Sedge family',
#  'Aster family',
#  'Mustard family',
#  'Pondweed family',
#  'Bellflower family',
#  'Mint family',
#  None,
#  'Buckwheat family',
#  'Milkwort family',
#  'Pea family',
#  None,
#  'Rush family',
#  None,
#  'Grass family',
#  'Carrot family',
#  'Verbena family',
#  'Pink family',
#  None,
#  'Beech family',
#  'Saxifrage family',
#  'Mustard family',
#  'Aster family',
#  'Lily family',
#  'Buckwheat family',
#  'Pea family',
#  'Sedge family',
#  'Buttercup family',
#  'Sedge family',
#  'Acanthus family',
#  'Pink family',
#  'Grass family',
#  'Plantain family',
#  'Buckwheat family',
#  'Spurge family',
#  'Sedge family',
#  'Pink family',
#  'Grass family',
#  'Horsetail family',
#  'Pea family',
#  'Aster family',
#  'Sedge family',
#  'Mustard family',
#  'Poppy family',
#  'Sundew family',
#  'Aster family',
#  'Pea family',
#  None,
#  'Stonecrop family',
#  'Aster family',
#  'Calamus family',
#  'Sedge family',
#  'Pea family',
#  'Stonecrop family',
#  'Loosestrife family',
#  None,
#  'Sedge family',
#  'Primrose family',
#  'Carrot family',
#  'Grass family',
#  'Rose family',
#  'Carrot family',
#  'Pea family',
#  'Broom-rape family',
#  "Adder's-tongue family",
#  'Evening Primrose family',
#  'Buttercup family',
#  'Pink family',
#  'Borage family',
#  'Pink family',
#  'Poppy family',
#  'Buttercup family',
#  'Polypody family',
#  'Buttercup family',
#  'Buttercup family',
#  'Grass family',
#  'Saxifrage family',
#  'Mustard family',
#  'Mint family',
#  None,
#  'Carrot family',
#  'Sedge family',
#  None,
#  'Poppy family',
#  'Carrot family',
#  'Mezereum family',
#  None,
#  'Primrose family',
#  'Grass family',
#  'Mint family',
#  'Grass family',
#  'Pea family',
#  'Mint family',
#  'Aster family',
#  'Arum family',
#  None,
#  'Pea family',
#  'Carrot family',
#  'Gentian family',
#  'Pea family',
#  None,
#  'Pink family',
#  'Mint family',
#  'Aster family',
#  None,
#  None,
#  None,
#  'Aster family',
#  'Polypody family',
#  'Morning-glory family',
#  'Aster family',
#  'Spurge family',
#  'Mustard family',
#  'Pea family',
#  None,
#  'Pine family',
#  'Grass family',
#  'Broom-rape family',
#  'Soapberry family',
#  'Plantain family',
#  'Amaranth family',
#  'Aster family',
#  'Aster family',
#  'Aster family',
#  'Aster family',
#  'Rock-rose family',
#  'Sedge family',
#  'Aster family',
#  'Grass family',
#  'Poppy family',
#  'Carrot family',
#  'Wood-Sorrel family',
#  'Grass family',
#  'Mustard family',
#  None,
#  'Mustard family',
#  'Aster family',
#  None,
#  'Olive family',
#  'Pea family',
#  'Bladderwort family',
#  'Water Milfoil family',
#  'Primrose family',
#  'Rush family',
#  'Water Milfoil family',
#  'Dogwood family',
#  'Mustard family',
#  'Aster family',
#  'Carrot family',
#  'Sedge family',
#  'Sedge family',
#  None,
#  'Birthwort family',
#  'Sumac family',
#  None,
#  None,
#  'Pittosporum family',
#  'Mustard family',
#  'Pea family',
#  'Sedge family',
#  'Honeysuckle family',
#  'Heath family',
#  'Grass family',
#  'Mustard family',
#  None,
#  'Mint family',
#  'Club-moss family',
#  'Grass family',
#  'Aster family',
#  'Rose family',
#  'Borage family',
#  None,
#  'Pink family',
#  'Pink family',
#  'Grass family',
#  'Grass family',
#  'Stonecrop family',
#  None,
#  'Pink family',
#  'Rose family',
#  None,
#  None,
#  None,
#  'Plantain family',
#  'Palm family',
#  'Sedge family',
#  'Aster family',
#  'Pittosporum family',
#  'Club-moss family',
#  'Rose family',
#  'Spleenwort family',
#  'Grass family',
#  'Plantain family',
#  'Polypody family',
#  'Pink family',
#  'Plantain family',
#  'Aster family',
#  'Aster family',
#  'Pink family',
#  'Pink family',
#  'Grass family',
#  'Pea family',
#  'Pea family',
#  'Sedge family',
#  'Aster family']

# %%
len(family_names)
# Out:
# 1000

# %%
unique_names = set(family_names)
unique_names
# Out:
# {'Acanthus family',
#  "Adder's-tongue family",
#  'Amaranth family',
#  'Arrow-grass family',
#  'Arum family',
#  'Aster family',
#  'Barberry family',
#  'Bayberry family',
#  'Beech family',
#  'Bellflower family',
#  'Birch family',
#  'Birthwort family',
#  'Bittersweet family',
#  'Bladderwort family',
#  'Borage family',
#  'Boxwood family',
#  'Brachythecium moss family',
#  'Bracken Fern family',
#  'Broom-rape family',
#  'Buckbean family',
#  'Buckthorn family',
#  'Buckwheat family',
#  'Buttercup family',
#  'Calamus family',
#  'Carrot family',
#  'Cat-tail family',
#  'Club-moss family',
#  'Cucumber family',
#  'Currant family',
#  'Cypress family',
#  'Dogbane family',
#  'Dogwood family',
#  'Eel-grass family',
#  'Elm family',
#  'Evening Primrose family',
#  'Flax family',
#  'Flowering Rush family',
#  'Gentian family',
#  'Geranium family',
#  'Ginseng family',
#  'Grape family',
#  'Grass family',
#  'Heath family',
#  'Hemp family',
#  'Holly family',
#  'Honeysuckle family',
#  'Hornwort family',
#  'Horsetail family',
#  'Iris family',
#  'Leadwort family',
#  'Lily family',
#  'Loosestrife family',
#  'Madder family',
#  'Mallow family',
#  'Manatee-grass family',
#  'Melastome family',
#  'Mezereum family',
#  'Mignonette family',
#  'Milkwort family',
#  'Mint family',
#  'Morning-glory family',
#  'Mustard family',
#  'Myrtle family',
#  'Nettle family',
#  None,
#  'Oleaster family',
#  'Olive family',
#  'Palm family',
#  'Pea family',
#  'Pine family',
#  'Pink family',
#  'Pittosporum family',
#  'Plantain family',
#  'Pokeweed family',
#  'Polypody family',
#  'Pondweed family',
#  'Poppy family',
#  'Potato family',
#  'Primrose family',
#  'Purslane family',
#  'Rock-rose family',
#  'Rose family',
#  'Rush family',
#  'Sandalwood family',
#  'Saxifrage family',
#  'Sedge family',
#  'Soapberry family',
#  'Spike-moss family',
#  'Spleenwort family',
#  'Spurge family',
#  'Stonecrop family',
#  'Sumac family',
#  'Sundew family',
#  'Tape-grass family',
#  'Touch-me-not family',
#  'Verbena family',
#  'Walnut family',
#  'Water Milfoil family',
#  'Water-lily family',
#  'Water-plantain family',
#  'Willow family',
#  'Wood-Sorrel family',
#  'Yam family'}

# %%
len(unique_names)
# Out:
# 103

# %%
plant_dict2 = {name: 0 for name in unique_names}
plant_dict2
# Out:
# {'Honeysuckle family': 0,
#  'Aster family': 0,
#  'Buckwheat family': 0,
#  'Morning-glory family': 0,
#  'Leadwort family': 0,
#  'Polypody family': 0,
#  'Amaranth family': 0,
#  'Sandalwood family': 0,
#  None: 0,
#  'Poppy family': 0,
#  'Buckthorn family': 0,
#  'Carrot family': 0,
#  'Grape family': 0,
#  'Bittersweet family': 0,
#  'Mallow family': 0,
#  'Arum family': 0,
#  'Lily family': 0,
#  'Spurge family': 0,
#  'Purslane family': 0,
#  'Willow family': 0,
#  'Boxwood family': 0,
#  'Cypress family': 0,
#  'Club-moss family': 0,
#  'Loosestrife family': 0,
#  'Dogwood family': 0,
#  'Melastome family': 0,
#  'Cucumber family': 0,
#  'Manatee-grass family': 0,
#  'Grass family': 0,
#  'Sundew family': 0,
#  'Evening Primrose family': 0,
#  'Oleaster family': 0,
#  'Touch-me-not family': 0,
#  'Water Milfoil family': 0,
#  'Beech family': 0,
#  'Spleenwort family': 0,
#  'Tape-grass family': 0,
#  'Hornwort family': 0,
#  'Nettle family': 0,
#  'Borage family': 0,
#  'Spike-moss family': 0,
#  'Mezereum family': 0,
#  'Pondweed family': 0,
#  'Wood-Sorrel family': 0,
#  'Olive family': 0,
#  'Flax family': 0,
#  'Heath family': 0,
#  'Primrose family': 0,
#  'Mustard family': 0,
#  'Pittosporum family': 0,
#  'Bayberry family': 0,
#  'Water-lily family': 0,
#  'Walnut family': 0,
#  'Currant family': 0,
#  'Myrtle family': 0,
#  'Buttercup family': 0,
#  'Geranium family': 0,
#  'Mint family': 0,
#  'Iris family': 0,
#  'Hemp family': 0,
#  'Pink family': 0,
#  'Rush family': 0,
#  'Birch family': 0,
#  'Palm family': 0,
#  'Elm family': 0,
#  'Barberry family': 0,
#  'Pokeweed family': 0,
#  'Holly family': 0,
#  'Plantain family': 0,
#  'Gentian family': 0,
#  'Pea family': 0,
#  'Calamus family': 0,
#  'Cat-tail family': 0,
#  'Yam family': 0,
#  'Bracken Fern family': 0,
#  'Broom-rape family': 0,
#  "Adder's-tongue family": 0,
#  'Flowering Rush family': 0,
#  'Bladderwort family': 0,
#  'Verbena family': 0,
#  'Arrow-grass family': 0,
#  'Sedge family': 0,
#  'Buckbean family': 0,
#  'Dogbane family': 0,
#  'Eel-grass family': 0,
#  'Bellflower family': 0,
#  'Ginseng family': 0,
#  'Soapberry family': 0,
#  'Potato family': 0,
#  'Rose family': 0,
#  'Madder family': 0,
#  'Pine family': 0,
#  'Rock-rose family': 0,
#  'Saxifrage family': 0,
#  'Birthwort family': 0,
#  'Brachythecium moss family': 0,
#  'Sumac family': 0,
#  'Stonecrop family': 0,
#  'Horsetail family': 0,
#  'Mignonette family': 0,
#  'Water-plantain family': 0,
#  'Milkwort family': 0,
#  'Acanthus family': 0}

# %%
for plant in plants:
    plant_dict[plant['family_common_name']] += 1

# %%
plant_dict
# Out:
# defaultdict(int,
#             {'Beech family': 10,
#              'Nettle family': 2,
#              'Grass family': 81,
#              'Plantain family': 25,
#              'Buttercup family': 21,
#              'Pea family': 63,
#              'Olive family': 5,
#              'Rose family': 49,
#              'Birch family': 7,
#              'Rush family': 19,
#              'Buckwheat family': 17,
#              'Soapberry family': 7,
#              'Pine family': 10,
#              'Mint family': 45,
#              'Madder family': 9,
#              None: 113,
#              'Pink family': 31,
#              'Carrot family': 29,
#              'Geranium family': 10,
#              'Aster family': 80,
#              'Horsetail family': 7,
#              'Heath family': 17,
#              'Loosestrife family': 2,
#              'Bracken Fern family': 1,
#              'Mustard family': 29,
#              'Evening Primrose family': 10,
#              'Willow family': 3,
#              'Polypody family': 7,
#              'Dogwood family': 3,
#              'Honeysuckle family': 9,
#              'Morning-glory family': 3,
#              'Iris family': 1,
#              'Spleenwort family': 8,
#              'Amaranth family': 6,
#              'Sedge family': 41,
#              'Buckthorn family': 3,
#              'Holly family': 1,
#              'Potato family': 7,
#              'Bellflower family': 9,
#              'Wood-Sorrel family': 3,
#              'Borage family': 13,
#              'Bittersweet family': 2,
#              'Primrose family': 12,
#              'Poppy family': 7,
#              'Spurge family': 10,
#              'Cat-tail family': 4,
#              'Arum family': 8,
#              'Water-plantain family': 1,
#              'Hemp family': 1,
#              'Sumac family': 2,
#              'Touch-me-not family': 3,
#              'Broom-rape family': 10,
#              'Elm family': 2,
#              'Flax family': 2,
#              'Stonecrop family': 8,
#              'Brachythecium moss family': 3,
#              'Rock-rose family': 5,
#              'Mallow family': 5,
#              'Buckbean family': 1,
#              'Sundew family': 2,
#              'Milkwort family': 2,
#              'Cypress family': 2,
#              'Myrtle family': 2,
#              'Verbena family': 3,
#              'Ginseng family': 1,
#              'Currant family': 4,
#              'Sandalwood family': 1,
#              'Pondweed family': 7,
#              'Water-lily family': 2,
#              'Gentian family': 6,
#              'Yam family': 1,
#              'Walnut family': 1,
#              'Boxwood family': 1,
#              'Dogbane family': 3,
#              'Mignonette family': 2,
#              'Bladderwort family': 2,
#              'Melastome family': 1,
#              'Saxifrage family': 5,
#              'Purslane family': 1,
#              'Grape family': 2,
#              'Pokeweed family': 1,
#              'Mezereum family': 3,
#              'Bayberry family': 1,
#              'Club-moss family': 4,
#              'Hornwort family': 1,
#              'Leadwort family': 1,
#              'Arrow-grass family': 2,
#              'Cucumber family': 1,
#              'Water Milfoil family': 3,
#              'Tape-grass family': 10,
#              'Manatee-grass family': 4,
#              'Eel-grass family': 1,
#              'Flowering Rush family': 1,
#              'Lily family': 2,
#              'Spike-moss family': 1,
#              'Barberry family': 1,
#              "Adder's-tongue family": 2,
#              'Oleaster family': 1,
#              'Palm family': 2,
#              'Acanthus family': 1,
#              'Calamus family': 1,
#              'Birthwort family': 1,
#              'Pittosporum family': 2})

# %%
type(plant_dict)
# Out:
# collections.defaultdict

# %%
len(plant_dict.keys())
# Out:
# 103

# %%
plant_dict.get('Grass family')
# Out:
# 81

# %%
for plant in plants:
    plant_dict2[plant['family_common_name']] += 1
    
plant_dict2
# Out:
# {'Honeysuckle family': 9,
#  'Aster family': 80,
#  'Buckwheat family': 17,
#  'Morning-glory family': 3,
#  'Leadwort family': 1,
#  'Polypody family': 7,
#  'Amaranth family': 6,
#  'Sandalwood family': 1,
#  None: 113,
#  'Poppy family': 7,
#  'Buckthorn family': 3,
#  'Carrot family': 29,
#  'Grape family': 2,
#  'Bittersweet family': 2,
#  'Mallow family': 5,
#  'Arum family': 8,
#  'Lily family': 2,
#  'Spurge family': 10,
#  'Purslane family': 1,
#  'Willow family': 3,
#  'Boxwood family': 1,
#  'Cypress family': 2,
#  'Club-moss family': 4,
#  'Loosestrife family': 2,
#  'Dogwood family': 3,
#  'Melastome family': 1,
#  'Cucumber family': 1,
#  'Manatee-grass family': 4,
#  'Grass family': 81,
#  'Sundew family': 2,
#  'Evening Primrose family': 10,
#  'Oleaster family': 1,
#  'Touch-me-not family': 3,
#  'Water Milfoil family': 3,
#  'Beech family': 10,
#  'Spleenwort family': 8,
#  'Tape-grass family': 10,
#  'Hornwort family': 1,
#  'Nettle family': 2,
#  'Borage family': 13,
#  'Spike-moss family': 1,
#  'Mezereum family': 3,
#  'Pondweed family': 7,
#  'Wood-Sorrel family': 3,
#  'Olive family': 5,
#  'Flax family': 2,
#  'Heath family': 17,
#  'Primrose family': 12,
#  'Mustard family': 29,
#  'Pittosporum family': 2,
#  'Bayberry family': 1,
#  'Water-lily family': 2,
#  'Walnut family': 1,
#  'Currant family': 4,
#  'Myrtle family': 2,
#  'Buttercup family': 21,
#  'Geranium family': 10,
#  'Mint family': 45,
#  'Iris family': 1,
#  'Hemp family': 1,
#  'Pink family': 31,
#  'Rush family': 19,
#  'Birch family': 7,
#  'Palm family': 2,
#  'Elm family': 2,
#  'Barberry family': 1,
#  'Pokeweed family': 1,
#  'Holly family': 1,
#  'Plantain family': 25,
#  'Gentian family': 6,
#  'Pea family': 63,
#  'Calamus family': 1,
#  'Cat-tail family': 4,
#  'Yam family': 1,
#  'Bracken Fern family': 1,
#  'Broom-rape family': 10,
#  "Adder's-tongue family": 2,
#  'Flowering Rush family': 1,
#  'Bladderwort family': 2,
#  'Verbena family': 3,
#  'Arrow-grass family': 2,
#  'Sedge family': 41,
#  'Buckbean family': 1,
#  'Dogbane family': 3,
#  'Eel-grass family': 1,
#  'Bellflower family': 9,
#  'Ginseng family': 1,
#  'Soapberry family': 7,
#  'Potato family': 7,
#  'Rose family': 49,
#  'Madder family': 9,
#  'Pine family': 10,
#  'Rock-rose family': 5,
#  'Saxifrage family': 5,
#  'Birthwort family': 1,
#  'Brachythecium moss family': 3,
#  'Sumac family': 2,
#  'Stonecrop family': 8,
#  'Horsetail family': 7,
#  'Mignonette family': 2,
#  'Water-plantain family': 1,
#  'Milkwort family': 2,
#  'Acanthus family': 1}

# %%
plant_dict['Grass family']
# Out:
# 81

# %%
plant_dict2['Grass family']
# Out:
# 81

# %%
# How many beech?
plant_dict['Beech family']
# Out:
# 10

# %% [markdown]
# Are there any missing values?

# %%
plant_dict[None]
# Out:
# 113

# %% [markdown]
# Let's remove these by using a dictionary comprehension:

# %%
plant_dict.items()
# Out:
# dict_items([('Beech family', 10), ('Nettle family', 2), ('Grass family', 81), ('Plantain family', 25), ('Buttercup family', 21), ('Pea family', 63), ('Olive family', 5), ('Rose family', 49), ('Birch family', 7), ('Rush family', 19), ('Buckwheat family', 17), ('Soapberry family', 7), ('Pine family', 10), ('Mint family', 45), ('Madder family', 9), (None, 113), ('Pink family', 31), ('Carrot family', 29), ('Geranium family', 10), ('Aster family', 80), ('Horsetail family', 7), ('Heath family', 17), ('Loosestrife family', 2), ('Bracken Fern family', 1), ('Mustard family', 29), ('Evening Primrose family', 10), ('Willow family', 3), ('Polypody family', 7), ('Dogwood family', 3), ('Honeysuckle family', 9), ('Morning-glory family', 3), ('Iris family', 1), ('Spleenwort family', 8), ('Amaranth family', 6), ('Sedge family', 41), ('Buckthorn family', 3), ('Holly family', 1), ('Potato family', 7), ('Bellflower family', 9), ('Wood-Sorrel family', 3), ('Borage family', 13), ('Bittersweet family', 2), ('Primrose family', 12), ('Poppy family', 7), ('Spurge family', 10), ('Cat-tail family', 4), ('Arum family', 8), ('Water-plantain family', 1), ('Hemp family', 1), ('Sumac family', 2), ('Touch-me-not family', 3), ('Broom-rape family', 10), ('Elm family', 2), ('Flax family', 2), ('Stonecrop family', 8), ('Brachythecium moss family', 3), ('Rock-rose family', 5), ('Mallow family', 5), ('Buckbean family', 1), ('Sundew family', 2), ('Milkwort family', 2), ('Cypress family', 2), ('Myrtle family', 2), ('Verbena family', 3), ('Ginseng family', 1), ('Currant family', 4), ('Sandalwood family', 1), ('Pondweed family', 7), ('Water-lily family', 2), ('Gentian family', 6), ('Yam family', 1), ('Walnut family', 1), ('Boxwood family', 1), ('Dogbane family', 3), ('Mignonette family', 2), ('Bladderwort family', 2), ('Melastome family', 1), ('Saxifrage family', 5), ('Purslane family', 1), ('Grape family', 2), ('Pokeweed family', 1), ('Mezereum family', 3), ('Bayberry family', 1), ('Club-moss family', 4), ('Hornwort family', 1), ('Leadwort family', 1), ('Arrow-grass family', 2), ('Cucumber family', 1), ('Water Milfoil family', 3), ('Tape-grass family', 10), ('Manatee-grass family', 4), ('Eel-grass family', 1), ('Flowering Rush family', 1), ('Lily family', 2), ('Spike-moss family', 1), ('Barberry family', 1), ("Adder's-tongue family", 2), ('Oleaster family', 1), ('Palm family', 2), ('Acanthus family', 1), ('Calamus family', 1), ('Birthwort family', 1), ('Pittosporum family', 2)])

# %%
fams_clean = {fam: num for fam, num in plant_dict.items() if fam != None}

# %%
# Check to make sure
fams_clean.get(None, 0)
# Out:
# 0

# %%
fams_clean[None]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-2b6c2f60da9b> in <module>
# ----> 1 fams_clean[None]
#
# KeyError: None

# %% [markdown]
# Let's also remove the families whose counts are less than ten:

# %%
fams_clean = {fam: num for fam, num in fams_clean.items() if num >= 10}

# %%
fams_clean
# Out:
# {'Beech family': 10,
#  'Grass family': 81,
#  'Plantain family': 25,
#  'Buttercup family': 21,
#  'Pea family': 63,
#  'Rose family': 49,
#  'Rush family': 19,
#  'Buckwheat family': 17,
#  'Pine family': 10,
#  'Mint family': 45,
#  'Pink family': 31,
#  'Carrot family': 29,
#  'Geranium family': 10,
#  'Aster family': 80,
#  'Heath family': 17,
#  'Mustard family': 29,
#  'Evening Primrose family': 10,
#  'Sedge family': 41,
#  'Borage family': 13,
#  'Primrose family': 12,
#  'Spurge family': 10,
#  'Broom-rape family': 10,
#  'Tape-grass family': 10}

# %% [markdown]
# Now we can make a bar chart of the numbers:

# %%
# Need to import matplotlib first
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
fam_names = list(fams_clean.keys())
fam_counts = list(fams_clean.values())

# %%
fam_names
# Out:
# ['Beech family',
#  'Grass family',
#  'Plantain family',
#  'Buttercup family',
#  'Pea family',
#  'Rose family',
#  'Rush family',
#  'Buckwheat family',
#  'Pine family',
#  'Mint family',
#  'Pink family',
#  'Carrot family',
#  'Geranium family',
#  'Aster family',
#  'Heath family',
#  'Mustard family',
#  'Evening Primrose family',
#  'Sedge family',
#  'Borage family',
#  'Primrose family',
#  'Spurge family',
#  'Broom-rape family',
#  'Tape-grass family']

# %%
fig, ax = plt.subplots(figsize=(16, 10))

ax.bar(x=fam_names, height=fam_counts)
ax.set_title('Families by Number', fontsize=30)
plt.xticks(rotation=80, fontsize=20)
plt.yticks(fontsize=20);

# %%
plant_dict[None]
# Out:
# 113

# %%
plant_dict.pop(None)
# Out:
# 113

# %%
plant_dict
# Out:
# defaultdict(int,
#             {'Beech family': 10,
#              'Nettle family': 2,
#              'Grass family': 81,
#              'Plantain family': 25,
#              'Buttercup family': 21,
#              'Pea family': 63,
#              'Olive family': 5,
#              'Rose family': 49,
#              'Birch family': 7,
#              'Rush family': 19,
#              'Buckwheat family': 17,
#              'Soapberry family': 7,
#              'Pine family': 10,
#              'Mint family': 45,
#              'Madder family': 9,
#              'Pink family': 31,
#              'Carrot family': 29,
#              'Geranium family': 10,
#              'Aster family': 80,
#              'Horsetail family': 7,
#              'Heath family': 17,
#              'Loosestrife family': 2,
#              'Bracken Fern family': 1,
#              'Mustard family': 29,
#              'Evening Primrose family': 10,
#              'Willow family': 3,
#              'Polypody family': 7,
#              'Dogwood family': 3,
#              'Honeysuckle family': 9,
#              'Morning-glory family': 3,
#              'Iris family': 1,
#              'Spleenwort family': 8,
#              'Amaranth family': 6,
#              'Sedge family': 41,
#              'Buckthorn family': 3,
#              'Holly family': 1,
#              'Potato family': 7,
#              'Bellflower family': 9,
#              'Wood-Sorrel family': 3,
#              'Borage family': 13,
#              'Bittersweet family': 2,
#              'Primrose family': 12,
#              'Poppy family': 7,
#              'Spurge family': 10,
#              'Cat-tail family': 4,
#              'Arum family': 8,
#              'Water-plantain family': 1,
#              'Hemp family': 1,
#              'Sumac family': 2,
#              'Touch-me-not family': 3,
#              'Broom-rape family': 10,
#              'Elm family': 2,
#              'Flax family': 2,
#              'Stonecrop family': 8,
#              'Brachythecium moss family': 3,
#              'Rock-rose family': 5,
#              'Mallow family': 5,
#              'Buckbean family': 1,
#              'Sundew family': 2,
#              'Milkwort family': 2,
#              'Cypress family': 2,
#              'Myrtle family': 2,
#              'Verbena family': 3,
#              'Ginseng family': 1,
#              'Currant family': 4,
#              'Sandalwood family': 1,
#              'Pondweed family': 7,
#              'Water-lily family': 2,
#              'Gentian family': 6,
#              'Yam family': 1,
#              'Walnut family': 1,
#              'Boxwood family': 1,
#              'Dogbane family': 3,
#              'Mignonette family': 2,
#              'Bladderwort family': 2,
#              'Melastome family': 1,
#              'Saxifrage family': 5,
#              'Purslane family': 1,
#              'Grape family': 2,
#              'Pokeweed family': 1,
#              'Mezereum family': 3,
#              'Bayberry family': 1,
#              'Club-moss family': 4,
#              'Hornwort family': 1,
#              'Leadwort family': 1,
#              'Arrow-grass family': 2,
#              'Cucumber family': 1,
#              'Water Milfoil family': 3,
#              'Tape-grass family': 10,
#              'Manatee-grass family': 4,
#              'Eel-grass family': 1,
#              'Flowering Rush family': 1,
#              'Lily family': 2,
#              'Spike-moss family': 1,
#              'Barberry family': 1,
#              "Adder's-tongue family": 2,
#              'Oleaster family': 1,
#              'Palm family': 2,
#              'Acanthus family': 1,
#              'Calamus family': 1,
#              'Birthwort family': 1,
#              'Pittosporum family': 2})

# %%
plant_dict[None]
# Out:
# 0

# %%
plant_dict.get(None)
# Out:
# 0

# %% [markdown]
# ## Synonyms

# %%
plants[0]
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %% [markdown]
# Suppose we wanted to know how many synonymous names were listed for each plant. We could grab this number with a list comprehension:

# %%
num_syn = [len(plant['synonyms']) for plant in plants]

# %%
max(num_syn)
# Out:
# 342

# %%
min(num_syn)
# Out:
# 0

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.scatter(range(1000), num_syn, alpha=0.5)
ax.set_title('Numbers of Synonyms');

# %% [markdown]
# ## Exercise

# %% [markdown]
# One plant has nearly 350 synonynms! What plant is this?

# %%
[plant for plant in plants if len(plant['synonyms']) == max(num_syn)][0]
# Out:
# {'id': 182597,
#  'common_name': 'Irish potato',
#  'slug': 'solanum-tuberosum',
#  'scientific_name': 'Solanum tuberosum',
#  'year': 1753,
#  'bibliography': 'Sp. Pl.: 185 (1753)',
#  'author': 'L.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Potato family',
#  'genus_id': 4329,
#  'image_url': 'https://bs.plantnet.org/image/o/95a0197b33f8efe2ea7a0d25f84476415779a4b5',
#  'synonyms': ['Solanum tuberosum subsp. andigenum',
#   'Solanum tuberosum f. chiar-pala',
#   'Solanum tuberosum var. strobilinum',
#   'Solanum tuberosum var. murukewillu',
#   'Solanum stenotomum var. peruanum',
#   'Larnax sylvarum subsp. novogranatensis',
#   'Solanum andigenum f. tiahuanacense',
#   'Solanum andigenum f. pallidum',
#   'Solanum tuberosum var. batatinum',
#   'Solanum tuberosum var. rugiorum',
#   'Solanum andigenum f. ovatibaccatum',
#   'Solanum tuberosum f. contortum',
#   'Solanum andigenum f. llutuc-runtum',
#   'Solanum andigenum var. mexicanum',
#   'Solanum tuberosum var. album',
#   'Solanum andigenum f. ancacc-maquin',
#   'Solanum andigenum f. conicicolumnatum',
#   'Solanum andigenum f. dilatatum',
#   'Parmentiera edulis',
#   'Solanum andigenum subsp. australiperuvianum',
#   'Solanum tuberosum f. thalassinum',
#   'Solanum aracatscha',
#   'Solanum tuberosum var. melanoceras',
#   'Solanum stenotomum var. cyaneum',
#   'Solanum andigenum var. quechuanum',
#   'Solanum tuberosum var. sesquimensale',
#   'Solanum tuberosum f. viride',
#   'Solanum tuberosum f. laram-lelekkoya',
#   'Solanum andigenum f. alccai-huarmi',
#   'Solanum stenotomum f. catari-papa',
#   'Solanum andigenum f. caesium',
#   'Solanum tuberosum f. ovatum',
#   'Solanum tuberosum f. sebastianum',
#   "Solanum phureja var. janck'o-phureja",
#   'Solanum chilotanum var. angustifurcatum',
#   'Solanum tuberosum var. bertuchii',
#   'Solanum chilotanum var. talukdarii',
#   'Solanum phureja',
#   'Solanum leptostigma',
#   'Solanum sendigena',
#   'Solanum andigenum f. ccompis',
#   'Solanum diemii',
#   'Solanum tuberosum f. milagro',
#   'Solanum stenotomum var. megalocalyx',
#   'Solanum tenuifilamentum',
#   'Solanum tuberosum f. coraila',
#   'Solanum tuberosum var. elegans',
#   'Solanum tuberosum var. norfolcicum',
#   'Lycopersicon tuberosum',
#   'Solanum stenotomum f. ccami',
#   'Solanum tuberosum var. platyceras',
#   'Solanum tuberosum var. hispanicum',
#   'Solanum tuberosum var. yutuense',
#   'Solanum andigenum var. stenophyllum',
#   'Solanum rybinii var. popayanum',
#   'Solanum chaucha var. khoyllu',
#   "Solanum tuberosum f. wila-k'oyu",
#   'Solanum stenotomum f. koso-nahui',
#   'Solanum tuberosum f. huichinkka',
#   'Solanum andigenum f. ppacc-nacha',
#   'Solanum stenotomum var. puca-lunca',
#   'Solanum andigenum f. bifidum',
#   'Solanum tuberosum var. taraco',
#   'Solanum oceanicum',
#   'Solanum tuberosum f. latum',
#   'Solanum andigenum f. cryptostylum',
#   'Solanum phureja f. sayhuanimayo',
#   'Solanum tuberosum var. praecox',
#   'Solanum aracc-papa',
#   'Solanum stenotomum f. tiele',
#   'Solanum tuberosum var. hassicum',
#   'Solanum tuberosum var. multibaccatum',
#   'Solanum andigenum var. herrerae',
#   'Solanum andigenum var. aymaranum',
#   'Solanum phureja var. sanguineum',
#   'Solanum stenotomum f. chincherae',
#   'Solanum goniocalyx var. caeruleum',
#   'Solanum stenotomum f. roseum',
#   'Solanum sinense',
#   'Solanum andigenum f. chalcoense',
#   'Solanum andigenum f. chimaco',
#   'Solanum tuberosum var. menapianum',
#   'Solanum tuberosum var. merceri',
#   'Solanum tuberosum f. enode',
#   'Solanum stenotomum f. chojllu',
#   'Solanum tuberosum var. bufoninum',
#   'Solanum tuberosum var. corsicanum',
#   'Solanum chaucha var. puca-suitu',
#   'Solanum andigenum subsp. tarmense',
#   'Solanum stenotomum f. eucaliptae',
#   'Solanum tuberosum f. isla-imilla',
#   'Solanum tuberosum f. wila-monda',
#   'Solanum stenotomum var. putis',
#   'Solanum andigenum f. pomacanchicum',
#   'Solanum tuberosum f. chiar-lelekkoya',
#   'Solanum riobambense',
#   'Solanum andigenum f. arcuatum',
#   'Solanum tuberosum f. elongatum',
#   'Solanum tuberosum var. conocarpum',
#   'Solanum kesselbrenneri',
#   'Solanum phureja f. timusi',
#   'Solanum andigenum subsp. ecuatorianum',
#   'Solanum tuberosum var. schnittspahnii',
#   'Solanum tuberosum var. aethiopicum',
#   'Solanum andigenum var. bolivianum',
#   'Solanum andigenum var. huairuru',
#   'Solanum maglia var. chubutense',
#   'Solanum stenotomum f. alcay-imilla',
#   'Solanum tuberosum f. overita',
#   'Solanum andigenum',
#   'Solanum tuberosum var. malcachu',
#   'Solanum andigenum var. colombianum',
#   'Solanum tuberosum f. wila-imilla',
#   'Solanum molinae',
#   'Solanum andigenum f. incrassatum',
#   'Solanum stenotomum var. huicu',
#   'Solanum subandigenum',
#   'Solanum tuberosum var. crassipedicellatum',
#   'Solanum tuberosum var. ulmense',
#   'Solanum tuberosum f. camota',
#   'Solanum tuberosum var. villaroella',
#   'Solanum stenotomum f. cohuasa',
#   'Solanum phureja var. caeruleum',
#   'Solanum andigenum var. sihuanum',
#   'Solanum rybinii var. boyacense',
#   'Solanum tuberosum var. tener',
#   'Solanum caniarense',
#   'Solanum chaucha var. surimana',
#   'Solanum zykinii',
#   'Solanum stenotomum f. pitoca',
#   "Solanum tuberosum f. jancck'o-kkoyllu",
#   'Solanum stenotomum f. kehuillo',
#   'Solanum andigenum f. microstigma',
#   'Solanum tascalense',
#   'Solanum cayeuxi',
#   'Solanum tuberosum f. chojo-sajama',
#   'Solanum andigenum f. pacus',
#   'Solanum tuberosum var. rockii',
#   'Solanum tuberosum var. rubrisuturatum',
#   'Solanum phureja f. viuda',
#   'Solanum tuberosum var. guaytecarum',
#   'Solanum stenotomum f. yuracc',
#   'Solanum tuberosum var. putscheanum',
#   'Solanum andigenum subsp. colombianum',
#   'Solanum andigenum var. grauense',
#   'Solanum tuberosum var. cordiforme',
#   'Solanum tarmense',
#   'Solanum dubium',
#   'Solanum goniocalyx',
#   'Solanum cultum',
#   'Solanum andigenum f. basiscopum',
#   'Solanum stenotomum f. yana-cculi',
#   'Solanum tuberosum var. lelekkoya',
#   'Solanum mamilliferum',
#   'Solanum tuberosum f. pulo',
#   'Solanum stenotomum f. phitu-huayacas',
#   'Solanum andigenum var. cuzcoense',
#   "Solanum tuberosum f. janck'o-chockella",
#   'Solanum tuberosum f. yurac-taraco',
#   'Solanum andigenum f. cevallosii',
#   'Solanum chocclo',
#   'Solanum stenotomum var. keccrana',
#   'Solanum tuberosum var. cultum',
#   'Solanum tuberosum var. rossicum',
#   'Solanum tuberosum f. chaped',
#   'Solanum stenotomum f. cuchipacon',
#   'Solanum estradea',
#   'Solanum tuberosum var. reniforme',
#   'Solanum tuberosum var. pecorum',
#   'Solanum stenotomum f. canastilla',
#   'Solanum andigenum var. socco-huaccoto',
#   'Solanum rybinii var. pastoense',
#   'Solanum stenotomum f. canasense',
#   'Solanum tuberosum subsp. chiloense',
#   'Solanum tuberosum var. runa',
#   'Solanum tuberosum f. huaca-zapato',
#   'Solanum andigenum f. lapazense',
#   'Solanum andigenum f. tolucanum',
#   'Solanum cardenasii',
#   'Solanum ochoanum',
#   'Solanum tuberosum f. conicum',
#   'Solanum tuberosum var. praedicandum',
#   'Solanum paramoense',
#   'Solanum tuberosum var. borsdorfianum',
#   'Solanum chilotanum',
#   'Solanum andigenum var. hederiforme',
#   'Solanum andigenum f. lecke-umo',
#   'Solanum andigenum subsp. aya-papa',
#   'Solanum stenotomum f. pallidum',
#   'Solanum andigenum f. nodosum',
#   'Solanum tuberosum var. vulgare',
#   "Solanum tuberosum f. janck'o-pala",
#   'Solanum andigenum var. ccusi',
#   'Solanum stenotomum var. chapina',
#   'Solanum tuberosum f. crassifilamentum',
#   'Solanum tuberosum var. peruvianum',
#   'Solanum tuberosum f. montticum',
#   'Solanum andigenum f. caiceda',
#   'Solanum tuberosum var. chiloense',
#   'Solanum tuberosum var. fragariinum',
#   'Solanum tuberosum var. holsaticum',
#   'Solanum tuberosum var. helenanum',
#   'Solanum tuberosum f. brachykalukon',
#   'Solanum tuberosum var. sabinei',
#   'Solanum andigenum var. platyantherum',
#   'Solanum rybinii',
#   'Solanum stenotomum f. orcco-amajaya',
#   'Solanum tuberosum f. alkka-imilla',
#   'Solanum tuberosum var. salamandrinum',
#   'Solanum andigenum f. tocanum',
#   'Solanum tuberosum f. sani-imilla',
#   'Solanum andigenum f. guatemalense',
#   'Solanum andigenum f. lanciacuminatum',
#   'Solanum hygrothermicum',
#   'Solanum tuberosum var. xanthoceras',
#   'Solanum yabari var. cuzcoense',
#   'Solanum chaucha f. purpureum',
#   'Solanum tuberosum var. elongatum',
#   'Solanum ascasabii',
#   'Solanum chiloense',
#   'Solanum sanmartinense',
#   'Solanum stenotomum f. kamara',
#   'Solanum andigenum var. latius',
#   'Solanum stenotomum f. chilcas',
#   'Solanum tuberosum f. kunurana',
#   'Solanum tuberosum f. infectum',
#   'Solanum phureja subsp. estradae',
#   'Solanum andigenum var. ckello-huaccoto',
#   'Solanum andigenum f. sunchchu',
#   'Solanum tuberosum var. nucinum',
#   'Solanum tuberosum var. cepinum',
#   'Solanum tuberosum f. oculosum',
#   'Solanum tuberosum var. chilotanum',
#   'Solanum tuberosum f. brevipapillosum',
#   'Solanum macmillanii',
#   'Solanum parmentieri',
#   'Solanum rybinii var. bogotense',
#   'Solanum tuberosum var. brachyceras',
#   'Solanum stenotomum f. phinu',
#   'Solanum sylvestre',
#   'Solanum tuberosum f. tinguipaya',
#   'Solanum andigenum subsp. argentinicum',
#   'Solanum andigenum f. coeruleum',
#   'Solanum tuberosum f. alkka-silla',
#   'Solanum tuberosum var. sicha',
#   'Solanum chilotanum f. parvicorollatum',
#   'Solanum andigenum f. tenue',
#   'Solanum tuberosum var. drakeanum',
#   'Solanum tuberosum var. recurvatum',
#   'Solanum tuberosum f. acuminatum',
#   'Solanum andigenum f. huaca-layra',
#   'Solanum yabari',
#   'Solanum boyacense',
#   'Solanum tuberosum f. araucanum',
#   'Solanum phureja subsp. hygrothermicum',
#   'Solanum tuberosum var. leonhardianum',
#   'Solanum tuberosum var. nobile',
#   'Solanum stenotomum f. puca',
#   'Solanum phureja var. rubroroseum',
#   'Solanum andigenum var. digitotuberosum',
#   'Battata tuberosa',
#   'Solanum stenotomum f. negrum',
#   'Solanum andigenum f. lisarassa',
#   'Solanum andigenum var. longibaccatum',
#   'Solanum tuberosum f. pichuna',
#   'Solanum stenotomum',
#   'Solanum stenotomum f. piticana',
#   'Solanum andigenum f. huaman-uma',
#   'Solanum andigenum var. brevicalyx',
#   'Solanum stenotomum var. pitiquilla',
#   'Solanum phureja var. flavum',
#   'Solanum tuberosum var. anglicum',
#   'Solanum tuberosum f. indianum',
#   'Solanum tuberosum var. julianum',
#   'Solanum tuberosum var. kaunitzii',
#   'Solanum coeruleiflorum',
#   'Solanum herrerae',
#   'Solanum utile',
#   'Solanum tuberosum var. versicolor',
#   'Solanum chaucha var. ckati',
#   'Solanum stenotomum f. huamanpa-uman',
#   'Solanum apurimacense',
#   'Solanum tuberosum f. wila-pala',
#   'Solanum esculentum',
#   'Solanum chilotanum f. magnicorollatum',
#   'Solanum tuberosum var. sipancachi',
#   'Solanum sabinei',
#   'Solanum tuberosum f. amajaya',
#   'Solanum andigenum f. huallata',
#   'Solanum andigenum f. ppaqui',
#   'Solanum chaucha',
#   'Solanum phureja var. macmillanii',
#   'Solanum andigenum f. globosum',
#   'Solanum tuberosum var. saccharatum',
#   'Solanum tuberosum f. pillicuma',
#   'Solanum tuberosum var. erythroceras',
#   'Solanum tuberosum var. vuchefeldicum',
#   'Solanum churuspi',
#   'Solanum phureja f. orbiculatum',
#   'Solanum andigenum var. imilla',
#   'Solanum stenotomum f. cochicallo',
#   'Solanum andigenum f. lilacinoflorum',
#   'Solanum erlansonii',
#   'Solanum andigenum f. magnicorollatum',
#   'Solanum stenotomum var. ccami',
#   'Solanum andigenum var. carhua',
#   'Solanum andigenum f. ccompetillo',
#   'Solanum tuberosum var. alaudinum',
#   'Solanum tuberosum var. palatinatum',
#   'Solanum tuberosum f. mahuinhue',
#   'Solanum stenotomum var. poccoya',
#   'Solanum tuberosum var. cucumerinum',
#   'Solanum phureja var. pujeri',
#   'Solanum tuberosum var. laurentianum',
#   'Solanum tuberosum var. brevipilosum',
#   'Solanum stenotomum subsp. goniocalyx',
#   'Solanum chaucha var. ccoe-sulla',
#   'Solanum stenotomum f. huanuchi',
#   'Solanum andigenum subsp. bolivianum',
#   'Solanum stenotomum f. kantillero',
#   'Solanum tuberosum f. wila-huaycku',
#   'Solanum tuberosum f. azul-runa',
#   'Solanum chariense',
#   'Solanum andigenum f. uncuna',
#   'Solanum parvicorollatum',
#   'Solanum phureja var. erlansonii',
#   'Solanum tuberosum f. surico',
#   'Solanum yabari var. pepino',
#   'Solanum tuberosum var. chubutense',
#   'Solanum chaucha f. roseum',
#   'Solanum tuberosum var. tinctorium',
#   'Solanum andigenum f. discolor',
#   'Solanum tuberosum f. auriculatum',
#   'Solanum tuberosum f. tenuipedicellatum',
#   'Solanum andigenum subsp. centraliperuvianum',
#   'Solanum tuberosum var. californicum',
#   'Solanum maglia var. guaytecarum',
#   'Solanum stenotomum f. huallata-chinchi',
#   'Solanum andigenum f. elongatipedicellatum',
#   'Solanum andigenum var. juninum',
#   'Solanum tuberosum f. nigrum',
#   'Solanum tuberosum var. polemoniifolium'],
#  'genus': 'Solanum',
#  'family': 'Solanaceae',
#  'links': {'self': '/api/v1/species/solanum-tuberosum',
#   'plant': '/api/v1/plants/solanum-tuberosum',
#   'genus': '/api/v1/genus/solanum'}}

# %%
[plant for plant in plants if len(plant['synonyms']) > 150]
# Out:
# {'id': 182597,
#  'common_name': 'Irish potato',
#  'slug': 'solanum-tuberosum',
#  'scientific_name': 'Solanum tuberosum',
#  'year': 1753,
#  'bibliography': 'Sp. Pl.: 185 (1753)',
#  'author': 'L.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Potato family',
#  'genus_id': 4329,
#  'image_url': 'https://bs.plantnet.org/image/o/95a0197b33f8efe2ea7a0d25f84476415779a4b5',
#  'synonyms': ['Solanum tuberosum subsp. andigenum',
#   'Solanum tuberosum f. chiar-pala',
#   'Solanum tuberosum var. strobilinum',
#   'Solanum tuberosum var. murukewillu',
#   'Solanum stenotomum var. peruanum',
#   'Larnax sylvarum subsp. novogranatensis',
#   'Solanum andigenum f. tiahuanacense',
#   'Solanum andigenum f. pallidum',
#   'Solanum tuberosum var. batatinum',
#   'Solanum tuberosum var. rugiorum',
#   'Solanum andigenum f. ovatibaccatum',
#   'Solanum tuberosum f. contortum',
#   'Solanum andigenum f. llutuc-runtum',
#   'Solanum andigenum var. mexicanum',
#   'Solanum tuberosum var. album',
#   'Solanum andigenum f. ancacc-maquin',
#   'Solanum andigenum f. conicicolumnatum',
#   'Solanum andigenum f. dilatatum',
#   'Parmentiera edulis',
#   'Solanum andigenum subsp. australiperuvianum',
#   'Solanum tuberosum f. thalassinum',
#   'Solanum aracatscha',
#   'Solanum tuberosum var. melanoceras',
#   'Solanum stenotomum var. cyaneum',
#   'Solanum andigenum var. quechuanum',
#   'Solanum tuberosum var. sesquimensale',
#   'Solanum tuberosum f. viride',
#   'Solanum tuberosum f. laram-lelekkoya',
#   'Solanum andigenum f. alccai-huarmi',
#   'Solanum stenotomum f. catari-papa',
#   'Solanum andigenum f. caesium',
#   'Solanum tuberosum f. ovatum',
#   'Solanum tuberosum f. sebastianum',
#   "Solanum phureja var. janck'o-phureja",
#   'Solanum chilotanum var. angustifurcatum',
#   'Solanum tuberosum var. bertuchii',
#   'Solanum chilotanum var. talukdarii',
#   'Solanum phureja',
#   'Solanum leptostigma',
#   'Solanum sendigena',
#   'Solanum andigenum f. ccompis',
#   'Solanum diemii',
#   'Solanum tuberosum f. milagro',
#   'Solanum stenotomum var. megalocalyx',
#   'Solanum tenuifilamentum',
#   'Solanum tuberosum f. coraila',
#   'Solanum tuberosum var. elegans',
#   'Solanum tuberosum var. norfolcicum',
#   'Lycopersicon tuberosum',
#   'Solanum stenotomum f. ccami',
#   'Solanum tuberosum var. platyceras',
#   'Solanum tuberosum var. hispanicum',
#   'Solanum tuberosum var. yutuense',
#   'Solanum andigenum var. stenophyllum',
#   'Solanum rybinii var. popayanum',
#   'Solanum chaucha var. khoyllu',
#   "Solanum tuberosum f. wila-k'oyu",
#   'Solanum stenotomum f. koso-nahui',
#   'Solanum tuberosum f. huichinkka',
#   'Solanum andigenum f. ppacc-nacha',
#   'Solanum stenotomum var. puca-lunca',
#   'Solanum andigenum f. bifidum',
#   'Solanum tuberosum var. taraco',
#   'Solanum oceanicum',
#   'Solanum tuberosum f. latum',
#   'Solanum andigenum f. cryptostylum',
#   'Solanum phureja f. sayhuanimayo',
#   'Solanum tuberosum var. praecox',
#   'Solanum aracc-papa',
#   'Solanum stenotomum f. tiele',
#   'Solanum tuberosum var. hassicum',
#   'Solanum tuberosum var. multibaccatum',
#   'Solanum andigenum var. herrerae',
#   'Solanum andigenum var. aymaranum',
#   'Solanum phureja var. sanguineum',
#   'Solanum stenotomum f. chincherae',
#   'Solanum goniocalyx var. caeruleum',
#   'Solanum stenotomum f. roseum',
#   'Solanum sinense',
#   'Solanum andigenum f. chalcoense',
#   'Solanum andigenum f. chimaco',
#   'Solanum tuberosum var. menapianum',
#   'Solanum tuberosum var. merceri',
#   'Solanum tuberosum f. enode',
#   'Solanum stenotomum f. chojllu',
#   'Solanum tuberosum var. bufoninum',
#   'Solanum tuberosum var. corsicanum',
#   'Solanum chaucha var. puca-suitu',
#   'Solanum andigenum subsp. tarmense',
#   'Solanum stenotomum f. eucaliptae',
#   'Solanum tuberosum f. isla-imilla',
#   'Solanum tuberosum f. wila-monda',
#   'Solanum stenotomum var. putis',
#   'Solanum andigenum f. pomacanchicum',
#   'Solanum tuberosum f. chiar-lelekkoya',
#   'Solanum riobambense',
#   'Solanum andigenum f. arcuatum',
#   'Solanum tuberosum f. elongatum',
#   'Solanum tuberosum var. conocarpum',
#   'Solanum kesselbrenneri',
#   'Solanum phureja f. timusi',
#   'Solanum andigenum subsp. ecuatorianum',
#   'Solanum tuberosum var. schnittspahnii',
#   'Solanum tuberosum var. aethiopicum',
#   'Solanum andigenum var. bolivianum',
#   'Solanum andigenum var. huairuru',
#   'Solanum maglia var. chubutense',
#   'Solanum stenotomum f. alcay-imilla',
#   'Solanum tuberosum f. overita',
#   'Solanum andigenum',
#   'Solanum tuberosum var. malcachu',
#   'Solanum andigenum var. colombianum',
#   'Solanum tuberosum f. wila-imilla',
#   'Solanum molinae',
#   'Solanum andigenum f. incrassatum',
#   'Solanum stenotomum var. huicu',
#   'Solanum subandigenum',
#   'Solanum tuberosum var. crassipedicellatum',
#   'Solanum tuberosum var. ulmense',
#   'Solanum tuberosum f. camota',
#   'Solanum tuberosum var. villaroella',
#   'Solanum stenotomum f. cohuasa',
#   'Solanum phureja var. caeruleum',
#   'Solanum andigenum var. sihuanum',
#   'Solanum rybinii var. boyacense',
#   'Solanum tuberosum var. tener',
#   'Solanum caniarense',
#   'Solanum chaucha var. surimana',
#   'Solanum zykinii',
#   'Solanum stenotomum f. pitoca',
#   "Solanum tuberosum f. jancck'o-kkoyllu",
#   'Solanum stenotomum f. kehuillo',
#   'Solanum andigenum f. microstigma',
#   'Solanum tascalense',
#   'Solanum cayeuxi',
#   'Solanum tuberosum f. chojo-sajama',
#   'Solanum andigenum f. pacus',
#   'Solanum tuberosum var. rockii',
#   'Solanum tuberosum var. rubrisuturatum',
#   'Solanum phureja f. viuda',
#   'Solanum tuberosum var. guaytecarum',
#   'Solanum stenotomum f. yuracc',
#   'Solanum tuberosum var. putscheanum',
#   'Solanum andigenum subsp. colombianum',
#   'Solanum andigenum var. grauense',
#   'Solanum tuberosum var. cordiforme',
#   'Solanum tarmense',
#   'Solanum dubium',
#   'Solanum goniocalyx',
#   'Solanum cultum',
#   'Solanum andigenum f. basiscopum',
#   'Solanum stenotomum f. yana-cculi',
#   'Solanum tuberosum var. lelekkoya',
#   'Solanum mamilliferum',
#   'Solanum tuberosum f. pulo',
#   'Solanum stenotomum f. phitu-huayacas',
#   'Solanum andigenum var. cuzcoense',
#   "Solanum tuberosum f. janck'o-chockella",
#   'Solanum tuberosum f. yurac-taraco',
#   'Solanum andigenum f. cevallosii',
#   'Solanum chocclo',
#   'Solanum stenotomum var. keccrana',
#   'Solanum tuberosum var. cultum',
#   'Solanum tuberosum var. rossicum',
#   'Solanum tuberosum f. chaped',
#   'Solanum stenotomum f. cuchipacon',
#   'Solanum estradea',
#   'Solanum tuberosum var. reniforme',
#   'Solanum tuberosum var. pecorum',
#   'Solanum stenotomum f. canastilla',
#   'Solanum andigenum var. socco-huaccoto',
#   'Solanum rybinii var. pastoense',
#   'Solanum stenotomum f. canasense',
#   'Solanum tuberosum subsp. chiloense',
#   'Solanum tuberosum var. runa',
#   'Solanum tuberosum f. huaca-zapato',
#   'Solanum andigenum f. lapazense',
#   'Solanum andigenum f. tolucanum',
#   'Solanum cardenasii',
#   'Solanum ochoanum',
#   'Solanum tuberosum f. conicum',
#   'Solanum tuberosum var. praedicandum',
#   'Solanum paramoense',
#   'Solanum tuberosum var. borsdorfianum',
#   'Solanum chilotanum',
#   'Solanum andigenum var. hederiforme',
#   'Solanum andigenum f. lecke-umo',
#   'Solanum andigenum subsp. aya-papa',
#   'Solanum stenotomum f. pallidum',
#   'Solanum andigenum f. nodosum',
#   'Solanum tuberosum var. vulgare',
#   "Solanum tuberosum f. janck'o-pala",
#   'Solanum andigenum var. ccusi',
#   'Solanum stenotomum var. chapina',
#   'Solanum tuberosum f. crassifilamentum',
#   'Solanum tuberosum var. peruvianum',
#   'Solanum tuberosum f. montticum',
#   'Solanum andigenum f. caiceda',
#   'Solanum tuberosum var. chiloense',
#   'Solanum tuberosum var. fragariinum',
#   'Solanum tuberosum var. holsaticum',
#   'Solanum tuberosum var. helenanum',
#   'Solanum tuberosum f. brachykalukon',
#   'Solanum tuberosum var. sabinei',
#   'Solanum andigenum var. platyantherum',
#   'Solanum rybinii',
#   'Solanum stenotomum f. orcco-amajaya',
#   'Solanum tuberosum f. alkka-imilla',
#   'Solanum tuberosum var. salamandrinum',
#   'Solanum andigenum f. tocanum',
#   'Solanum tuberosum f. sani-imilla',
#   'Solanum andigenum f. guatemalense',
#   'Solanum andigenum f. lanciacuminatum',
#   'Solanum hygrothermicum',
#   'Solanum tuberosum var. xanthoceras',
#   'Solanum yabari var. cuzcoense',
#   'Solanum chaucha f. purpureum',
#   'Solanum tuberosum var. elongatum',
#   'Solanum ascasabii',
#   'Solanum chiloense',
#   'Solanum sanmartinense',
#   'Solanum stenotomum f. kamara',
#   'Solanum andigenum var. latius',
#   'Solanum stenotomum f. chilcas',
#   'Solanum tuberosum f. kunurana',
#   'Solanum tuberosum f. infectum',
#   'Solanum phureja subsp. estradae',
#   'Solanum andigenum var. ckello-huaccoto',
#   'Solanum andigenum f. sunchchu',
#   'Solanum tuberosum var. nucinum',
#   'Solanum tuberosum var. cepinum',
#   'Solanum tuberosum f. oculosum',
#   'Solanum tuberosum var. chilotanum',
#   'Solanum tuberosum f. brevipapillosum',
#   'Solanum macmillanii',
#   'Solanum parmentieri',
#   'Solanum rybinii var. bogotense',
#   'Solanum tuberosum var. brachyceras',
#   'Solanum stenotomum f. phinu',
#   'Solanum sylvestre',
#   'Solanum tuberosum f. tinguipaya',
#   'Solanum andigenum subsp. argentinicum',
#   'Solanum andigenum f. coeruleum',
#   'Solanum tuberosum f. alkka-silla',
#   'Solanum tuberosum var. sicha',
#   'Solanum chilotanum f. parvicorollatum',
#   'Solanum andigenum f. tenue',
#   'Solanum tuberosum var. drakeanum',
#   'Solanum tuberosum var. recurvatum',
#   'Solanum tuberosum f. acuminatum',
#   'Solanum andigenum f. huaca-layra',
#   'Solanum yabari',
#   'Solanum boyacense',
#   'Solanum tuberosum f. araucanum',
#   'Solanum phureja subsp. hygrothermicum',
#   'Solanum tuberosum var. leonhardianum',
#   'Solanum tuberosum var. nobile',
#   'Solanum stenotomum f. puca',
#   'Solanum phureja var. rubroroseum',
#   'Solanum andigenum var. digitotuberosum',
#   'Battata tuberosa',
#   'Solanum stenotomum f. negrum',
#   'Solanum andigenum f. lisarassa',
#   'Solanum andigenum var. longibaccatum',
#   'Solanum tuberosum f. pichuna',
#   'Solanum stenotomum',
#   'Solanum stenotomum f. piticana',
#   'Solanum andigenum f. huaman-uma',
#   'Solanum andigenum var. brevicalyx',
#   'Solanum stenotomum var. pitiquilla',
#   'Solanum phureja var. flavum',
#   'Solanum tuberosum var. anglicum',
#   'Solanum tuberosum f. indianum',
#   'Solanum tuberosum var. julianum',
#   'Solanum tuberosum var. kaunitzii',
#   'Solanum coeruleiflorum',
#   'Solanum herrerae',
#   'Solanum utile',
#   'Solanum tuberosum var. versicolor',
#   'Solanum chaucha var. ckati',
#   'Solanum stenotomum f. huamanpa-uman',
#   'Solanum apurimacense',
#   'Solanum tuberosum f. wila-pala',
#   'Solanum esculentum',
#   'Solanum chilotanum f. magnicorollatum',
#   'Solanum tuberosum var. sipancachi',
#   'Solanum sabinei',
#   'Solanum tuberosum f. amajaya',
#   'Solanum andigenum f. huallata',
#   'Solanum andigenum f. ppaqui',
#   'Solanum chaucha',
#   'Solanum phureja var. macmillanii',
#   'Solanum andigenum f. globosum',
#   'Solanum tuberosum var. saccharatum',
#   'Solanum tuberosum f. pillicuma',
#   'Solanum tuberosum var. erythroceras',
#   'Solanum tuberosum var. vuchefeldicum',
#   'Solanum churuspi',
#   'Solanum phureja f. orbiculatum',
#   'Solanum andigenum var. imilla',
#   'Solanum stenotomum f. cochicallo',
#   'Solanum andigenum f. lilacinoflorum',
#   'Solanum erlansonii',
#   'Solanum andigenum f. magnicorollatum',
#   'Solanum stenotomum var. ccami',
#   'Solanum andigenum var. carhua',
#   'Solanum andigenum f. ccompetillo',
#   'Solanum tuberosum var. alaudinum',
#   'Solanum tuberosum var. palatinatum',
#   'Solanum tuberosum f. mahuinhue',
#   'Solanum stenotomum var. poccoya',
#   'Solanum tuberosum var. cucumerinum',
#   'Solanum phureja var. pujeri',
#   'Solanum tuberosum var. laurentianum',
#   'Solanum tuberosum var. brevipilosum',
#   'Solanum stenotomum subsp. goniocalyx',
#   'Solanum chaucha var. ccoe-sulla',
#   'Solanum stenotomum f. huanuchi',
#   'Solanum andigenum subsp. bolivianum',
#   'Solanum stenotomum f. kantillero',
#   'Solanum tuberosum f. wila-huaycku',
#   'Solanum tuberosum f. azul-runa',
#   'Solanum chariense',
#   'Solanum andigenum f. uncuna',
#   'Solanum parvicorollatum',
#   'Solanum phureja var. erlansonii',
#   'Solanum tuberosum f. surico',
#   'Solanum yabari var. pepino',
#   'Solanum tuberosum var. chubutense',
#   'Solanum chaucha f. roseum',
#   'Solanum tuberosum var. tinctorium',
#   'Solanum andigenum f. discolor',
#   'Solanum tuberosum f. auriculatum',
#   'Solanum tuberosum f. tenuipedicellatum',
#   'Solanum andigenum subsp. centraliperuvianum',
#   'Solanum tuberosum var. californicum',
#   'Solanum maglia var. guaytecarum',
#   'Solanum stenotomum f. huallata-chinchi',
#   'Solanum andigenum f. elongatipedicellatum',
#   'Solanum andigenum var. juninum',
#   'Solanum tuberosum f. nigrum',
#   'Solanum tuberosum var. polemoniifolium'],
#  'genus': 'Solanum',
#  'family': 'Solanaceae',
#  'links': {'self': '/api/v1/species/solanum-tuberosum',
#   'plant': '/api/v1/plants/solanum-tuberosum',
#   'genus': '/api/v1/genus/solanum'}}

# %%
len([plant for plant in plants if len(plant['synonyms']) > 150])
# Out:
# 6

# %% [markdown]
# <details>
#     <summary>
#         Answer
#     </summary>
#
# ```python
# [plant for plant in plants if len(plant['synonyms']) > 300]
# ```
# </details>

# %% [markdown]
# ## Bibliography

# %%
biblios = [plant['bibliography'] for plant in plants]

# %%
biblios[0]
# Out:
# 'Encycl. 1: 723 (1785)'

# %% [markdown]
# Let's check the bibliographies for any explicit mention of Linnaeus, the godfather of biological taxonomy. First we'll remove the plants with no bibliography:

# %%
hasbiblio = [plant for plant in plants if plant['bibliography'] != None]

# %%
hasbiblio
# Out:
# [{'id': 678281,
#   'common_name': 'Evergreen oak',
#   'slug': 'quercus-rotundifolia',
#   'scientific_name': 'Quercus rotundifolia',
#   'year': 1785,
#   'bibliography': 'Encycl. 1: 723 (1785)',
#   'author': 'Lam.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Beech family',
#   'genus_id': 5778,
#   'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#   'synonyms': ['Quercus lyauteyi',
#    'Quercus rotundifolia f. crassicupulata',
#    'Quercus ballota',
#    'Quercus ilex f. brevicupulata',
#    'Quercus calycina',
#    'Quercus rotundifolia f. dolichocalyx',
#    'Quercus rotundifolia f. pilosella',
#    'Quercus rotundifolia f. macrocarpa',
#    'Quercus rotundifolia f. calycina',
#    'Quercus ilex f. macrocarpa',
#    'Quercus ilex subsp. ballota',
#    'Quercus rotundifolia var. pilosella',
#    'Quercus rotundifolia var. brevicupulata',
#    'Quercus rotundifolia subsp. maghrebiana',
#    'Quercus rotundifolia f. brevicupulata',
#    'Quercus rotundifolia var. macrocarpa'],
#   'genus': 'Quercus',
#   'family': 'Fagaceae',
#   'links': {'self': '/api/v1/species/quercus-rotundifolia',
#    'plant': '/api/v1/plants/quercus-rotundifolia',
#    'genus': '/api/v1/genus/quercus'}},
#  {'id': 190500,
#   'common_name': 'Stinging nettle',
#   'slug': 'urtica-dioica',
#   'scientific_name': 'Urtica dioica',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 984 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Nettle family',
#   'genus_id': 1028,
#   'image_url': 'https://bs.plantnet.org/image/o/85256a1c2c098e254fefe05040626a4df49ce248',
#   'synonyms': ['Urtica major',
#    'Urtica tibetica',
#    'Urtica sicula',
#    'Urtica eckloniana',
#    'Urtica haussknechtii',
#    'Urtica submitis'],
#   'genus': 'Urtica',
#   'family': 'Urticaceae',
#   'links': {'self': '/api/v1/species/urtica-dioica',
#    'plant': '/api/v1/plants/urtica-dioica',
#    'genus': '/api/v1/genus/urtica'}},
#  {'id': 126957,
#   'common_name': 'Orchardgrass',
#   'slug': 'dactylis-glomerata',
#   'scientific_name': 'Dactylis glomerata',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 71 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2284,
#   'image_url': 'https://bs.plantnet.org/image/o/428f40dadfa0281dc890ead17fcd07882f9efb09',
#   'synonyms': ['Koeleria dactylis',
#    'Festuca glomerata',
#    'Trachypoa vulgaris',
#    'Phalaris glomerata',
#    'Dactylis glomerata var. vivipara',
#    'Dactylis glomerata var. detonsa',
#    'Dactylis glomerata f. variegata',
#    'Dactylis decalcata',
#    'Dactylis abbreviata',
#    'Dactylis glomerata f. hispida',
#    'Dactylis stenophylla',
#    'Dactylis kovarovicii',
#    'Dactylis noeana',
#    'Dactylis kirschbaumii',
#    'Dactylis glomerata var. variegata',
#    'Dactylis pubescens',
#    'Festuca phalarioides',
#    'Dactylis nemorosa',
#    'Dactylis glaucescens',
#    'Dactylis metlesicsii',
#    'Dactylis altaica',
#    'Dactylis glomerata var. titani',
#    'Dactylis cylindracea',
#    'Dactylis scaberrima',
#    'Bromus cylindraceus',
#    'Dactylis peylii',
#    'Dactylis glomerata f. pubescens',
#    'Dactylis capitellata',
#    'Dactylis pendula',
#    'Sesleria cirtensis',
#    'Dactylis glomerata subsp. himalayensis'],
#   'genus': 'Dactylis',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/dactylis-glomerata',
#    'plant': '/api/v1/plants/dactylis-glomerata',
#    'genus': '/api/v1/genus/dactylis'}},
#  {'id': 167888,
#   'common_name': 'Narrowleaf plantain',
#   'slug': 'plantago-lanceolata',
#   'scientific_name': 'Plantago lanceolata',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 113 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 5418,
#   'image_url': 'https://bs.plantnet.org/image/o/78a8374f009e6ed2dc71ca17d18e4271ea0a2a7b',
#   'synonyms': ['Plantago lanceolata var. sphaerostachya',
#    'Plantago azorica',
#    'Plantago glareosa',
#    'Plantago lanceolata var. lanuginosa',
#    'Plantago trinervis',
#    'Plantago dubia',
#    'Plantago lanuginosa',
#    'Plantago kurdica',
#    'Plantago nutans',
#    'Plantago orientalis',
#    'Plantago leiopetala',
#    'Plantago capitata',
#    'Plantago lanceolata var. dubia',
#    'Plantago longiscapa',
#    'Plantago ambigua',
#    'Plantago glauca',
#    'Plantago pseudopatagonica',
#    'Plantago eriophora',
#    'Plantago attenuata',
#    'Plantago hungarica',
#    'Plantago variabilis',
#    'Plantago preslii',
#    'Plantago contorta',
#    'Plantago yezomaritima',
#    'Plantago schottii',
#    'Plantago elata',
#    'Plantago linkii',
#    'Lagopus timbali',
#    'Lagopus lanceolatus',
#    'Plantago byzantina',
#    'Plantago sylvatica',
#    'Arnoglossum lanceolatum',
#    'Plantago fontis-curvae',
#    'Plantago glabriflora',
#    'Plantago succisa',
#    'Plantago flexuosa',
#    'Plantago lanceolata var. minor'],
#   'genus': 'Plantago',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/plantago-lanceolata',
#    'plant': '/api/v1/plants/plantago-lanceolata',
#    'genus': '/api/v1/genus/plantago'}},
#  {'id': 173327,
#   'common_name': 'English oak',
#   'slug': 'quercus-robur',
#   'scientific_name': 'Quercus robur',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 996 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Beech family',
#   'genus_id': 5778,
#   'image_url': 'https://bs.plantnet.org/image/o/2292b670683abdaac354389514105df0018d9ef8',
#   'synonyms': ['Quercus longaeva',
#    'Quercus salicifolia',
#    'Quercus pedemontana',
#    'Quercus pseudoschorochensis',
#    'Quercus robur f. globulata',
#    'Quercus robur subsp. asterotricha',
#    'Quercus axillaris',
#    'Quercus microcarpa',
#    'Quercus dalechampii f. rubens',
#    'Quercus dalechampii var. aurea',
#    'Quercus dalechampii f. piersii',
#    'Quercus dalechampii f. macroloba',
#    'Quercus dalechampii f. lancifolia',
#    'Quercus strigosa',
#    'Quercus mexicana var. glabrata',
#    'Quercus castanea var. glabrata',
#    'Quercus tahuasalana',
#    'Quercus duratifolia',
#    'Cerris salicifolia',
#    'Quercus acapulcensis',
#    'Quercus turbinata',
#    'Quercus dilatata',
#    'Quercus aurea',
#    'Quercus subvelutina',
#    'Quercus avellanoides',
#    'Quercus cuprea',
#    'Quercus purpurea',
#    'Quercus hyemalis',
#    'Quercus bellogradensis',
#    'Quercus malacophylla',
#    'Quercus fructipendula',
#    'Quercus monorensis',
#    'Quercus fennessii',
#    'Quercus extensa',
#    'Quercus dissecta',
#    'Quercus tardiflora',
#    'Quercus atropurpurea',
#    'Quercus pyramidalis',
#    'Quercus pseudosessilis',
#    'Quercus geltowiensis',
#    'Quercus palmata',
#    'Quercus farinosa',
#    'Quercus comptoniifolia',
#    'Quercus sieboldii',
#    'Quercus nigricans',
#    'Quercus condensata',
#    'Quercus lasistan',
#    'Quercus coriifolia',
#    'Quercus hispanica',
#    'Quercus horizontalis',
#    'Quercus rubicunda',
#    'Quercus scolopendrifolia',
#    'Quercus robur var. patellulata',
#    'Quercus viminalis',
#    'Quercus bedoi',
#    'Quercus pendulina',
#    'Quercus robur f. subpraecox',
#    'Quercus parmenteria',
#    'Quercus auzin',
#    'Quercus cupulatus',
#    'Quercus pulverulenta',
#    'Quercus pendula',
#    'Quercus longiglans',
#    'Quercus pseudotscharakensis',
#    'Quercus asterotricha',
#    'Quercus robur f. brachybalanus',
#    'Quercus bruttia',
#    'Quercus robur f. subglobosa',
#    'Quercus castanoides',
#    'Quercus rubens',
#    'Quercus haas',
#    'Quercus speciensis',
#    'Quercus falkenbergensis',
#    'Quercus aesculus',
#    'Quercus filipendula',
#    'Quercus annenkowii',
#    'Quercus abbreviata',
#    'Quercus tennesi',
#    'Quercus germanica',
#    'Quercus cylindracea',
#    'Quercus welandii',
#    'Quercus tricolor',
#    'Quercus tozzae',
#    'Quercus tetracarpa',
#    'Quercus paleacea',
#    'Quercus atrovirens',
#    'Quercus robur f. sphaerobalanus',
#    'Quercus virgata',
#    'Quercus rumelica',
#    'Quercus aestivalis',
#    'Quercus robur subsp. slavonica',
#    'Quercus fastigiata',
#    'Quercus altissima',
#    'Quercus brossa',
#    'Quercus pyrenaica f. sphaerocarpa',
#    'Quercus tauzinii',
#    'Quercus toza',
#    'Quercus tauza',
#    'Quercus camata',
#    'Quercus lezermiana',
#    'Quercus robur var. tardissima',
#    'Quercus svecica',
#    'Quercus robur f. crassiuscula',
#    'Quercus pyrenaica',
#    'Quercus banatus',
#    'Quercus australis',
#    'Quercus pyrenaica f. expansa',
#    'Quercus pyrenaica f. stenocarpa',
#    'Quercus racemosa',
#    'Quercus lanuginosa',
#    'Quercus brevipes',
#    'Quercus robur f. fastigiata',
#    'Quercus estremadurensis',
#    'Quercus acherdophylla',
#    'Quercus robur subsp. broteroana',
#    'Quercus rubramenta',
#    'Quercus dalechampii f. apatini',
#    'Quercus stolonifera',
#    'Quercus pyrenaica f. normalis',
#    'Quercus cenomanensis',
#    'Quercus tauzin'],
#   'genus': 'Quercus',
#   'family': 'Fagaceae',
#   'links': {'self': '/api/v1/species/quercus-robur',
#    'plant': '/api/v1/plants/quercus-robur',
#    'genus': '/api/v1/genus/quercus'}},
#  {'id': 137025,
#   'common_name': 'Red fescue',
#   'slug': 'festuca-rubra',
#   'scientific_name': 'Festuca rubra',
#   'year': 1753,
#   'bibliography': 'Sp. pl. 1:74.  1753',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 1102,
#   'image_url': 'https://bs.plantnet.org/image/o/0b932c8a275efc79f473a71bec20d6f15e9b6b90',
#   'synonyms': ['Festuca rubra var. arenaria',
#    'Bromus secundus',
#    'Festuca kitaibeliana',
#    'Festuca rubra var. lanuginosa',
#    'Festuca michiganica',
#    'Festuca pseudovivipara',
#    'Festuca fallax',
#    'Festuca rubra var. mediana',
#    'Festuca ammobia',
#    'Festuca aucta',
#    'Festuca densiuscula',
#    'Festuca vallicola',
#    'Festuca ovina subsp. glauca',
#    'Festuca calcarea',
#    'Festuca rivularis subsp. pseudorivularis',
#    'Festuca glauca',
#    'Festuca heterophylla var. subheterophylla',
#    'Festuca glabra',
#    'Festuca oregona',
#    'Festuca halleri',
#    'Festuca iberica subsp. atlantigena',
#    'Festuca clarkei',
#    'Festuca alpestris',
#    'Festuca rubra subsp. thessalica',
#    'Festuca rubra subsp. yvesiana',
#    'Festuca longifolia',
#    'Festuca lanuginosa',
#    'Festuca daghestanica',
#    'Festuca rubra subsp. sochondinensis',
#    'Festuca rubra subsp. villosa',
#    'Festuca rubra var. glabra',
#    'Festuca pratensis',
#    '× Festulolium ascendens',
#    'Schedonorus radicans',
#    'Festuca villosa',
#    'Festuca glaucescens',
#    'Festuca rubra subsp. fraterculae',
#    'Festuca rubra subsp. glaucodea',
#    'Festuca rubra var. radnensis',
#    'Festuca subcontorta',
#    'Festuca kirelowii',
#    'Festuca nankotaizanensis',
#    'Festuca atlantigena',
#    'Festuca viridis',
#    'Festuca pseudorubra',
#    'Festuca rubra subsp. pruinosa',
#    'Festuca baicalensis',
#    'Festuca rubra subsp. vallicola',
#    'Festuca rubra subsp. pseudorivularis',
#    'Festuca aurasiaca',
#    'Festuca rubra var. atlantigena',
#    'Festuca rubra f. dasyphylla',
#    'Festuca rubra subsp. kirelowii',
#    'Festuca alexeevii',
#    'Schedonorus dumetorum',
#    'Festuca waldsteinii',
#    'Festuca rubra f. pseudovivipara',
#    'Festuca rubra subsp. eriantha',
#    'Festuca septiflora',
#    'Festuca rubra f. littoralis',
#    'Avena dura',
#    'Festuca rubra subsp. kitaibeliana',
#    'Festuca rubra f. subheterophylla',
#    'Festuca iberica subsp. yvesiana',
#    'Festuca rubra var. caulispicula',
#    'Festuca rubra subsp. densiuscula',
#    'Festuca rubra var. altaica',
#    'Festuca briquetii',
#    'Gramen rubrum',
#    'Festuca rubra var. pauciflora',
#    'Festuca baicalensis var. tjulinae',
#    'Festuca inopoda',
#    'Festuca limosa',
#    'Festuca pruinosa',
#    'Festuca rubra f. longifolia',
#    'Festuca rubra f. glabra',
#    'Festuca eriantha',
#    'Festuca baltica',
#    'Festuca rubra subsp. scotica',
#    'Festuca ovina subsp. major',
#    'Festuca rubra subvar. grandiflora',
#    'Festuca polyantha',
#    'Festuca repens',
#    'Festuca rubra subsp. baicalensis',
#    'Festuca subglaucescens',
#    'Festuca egena',
#    'Festuca steineri',
#    'Festuca pseudonemorum',
#    'Festuca rubra subsp. arenaria',
#    'Festuca rubra f. pilosa',
#    'Festuca helgolandica',
#    'Festuca rubra var. atrata',
#    'Festuca alexeevii var. villispiculata',
#    'Festuca rubra subsp. limosa',
#    'Festuca rubra var. magnelii',
#    'Festuca rubra var. secunda',
#    'Festuca salina',
#    'Festuca rubra subsp. secunda',
#    'Festuca rubra subvar. pruinosa',
#    'Festuca rubra var. glabrata',
#    'Festuca rubra subsp. pluriflora',
#    'Festuca rubra var. clarkei',
#    'Festuca askelofiana',
#    'Festuca rubra subsp. glabra',
#    'Festuca musashiensis',
#    'Festuca balearica',
#    'Festuca communis',
#    'Festuca alpigena',
#    'Festuca rubra subsp. daghestanica',
#    'Festuca hondoensis',
#    'Festuca rubra f. caespitosa',
#    'Festuca rubra subvar. glaucescens',
#    'Festuca pallidiuscula',
#    'Festuca unifaria var. izhorica',
#    'Festuca paucispicula',
#    'Festuca cambrica',
#    'Festuca planifolia',
#    'Poa tenuifolia var. oregona',
#    'Festuca rubra subvar. dasyphylla',
#    'Festuca paucispiculata',
#    'Festuca rubra var. yvesiana',
#    'Festuca unifaria',
#    'Festuca rubra subvar. densiuscula',
#    'Festuca rubra subvar. barbata',
#    'Festuca rubra f. psilolemma',
#    'Festuca siracusana',
#    'Festuca villiflora',
#    'Festuca yvesiana',
#    'Festuca rubra subsp. lanuginosa',
#    'Festuca polonica',
#    'Festuca longiseta',
#    'Festuca niitakensis',
#    'Festuca americana',
#    'Festuca spiciformis',
#    'Festuca plonkae',
#    'Festuca corsica',
#    'Festuca halleri subsp. yvesii',
#    'Festuca halleri subsp. scardica',
#    'Festuca gaudinii',
#    'Festuca austrodolomitica',
#    'Festuca halleri var. tenuis',
#    'Festuca decipiens',
#    'Festuca ovina var. alpestris',
#    'Festuca strictifolia',
#    'Festuca veneris',
#    'Festuca eragrostoides',
#    'Festuca rubra var. megastachys',
#    'Festuca ovina var. duriuscula',
#    'Festuca rubra var. grandiflora',
#    'Festuca rubra var. commutata',
#    'Festuca rubra var. littoralis',
#    'Festuca rubra var. pruinosa',
#    'Festuca rubra var. juncea',
#    'Lolium pratense',
#    'Festuca rubra subsp. aucta',
#    'Festuca rubra subsp. commutata',
#    'Festuca rubra subsp. arenicola',
#    'Festuca rubra subsp. vulgaris',
#    'Festuca rubra f. grandiflora',
#    'Festuca rubra subsp. fallax',
#    'Festuca rubra subsp. mediana',
#    'Festuca rubra subsp. juncea',
#    'Vulpia australis',
#    'Vulpia eriolepis f. glabrata',
#    'Festuca arctica',
#    'Festuca muralis',
#    'Vulpia muralis var. spicata',
#    'Lolium apenninum',
#    'Schedonorus pratensis subsp. apenninus',
#    'Lolium pratense subsp. apenninum',
#    'Festuca hybrida',
#    'Vulpia hybrida',
#    'Vulpia broteri',
#    'Vulpia muralis',
#    'Festuca broteri',
#    'Festuca apennina',
#    'Schedonorus apenninus',
#    'Lolium appenninum',
#    'Festuca australis',
#    'Festuca fluitans var. pratensis',
#    'Schedonorus pratensis',
#    'Schedonorus curvatus',
#    'Bucetum pratense',
#    'Schedonorus americanus',
#    'Festuca pratensis f. mucronata',
#    'Festuca adscendens',
#    'Festuca pratensis f. parvillora',
#    'Festuca heteromalla',
#    'Tragus pratensis',
#    'Festuca pratensis f. macrostachya',
#    'Festuca radicans',
#    'Festuca curvata'],
#   'genus': 'Festuca',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/festuca-rubra',
#    'plant': '/api/v1/plants/festuca-rubra',
#    'genus': '/api/v1/genus/festuca'}},
#  {'id': 173910,
#   'common_name': 'Creeping buttercup',
#   'slug': 'ranunculus-repens',
#   'scientific_name': 'Ranunculus repens',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 554 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Buttercup family',
#   'genus_id': 1607,
#   'image_url': 'https://bs.plantnet.org/image/o/c6d9a5222b6ef0e3a7bdef3350278718d3097bce',
#   'synonyms': ['Ranunculus repens var. erectus',
#    'Ranunculus repens var. pleniflorus',
#    'Ranunculus repens var. glabratus',
#    'Ranunculus repens var. linearilobus',
#    'Ranunculus schlechtendalii',
#    'Ranunculus oenanthifolius',
#    'Ranunculus lucidus',
#    'Ranunculus semidecurrens',
#    'Ranunculus repens f. polypetalus',
#    'Ranunculus repens f. schlechtendalii',
#    'Ranunculastrum reptabundum',
#    'Ranunculastrum repens',
#    'Ranunculus caleyanus',
#    'Ranunculus clintonii',
#    'Ranunculus belvisii',
#    'Ranunculus prostratus',
#    'Ranunculus lagascanus',
#    'Ranunculus repens var. degeneratus',
#    'Ranunculus repens var. typicus',
#    'Ranunculus repens var. villosus'],
#   'genus': 'Ranunculus',
#   'family': 'Ranunculaceae',
#   'links': {'self': '/api/v1/species/ranunculus-repens',
#    'plant': '/api/v1/plants/ranunculus-repens',
#    'genus': '/api/v1/genus/ranunculus'}},
#  {'id': 143075,
#   'common_name': 'Common velvetgrass',
#   'slug': 'holcus-lanatus',
#   'scientific_name': 'Holcus lanatus',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 1048 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 1064,
#   'image_url': 'https://bs.plantnet.org/image/o/46619775d4319328b2fad6f1ba876ccca2d03534',
#   'synonyms': ['Nothoholcus lanatus',
#    'Holcus lanatus subsp. vaginatus',
#    'Notholcus lanatus',
#    'Ginannia pubescens',
#    'Holcus lanatus var. sobolifer',
#    'Holcus tuberosus',
#    'Holcus aestivalis',
#    'Holcus oriolis',
#    'Holcus argenteus',
#    'Aira holcus-lanata',
#    'Holcus lanatus var. vaginatus',
#    'Ginannia lanata',
#    'Holcus lanatus subsp. tuberosus',
#    'Holcus lanatus var. tuberosus',
#    'Holcus intermedius',
#    'Holcus lanatus f. viviparus',
#    'Holcus glaucus'],
#   'genus': 'Holcus',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/holcus-lanatus',
#    'plant': '/api/v1/plants/holcus-lanatus',
#    'genus': '/api/v1/genus/holcus'}},
#  {'id': 189539,
#   'common_name': 'White clover',
#   'slug': 'trifolium-repens',
#   'scientific_name': 'Trifolium repens',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 767 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 5044,
#   'image_url': 'https://bs.plantnet.org/image/o/c766ed84c547abac6021244bc0014d665ba7726f',
#   'synonyms': ['Amoria repens',
#    'Trifolium repens var. atropurpureum',
#    'Trifolium repens subsp. repens',
#    'Trifolium repens var. giganteum'],
#   'genus': 'Trifolium',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/trifolium-repens',
#    'plant': '/api/v1/plants/trifolium-repens',
#    'genus': '/api/v1/genus/trifolium'}},
#  {'id': 137834,
#   'common_name': 'European ash',
#   'slug': 'fraxinus-excelsior',
#   'scientific_name': 'Fraxinus excelsior',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 1057 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Olive family',
#   'genus_id': 3064,
#   'image_url': 'https://bs.plantnet.org/image/o/56cbb2c6905b39891def2c7aa09a94d63a0e572a',
#   'synonyms': ['Fraxinus excelsior var. communis',
#    'Fraxinus excelsior var. pendula',
#    'Fraxinus ochrochlora',
#    'Ornus strigata',
#    'Fraxinus excelsior f. digitata',
#    'Fraxinus lucida',
#    'Fraxinus polemonifolia',
#    'Fraxinus streptocarpa',
#    'Fraxinus excelsior var. angustifolia',
#    'Fraxinus steudelii',
#    'Fraxinus purpurascens',
#    'Fraxinus atrovirens',
#    'Fraxinus bumelia',
#    'Fraxinus oxyodon',
#    'Fraxinus linearis',
#    'Fraxinus retorta',
#    'Fraxinus globosa',
#    'Fraxinus baurieri',
#    'Aplilia laciniata',
#    'Fraxinus excelsior f. multifoliolata',
#    'Fraxinus integrifolia',
#    'Fraxinus concavifolia',
#    'Leptalix atrovirens',
#    'Fraxinus strigata',
#    'Fraxinus fungosa',
#    'Fraxinus scolopendrium',
#    'Fraxinus eliae',
#    'Fraxinus ceretanica',
#    'Fraxinus ararica',
#    'Fraxinus acutifolia',
#    'Fraxinus brevidentata',
#    'Fraxinus atra',
#    'Fraxinus pumila',
#    'Fraxinus cucullata',
#    'Fraxinus crispa',
#    'Fraxinus simplicifolia',
#    'Fraxinus glomerata',
#    'Fraxinus boitrayana',
#    'Aplilia pendula',
#    'Fraxinus exoniensis',
#    'Fraxinus heterophylla',
#    'Fraxinus apetala',
#    'Fraxinus amarissima',
#    'Fraxinus stenobotrys',
#    'Fraxinus spectabilis',
#    'Fraxinus dodei',
#    'Fraxinus biloba',
#    'Ornus striata',
#    'Fraxinus excelsior f. angustifolia',
#    'Leptalix nana',
#    'Fraxinus longisamara',
#    'Fraxinus burgalensis',
#    'Fraxinus aurea',
#    'Fraxinus humilis',
#    'Fraxinus subcordata',
#    'Fraxinus microphylla',
#    'Fraxinus scolopendrifolia',
#    'Fraxinus boscii',
#    'Fraxinus appendiculata',
#    'Fraxinus nana',
#    'Fraxinus grandifolia',
#    'Fraxinus intermedia'],
#   'genus': 'Fraxinus',
#   'family': 'Oleaceae',
#   'links': {'self': '/api/v1/species/fraxinus-excelsior',
#    'plant': '/api/v1/plants/fraxinus-excelsior',
#    'genus': '/api/v1/genus/fraxinus'}},
#  {'id': 124198,
#   'common_name': 'Oneseed hawthorn',
#   'slug': 'crataegus-monogyna',
#   'scientific_name': 'Crataegus monogyna',
#   'year': 1775,
#   'bibliography': 'Fl. Austriac. 3: 50 (1775)',
#   'author': 'Jacq.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 678,
#   'image_url': 'https://bs.plantnet.org/image/o/26b1520c799177ee1b7c4a27f9f46c4ace617dd2',
#   'synonyms': ['Crataegus insegnae',
#    'Mespilus insegnae',
#    'Mespilus crataegus',
#    'Mespilus elegans',
#    'Mespilus heterophylla',
#    'Crataegus triloba',
#    'Crataegus monogyna var. dissecta',
#    'Oxyacantha elegans',
#    'Mespilus brevispina',
#    'Crataegus brevispina',
#    'Crataegus monogyna var. lasiocarpa',
#    'Crataegus azarella',
#    'Crataegus monogyna var. microphylla',
#    'Crataegus dissecta',
#    'Crataegus monogyna var. nordica',
#    'Crataegus apiifolia',
#    'Mespilus maura',
#    'Mespilus constantinopolitana',
#    'Crataegus maura',
#    'Crataegus heterophylla',
#    'Oxyacantha azarella',
#    'Crataegus aegeica',
#    'Crataegus monogyna subsp. nordica',
#    'Mespilus triloba',
#    'Oxyacantha apiifolia',
#    'Oxyacantha monogyna',
#    'Mespilus monogyna',
#    'Crataegus lasiocarpa',
#    'Crataegus stevenii'],
#   'genus': 'Crataegus',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/crataegus-monogyna',
#    'plant': '/api/v1/plants/crataegus-monogyna',
#    'genus': '/api/v1/genus/crataegus'}},
#  {'id': 189529,
#   'common_name': 'Red clover',
#   'slug': 'trifolium-pratense',
#   'scientific_name': 'Trifolium pratense',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 768 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 5044,
#   'image_url': 'https://bs.plantnet.org/image/o/7eb243363838c9975c57204057e63fa8101c26d8',
#   'synonyms': ['Trifolium pratense var. sativum',
#    'Lagopus pratensis',
#    'Trifolium nivale',
#    'Trifolium glareosum',
#    'Trifolium villosum',
#    'Ononis trifoliata',
#    'Trifolium transsilvanicum',
#    'Trifolium pratense var. variegatum',
#    'Trifolium expansum',
#    'Trifolium pratense var. evariegatum',
#    'Trifolium ucrainicum',
#    'Trifolium pratense subsp. expansum',
#    'Trifolium foliosum',
#    'Trifolium leucophaeum',
#    'Trifolium officinarum',
#    'Trifolium abbreviatum',
#    'Trifolium carpathicum',
#    'Trifolium vaginatum',
#    'Trifolium lenkoranicum',
#    'Trifolium pratense var. foliosum',
#    'Trifolium brachyanthum',
#    'Trifolium capillatum',
#    'Trifolium borderi',
#    'Trifolium heterophyllum',
#    'Trifolium alpicola',
#    'Trifolium seravschanicum',
#    'Trifolium arizagae',
#    'Trifolium bracteatum',
#    'Trifolium brachystylos',
#    'Trifolium pensylvanicum f. albiflorum',
#    'Trifolium sativum',
#    'Trifolium pratense subsp. serotinum',
#    'Trifolium pratense subsp. semipurpureum',
#    'Trifolium purpureum',
#    'Trifolium pratense f. lilacinum',
#    'Trifolium microphyllum'],
#   'genus': 'Trifolium',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/trifolium-pratense',
#    'plant': '/api/v1/plants/trifolium-pratense',
#    'genus': '/api/v1/genus/trifolium'}},
#  {'id': 173587,
#   'common_name': 'Tall buttercup',
#   'slug': 'ranunculus-acris',
#   'scientific_name': 'Ranunculus acris',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 554 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Buttercup family',
#   'genus_id': 1607,
#   'image_url': 'https://bs.plantnet.org/image/o/8390d605e1947cb44e24af9492f96df4a34e8ca8',
#   'synonyms': ['Ranunculus acris var. minimus',
#    'Ranunculus mccallae',
#    'Ranunculastrum vulgatum',
#    'Ranunculus siculus',
#    'Ranunculus csatoi',
#    'Ranunculastrum acre',
#    'Ranunculus acris var. multifidus',
#    'Ranunculus acris f. multiplicipetalus',
#    'Ranunculus stevenii',
#    'Ranunculus pascuicola',
#    'Ranunculus buergeri',
#    'Ranunculus franchetianus',
#    'Ranunculus stipatus',
#    'Ranunculus kerneri',
#    'Ranunculus trachyticus',
#    'Ranunculus cammarifolius',
#    'Ranunculus kayseri',
#    'Ranunculus paradoxus',
#    'Ranunculastrum nemorivagum',
#    'Ranunculus sylvaticus',
#    'Ranunculus tomophyllus',
#    'Ranunculus acris var. filiformis',
#    'Ranunculus colocensis',
#    'Ranunculastrum boraeanum',
#    'Ranunculus silvaticus',
#    'Ranunculus barthii',
#    'Ranunculus boraeanus',
#    'Ranunculus intercedens',
#    'Ranunculus nemorivagus',
#    'Ranunculus rectus',
#    'Ranunculus major',
#    'Ranunculus subalpinus',
#    'Ranunculus vulgatus',
#    'Ranunculus acris var. sylvaticus',
#    'Ranunculus malacophyllus',
#    'Ranunculus platyphyllus',
#    'Ranunculus eustrigulosus',
#    'Ranunculus transsilvanicus',
#    'Ranunculus acris var. acris',
#    'Ranunculus acris var. typicus',
#    'Ranunculus acris var. latisectus',
#    'Ranunculus boreanus',
#    'Ranunculus acris subsp. pumilus'],
#   'genus': 'Ranunculus',
#   'family': 'Ranunculaceae',
#   'links': {'self': '/api/v1/species/ranunculus-acris',
#    'plant': '/api/v1/plants/ranunculus-acris',
#    'genus': '/api/v1/genus/ranunculus'}},
#  {'id': 123486,
#   'common_name': 'Common filbert',
#   'slug': 'corylus-avellana',
#   'scientific_name': 'Corylus avellana',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 998 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Birch family',
#   'genus_id': 2057,
#   'image_url': 'https://bs.plantnet.org/image/o/0d92cadb0d66dce1b0a8b26913125d6501e31d68',
#   'synonyms': ['Corylus sylvestris',
#    'Corylus ovata',
#    'Corylus pumila',
#    'Corylus quercifolia',
#    'Corylus ardua',
#    'Corylus arborea',
#    'Corylus pontica',
#    'Corylus avellana f. microphylla',
#    'Corylus urticifolia',
#    'Corylus avellana var. macrotruncus',
#    'Corylus alba',
#    'Corylus serenyiana',
#    'Corylus filicifolia',
#    'Corylus avellana f. peltata'],
#   'genus': 'Corylus',
#   'family': 'Betulaceae',
#   'links': {'self': '/api/v1/species/corylus-avellana',
#    'plant': '/api/v1/plants/corylus-avellana',
#    'genus': '/api/v1/genus/corylus'}},
#  {'id': 136773,
#   'common_name': 'European beech',
#   'slug': 'fagus-sylvatica',
#   'scientific_name': 'Fagus sylvatica',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 998 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Beech family',
#   'genus_id': 2976,
#   'image_url': 'https://bs.plantnet.org/image/o/a733221df31a1ff99af03566841744f3b4c6cffe',
#   'synonyms': ['Fagus purpurea',
#    'Fagus sylvestris',
#    'Fagus sylvatica var. purpurea',
#    'Fagus sylvatica var. quercifolia',
#    'Fagus sylvatica var. vulgaris',
#    'Fagus echinata',
#    'Castanea fagus',
#    'Fagus incisa',
#    'Fagus laciniata',
#    'Fagus cochleata',
#    'Fagus sylvatica var. zlatia',
#    'Fagus comptoniifolia',
#    'Fagus cuprea'],
#   'genus': 'Fagus',
#   'family': 'Fagaceae',
#   'links': {'self': '/api/v1/species/fagus-sylvatica',
#    'plant': '/api/v1/plants/fagus-sylvatica',
#    'genus': '/api/v1/genus/fagus'}},
#  {'id': 146208,
#   'common_name': 'Common rush',
#   'slug': 'juncus-effusus',
#   'scientific_name': 'Juncus effusus',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 326 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rush family',
#   'genus_id': 3848,
#   'image_url': 'https://bs.plantnet.org/image/o/93041212342d6e8f9f544fd55000c037485a360e',
#   'synonyms': ['Juncus communis',
#    'Juncus communis var. effusus',
#    'Juncus laevis',
#    'Tristemon conglomeratus',
#    'Juncus lucens',
#    'Juncus mauritianus',
#    'Juncus bogotensis var. compactus',
#    'Scirpus capsularis',
#    'Juncus luxurians',
#    'Juncus bogotensis',
#    'Juncus zebrinus',
#    'Juncus fistulosus',
#    'Juncus effusus var. compactus',
#    'Juncus effusus var. effusus',
#    'Juncus effusus var. subglomeratus'],
#   'genus': 'Juncus',
#   'family': 'Juncaceae',
#   'links': {'self': '/api/v1/species/juncus-effusus',
#    'plant': '/api/v1/plants/juncus-effusus',
#    'genus': '/api/v1/genus/juncus'}},
#  {'id': 176845,
#   'common_name': 'Garden sorrel',
#   'slug': 'rumex-acetosa',
#   'scientific_name': 'Rumex acetosa',
#   'year': 1753,
#   'bibliography': 'Sp. pl. 1:337.  1753, nom. cons.',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Buckwheat family',
#   'genus_id': 2722,
#   'image_url': 'https://bs.plantnet.org/image/o/780b9f3c63318588b8874d608c2d4900fc2adce3',
#   'synonyms': ['Acetosa pratensis subsp. fontanopaludosa',
#    'Acetosa officinalis',
#    'Rumex planellae',
#    'Lapathum pratense',
#    'Rumex fontanopaludosus',
#    'Rumex triangularis',
#    'Acetosa angustata',
#    'Acetosa amplexicaulis',
#    'Rumex oxyotus',
#    'Acetosa hastulata',
#    'Rumex oblongus',
#    'Acetosa bidentula',
#    'Acetosa olitoria',
#    'Rumex acetosa subsp. biformis',
#    'Acetosa pratensis subsp. biformis',
#    'Rumex angustatus',
#    'Rumex micranthus',
#    'Acetosa subalpina',
#    'Acetosa hastifolia',
#    'Rumex pseudoacetosa',
#    'Rumex commersonii',
#    'Acetosa fontanopaludosa',
#    'Rumex olitoria',
#    'Acetosa agrestis',
#    'Rumex agrestis',
#    'Rumex acuminatus',
#    'Rumex sagittifolius',
#    'Rumex biformis',
#    'Rumex bidentula',
#    'Acetosa pratensis',
#    'Rumex bulbosus',
#    'Lapathum acetosa'],
#   'genus': 'Rumex',
#   'family': 'Polygonaceae',
#   'links': {'self': '/api/v1/species/rumex-acetosa',
#    'plant': '/api/v1/plants/rumex-acetosa',
#    'genus': '/api/v1/genus/rumex'}},
#  {'id': 105790,
#   'common_name': 'Sweet vernalgrass',
#   'slug': 'anthoxanthum-odoratum',
#   'scientific_name': 'Anthoxanthum odoratum',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 28 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 499,
#   'image_url': 'https://bs.plantnet.org/image/o/fcf64ef0676db8ca9d2abf4017f5b8211b10e0b1',
#   'synonyms': ['Anthoxanthum odoratum f. montanum',
#    'Anthoxanthum odoratum f. tenerum',
#    'Anthoxanthum sommierianum',
#    'Anthoxanthum maderense',
#    'Xanthonanthos odoratus',
#    'Anthoxanthum pauciflorum',
#    'Anthoxanthum asperum',
#    'Anthoxanthum nebrodense'],
#   'genus': 'Anthoxanthum',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/anthoxanthum-odoratum',
#    'plant': '/api/v1/plants/anthoxanthum-odoratum',
#    'genus': '/api/v1/genus/anthoxanthum'}},
#  {'id': 137183,
#   'common_name': 'Queen of the meadow',
#   'slug': 'filipendula-ulmaria',
#   'scientific_name': 'Filipendula ulmaria',
#   'year': 1879,
#   'bibliography': 'Trudy Imp. S.-Peterburgsk. Bot. Sada 6: 251 (1879)',
#   'author': '(L.) Maxim.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 3008,
#   'image_url': 'https://bs.plantnet.org/image/o/f5f2a3d241dcd22e237cdebdbf770477721516f0',
#   'synonyms': ['Spiraea ulmaria',
#    'Filipendula denudata',
#    'Filipendula ulmaria var. denudata',
#    'Filipendula ulmaria subsp. megalocarpa',
#    'Filipendula ulmaria subsp. denudata',
#    'Spiraea denudata',
#    'Spiraea filipendula var. tomentosa',
#    'Spiraea ulmaria var. denudata',
#    'Ulmaria glauca',
#    'Ulmaria quinqueloba',
#    'Ulmaria pentapetala',
#    'Ulmaria ulmaria',
#    'Ulmaria vulgaris',
#    'Ulmaria denudata',
#    'Filipendula megalocarpa',
#    'Spiraea contorta',
#    'Filipendula ulmaria var. tomentosa',
#    'Filipendula ulmaria var. glaberrima'],
#   'genus': 'Filipendula',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/filipendula-ulmaria',
#    'plant': '/api/v1/plants/filipendula-ulmaria',
#    'genus': '/api/v1/genus/filipendula'}},
#  {'id': 101851,
#   'common_name': 'Sycamore maple',
#   'slug': 'acer-pseudoplatanus',
#   'scientific_name': 'Acer pseudoplatanus',
#   'year': 1753,
#   'bibliography': 'Sp. pl. 2:1054.  1753',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Soapberry family',
#   'genus_id': 39,
#   'image_url': 'https://bs.floristic.org/image/o/d2747c12a135a00ff8e6d8af86acbec3c6f8248d',
#   'synonyms': ['Acer purpureum',
#    'Acer worleei',
#    'Acer euchlorum',
#    'Acer rafinesquianum',
#    'Acer wondracekii',
#    'Acer villosum',
#    'Acer opizii',
#    'Acer melliodorum',
#    'Acer procerum',
#    'Acer atropurpureum',
#    'Acer abchasicum',
#    'Acer rubrum f. tomentosum'],
#   'genus': 'Acer',
#   'family': 'Sapindaceae',
#   'links': {'self': '/api/v1/species/acer-pseudoplatanus',
#    'plant': '/api/v1/plants/acer-pseudoplatanus',
#    'genus': '/api/v1/genus/acer'}},
#  {'id': 167892,
#   'common_name': 'Common plantain',
#   'slug': 'plantago-major',
#   'scientific_name': 'Plantago major',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 112 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 5418,
#   'image_url': 'https://bs.plantnet.org/image/o/36c2225c7d24a897eaf055e99eac26b3f5ceffa3',
#   'synonyms': ['Plantago major var. scopulorum',
#    'Plantago minima',
#    'Plantago subsinuata',
#    'Plantago major var. sinuata',
#    'Plantago dilatata',
#    'Plantago loureiroi',
#    'Plantago limosa',
#    'Plantago tabernaemontani',
#    'Plantago laciniosa',
#    'Plantago namikawae',
#    'Plantago nana',
#    'Plantago japonica',
#    'Plantago scopulorum',
#    'Plantago dostalii',
#    'Plantago dregeana',
#    'Plantago macronipponica',
#    'Plantago vulgaris',
#    'Plantago major var. brachystachya',
#    'Plantago togashii',
#    'Plantago littoralis',
#    'Plantago major var. leptostachya',
#    'Plantago compressiscapa',
#    'Plantago angustata',
#    'Plantago bracteata',
#    'Plantago sinuata',
#    'Plantago crenata',
#    'Plantago sorokini',
#    'Plantago humifusa',
#    'Plantago rosea',
#    'Plantago sawadae',
#    'Plantago officinarum',
#    'Plantago exaltata',
#    'Plantago gigas',
#    'Plantago major f. sinuata',
#    'Plantago fonticola',
#    'Plantago adriatica',
#    'Plantago borysthenica',
#    'Plantago gouanii',
#    'Plantago polystachia',
#    'Plantago rocae',
#    'Plantago polystachya',
#    'Plantago major var. pachyphylla',
#    'Plantago major var. pilgeri'],
#   'genus': 'Plantago',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/plantago-major',
#    'plant': '/api/v1/plants/plantago-major',
#    'genus': '/api/v1/genus/plantago'}},
#  {'id': 166081,
#   'common_name': 'Common reed',
#   'slug': 'phragmites-australis',
#   'scientific_name': 'Phragmites australis',
#   'year': 1841,
#   'bibliography': 'Nomencl. Bot., ed. 2, 2: 324 (1841)',
#   'author': '(Cav.) Trin. ex Steud.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 3364,
#   'image_url': 'https://bs.plantnet.org/image/o/1155e1614588374ce93aedb701ae8483e2cae45f',
#   'synonyms': ['Phragmites communis',
#    'Arundo australis',
#    'Arundo pseudophragmites',
#    'Donax australis',
#    'Phragmites australis subsp. americanus',
#    'Phragmites communis subsp. berlandieri',
#    'Phragmites australis var. flavescens',
#    'Remirea diffusa',
#    'Phragmites chilensis',
#    'Arundo filiformis',
#    'Cynodon phragmites',
#    'Arundo vulgaris',
#    'Phragmites breviglumis',
#    'Phragmites jahandiezii',
#    'Phragmites humilis',
#    'Czernya arundinacea',
#    'Phragmites hirsutus',
#    'Phragmites nagus',
#    'Cenchrus frutescens',
#    'Phragmites flavescens',
#    'Oxyanthe phragmites',
#    'Arundo barbata',
#    'Trichoon phragmites',
#    'Phragmites pungens',
#    'Phragmites communis f. salsa',
#    'Phragmites australis var. salsa',
#    'Phragmites stenophyllus',
#    'Phragmites australis var. turkestanicus',
#    'Phragmites australis var. striatopictus',
#    'Phragmites willkommianus',
#    'Phragmites fissifolius',
#    'Phragmites communis var. variegatus',
#    'Phragmites martinicensis',
#    'Phragmites explanatus',
#    'Phragmites congestus',
#    'Xenochloa arundinacea',
#    'Phragmites dioicus',
#    'Phragmites pumilus',
#    'Arundo nigricans',
#    'Phragmites australis subsp. maritimus',
#    'Arundo occidentalis',
#    'Phragmites australis subsp. humilis',
#    'Reimaria diffusa',
#    'Arundo vulnerans',
#    'Phragmites capensis',
#    'Arundo phragmites',
#    'Phragmites caudatus',
#    'Phragmites hispanicus',
#    'Phragmites occidentalis',
#    'Phragmites graecus',
#    'Phragmites nigricans',
#    'Phragmites flexuosus',
#    'Phragmites nakaianus',
#    'Calamagrostis nigricans',
#    'Phragmites australis f. pilifer',
#    'Phragmites australis var. marsillianus',
#    'Phragmites australis f. subuniflora',
#    'Phragmites australis var. stenophyllus',
#    'Phragmites vulgaris',
#    'Phragmites xenochloa',
#    'Phragmites frutescens',
#    'Phragmites maximus var. variegatus',
#    'Arundo graeca',
#    'Phragmites emodi',
#    'Phragmites maritimus',
#    'Arundo rivularis',
#    'Phragmites filiformis',
#    'Phragmites loscosii',
#    'Phragmites longivalvis',
#    'Phragmites distichus',
#    'Phragmites bhattacharyyae',
#    'Phragmites jeholensis',
#    'Arundo palustris',
#    'Phragmites australis var. humilis',
#    'Arundo pungens',
#    'Arundo aggerum',
#    'Phragmites australis subsp. berlandieri',
#    'Phragmites barbatus'],
#   'genus': 'Phragmites',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/phragmites-australis',
#    'plant': '/api/v1/plants/phragmites-australis',
#    'genus': '/api/v1/genus/phragmites'}},
#  {'id': 167120,
#   'common_name': 'Scots pine',
#   'slug': 'pinus-sylvestris',
#   'scientific_name': 'Pinus sylvestris',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 1000 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pine family',
#   'genus_id': 5,
#   'image_url': 'https://bs.plantnet.org/image/o/33d84b84c09347d360afa0d610e220664cfb6d93',
#   'synonyms': ['Pinus borealis',
#    'Pinus montana',
#    'Pinus fominii subsp. cretacea',
#    'Pinus sylvestris var. norvegica',
#    'Pinus hagenaviensis',
#    'Pinus genevensis',
#    'Pinus mughus',
#    'Pinus frieseana',
#    'Pinus sylvestris subsp. amurensis',
#    'Pinus sylvestris var. tartarica',
#    'Pinus sylvestris var. cretacea',
#    'Pinus sylvestris var. communis',
#    'Pinus sylvestris subsp. krylovii',
#    'Pinus erzeroomica',
#    'Pinus sylvestris var. nevadensis',
#    'Pinus sylvestris subsp. pannonica',
#    'Pinus sylvestris subsp. nevadensis',
#    'Pinus ericetorum',
#    'Pinus lapponica',
#    'Pinus fominii',
#    'Pinus krylovii',
#    'Pinus tartarica',
#    'Pinus binatofolio',
#    'Pinus sylvestris subsp. sibirica',
#    'Pinus genovensis',
#    'Pinus sylvestris subsp. ursina',
#    'Pinus cretacea',
#    'Pinus rubra'],
#   'genus': 'Pinus',
#   'family': 'Pinaceae',
#   'links': {'self': '/api/v1/species/pinus-sylvestris',
#    'plant': '/api/v1/plants/pinus-sylvestris',
#    'genus': '/api/v1/genus/pinus'}},
#  {'id': 151726,
#   'common_name': "Bird's-foot trefoil",
#   'slug': 'lotus-corniculatus',
#   'scientific_name': 'Lotus corniculatus',
#   'year': 1753,
#   'bibliography': 'Sp. pl. 2:775.  1753',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 4298,
#   'image_url': 'https://bs.plantnet.org/image/o/c2180ef57b83b419e4b851c058003d56ad2c6bbe',
#   'synonyms': ['Lotus caucasicus',
#    'Lotus corniculatus var. arvensis',
#    'Lotus corniculatus var. crassifolius',
#    'Lotus suberectus',
#    'Lotus angustifolius',
#    'Lotus pilosissimus',
#    'Lotus corniculatus subsp. ambiguus',
#    'Lotus corniculatus var. sativus',
#    'Lotus tchihatchewii',
#    'Lotus stenodon',
#    'Lotus orphanidis',
#    'Lotus corniculatus var. fallax',
#    'Lotus ambiguus',
#    'Lotus bracteatus',
#    'Lotus corniculatus var. futakii',
#    'Lotus corniculatus subsp. ruprechtii',
#    'Lotus zhegulensis',
#    'Lotus corniculatus subsp. komarovii',
#    'Lotus tauricus',
#    'Lotus corniculatus var. ciliatus',
#    'Lotus sativus',
#    'Lotus haeupleri',
#    'Lotus gibbus',
#    'Lotus rostellatus',
#    'Lotus balticus',
#    'Lotus humifusus',
#    'Lotus colocensis',
#    'Mullaghera communis',
#    'Lotus pentaphyllos',
#    'Lotus riparius',
#    'Lotus arvensis',
#    'Lotus forsteri',
#    'Lotus corniculatus var. sibthorpii',
#    'Lotus valdepilosus',
#    'Lotus symmetricus',
#    'Lotus depressus',
#    'Lotus olgae',
#    'Lotus juzepczukii',
#    'Tetragonolobus scandalida',
#    'Mullaghera uliginosa',
#    'Lotus uliginosus'],
#   'genus': 'Lotus',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/lotus-corniculatus',
#    'plant': '/api/v1/plants/lotus-corniculatus',
#    'genus': '/api/v1/genus/lotus'}},
#  {'id': 168794,
#   'common_name': 'Rough bluegrass',
#   'slug': 'poa-trivialis',
#   'scientific_name': 'Poa trivialis',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 67 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 1522,
#   'image_url': 'https://bs.plantnet.org/image/o/8e4f8472f36f36175a8d2fca4723059699f9d46e',
#   'synonyms': ['Poa sylvicola',
#    'Poa attica',
#    'Poa palustris',
#    'Poa triflora',
#    'Poa angustifolia f. collina',
#    'Poa serotina',
#    'Poa schultesii',
#    'Poa rotundata',
#    'Poa adspersa',
#    'Poa hydrophyla',
#    'Poa hydrophila',
#    'Poa palustris f. pauciflora',
#    'Poa palustris f. coarctata',
#    'Poa distans',
#    'Poa selemdzhensis',
#    'Poa fertilis',
#    'Poa laevis',
#    'Poa jamalinensis',
#    'Poa riparia',
#    'Poa crocata',
#    'Poa palustris var. halophila',
#    'Poa trivialis subsp. feratiana',
#    'Poa angustifolia',
#    'Poa volhynensis',
#    'Paneion triflorum',
#    'Poa abietina',
#    'Poa palustris f. turfosa',
#    'Poa trachyphylla',
#    'Poa semineutra',
#    'Poa stolonifera',
#    'Poa miliacea',
#    'Poa pratensis subsp. angustifolia',
#    'Poa angustifolia var. obornyana',
#    'Poa dubia',
#    'Poa panicea',
#    'Poa biflora',
#    'Poa elegans',
#    'Poa setacea',
#    'Poa depauperata',
#    'Poa kitaibelii',
#    'Poa effusa',
#    'Poa pseudonemoralis',
#    'Poa trivialis var. latifolia',
#    'Poa scabra',
#    'Poa trivialis subsp. latifolia',
#    'Poa pollinensis',
#    'Poa modesta',
#    'Poa trivialis subsp. semineutra',
#    'Poa trivialis var. holsatia',
#    'Poa trivialis f. prorepens',
#    'Phalaris semineutra',
#    'Poa ariguensis',
#    'Poa trivialis f. humilis',
#    'Poa feratiana',
#    'Poa callida',
#    'Poa uda',
#    'Poa perouinii',
#    'Poa tristriata',
#    'Poa trivialis var. obtusata',
#    'Poa portalii',
#    'Poa woronowii',
#    'Poa pseudohybrida',
#    'Poa pichinchensis',
#    'Poa angustifolia f. puberula',
#    'Poa angustifolia f. pyramidalis',
#    'Poa pratensis var. angustifolia',
#    'Poa trivialis subsp. sylvicola',
#    'Poa viridula',
#    'Poa angustifolia f. praesignis',
#    'Poa angustifolia f. filiformis',
#    'Poa angustifolia f. straminea',
#    'Poa strigosa',
#    'Poa angustifolia f. longifolia',
#    'Poa villarsii',
#    'Poa angustifolia var. violacea',
#    'Poa pratensis subsp. atlantis',
#    'Poa angustifolia f. hirtula',
#    'Poa hamhungensis',
#    'Poa palustris subsp. volhynensis',
#    'Poa janczewskii',
#    'Poa glauca var. crocata'],
#   'genus': 'Poa',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/poa-trivialis',
#    'plant': '/api/v1/plants/poa-trivialis',
#    'genus': '/api/v1/genus/poa'}},
#  {'id': 139683,
#   'common_name': 'Ground ivy',
#   'slug': 'glechoma-hederacea',
#   'scientific_name': 'Glechoma hederacea',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 578 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Mint family',
#   'genus_id': 3198,
#   'image_url': 'https://bs.plantnet.org/image/o/d7aa2ca54f628e1f5a67dd672aeebb006d281a9b',
#   'synonyms': ['Nepeta hederacea',
#    'Glechoma rotundifolia',
#    'Glechoma magna',
#    'Glechoma heterophylla',
#    'Chamaeclema hederacea',
#    'Calamintha hederacea',
#    'Hedera terrestris',
#    'Glechoma intermedia',
#    'Glechoma lobulata',
#    'Glechoma repens',
#    'Nepeta rigida',
#    'Nepeta glechoma',
#    'Glechoma longicaulis',
#    'Glechoma bulgarica',
#    'Glechoma serbica',
#    'Glechoma borealis',
#    'Glechoma rigida',
#    'Nepeta glechoma var. hirsuta',
#    'Glechonion hederaceum',
#    'Chamaecissos hederaceus',
#    'Glechoma micrantha',
#    'Glechoma hederacea var. micrantha',
#    'Glechoma hederacea var. parviflora'],
#   'genus': 'Glechoma',
#   'family': 'Lamiaceae',
#   'links': {'self': '/api/v1/species/glechoma-hederacea',
#    'plant': '/api/v1/plants/glechoma-hederacea',
#    'genus': '/api/v1/genus/glechoma'}},
#  {'id': 183086,
#   'common_name': 'European mountain ash',
#   'slug': 'sorbus-aucuparia',
#   'scientific_name': 'Sorbus aucuparia',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 477 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 677,
#   'image_url': 'https://bs.plantnet.org/image/o/63073d2fbf45b90701279405ecc2eec0272906ed',
#   'synonyms': ['Pyrus boissieri',
#    'Pyrus lanuginosa',
#    'Sorbus altaica',
#    'Sorbus subserrata',
#    'Mespilus aucuparia',
#    'Pyrenia aucuparia',
#    'Aucuparia silvestris',
#    'Sorbus lanuginosa',
#    'Sorbus cordata',
#    'Sorbus anadyrensis',
#    'Sorbus boissieri',
#    'Sorbus caucasigena',
#    'Sorbus monticola',
#    'Sorbus aucuparia var. xanthocarpa',
#    'Pyrus aucuparia'],
#   'genus': 'Sorbus',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/sorbus-aucuparia',
#    'plant': '/api/v1/plants/sorbus-aucuparia',
#    'genus': '/api/v1/genus/sorbus'}},
#  {'id': 138374,
#   'common_name': 'Stickywilly',
#   'slug': 'galium-aparine',
#   'scientific_name': 'Galium aparine',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 108 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Madder family',
#   'genus_id': 2120,
#   'image_url': 'https://bs.plantnet.org/image/o/dda8d72438e461abaca1e717c43b1555d2727bc8',
#   'synonyms': ['Galium aparine var. intermedium',
#    'Galium uliginosum',
#    'Crucianella purpurea',
#    'Galium horridum',
#    'Galium larecajense',
#    'Galium pseudoaparine',
#    'Galium aparine var. pseudoaparine',
#    'Galion aparinum',
#    'Rubia aparine',
#    'Asperula aparine',
#    'Asterophyllum aparine',
#    'Galium tenerrimum',
#    'Aparine vulgaris',
#    'Galium chonosense',
#    'Aparine hispida',
#    'Galium aculeatissimum',
#    'Galium segetum',
#    'Asperula aparine var. aparine',
#    'Galium charoides',
#    'Galium lappaceum',
#    'Galium chilense',
#    'Galium parviflorum',
#    'Galium uncinatum',
#    'Galium asperum'],
#   'genus': 'Galium',
#   'family': 'Rubiaceae',
#   'links': {'self': '/api/v1/species/galium-aparine',
#    'plant': '/api/v1/plants/galium-aparine',
#    'genus': '/api/v1/genus/galium'}},
#  {'id': 178451,
#   'common_name': 'Black elderberry',
#   'slug': 'sambucus-nigra',
#   'scientific_name': 'Sambucus nigra',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 269 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': None,
#   'genus_id': 5975,
#   'image_url': 'https://bs.plantnet.org/image/o/594bda8000b118433847bf0973eb397de8a87543',
#   'synonyms': ['Sambucus laciniata',
#    'Sambucus elegans',
#    'Sambucus alba',
#    'Sambucus columnaris',
#    'Sambucus leucocarpa',
#    'Sambucus hirta',
#    'Sambucus dissecta',
#    'Sambucus lucida',
#    'Sambucus monstrosa',
#    'Sambucus pyramidata',
#    'Sambucus pulverulenta',
#    'Sambucus virescens',
#    'Sambucus vulgaris',
#    'Sambucus aurea',
#    'Sambucus mexicana',
#    'Sambucus nigra var. laciniata'],
#   'genus': 'Sambucus',
#   'family': 'Viburnaceae',
#   'links': {'self': '/api/v1/species/sambucus-nigra',
#    'plant': '/api/v1/plants/sambucus-nigra',
#    'genus': '/api/v1/genus/sambucus'}},
#  {'id': 190033,
#   'common_name': 'Common wheat',
#   'slug': 'triticum-aestivum',
#   'scientific_name': 'Triticum aestivum',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 85 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 134,
#   'image_url': 'https://bs.plantnet.org/image/o/d4d05e22148e878ca3728beda0139b6dbe42fa3c',
# ...
#    'Fragaria monspeliensis',
#    'Potentilla flexuosa',
#    'Potentilla geminiflora',
#    'Potentilla norvegica subsp. genuina',
#    'Potentilla norvegica var. hirsuta',
#    'Potentilla norvegica subsp. monspeliensis'],
#   'genus': 'Potentilla',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/potentilla-norvegica',
#    'plant': '/api/v1/plants/potentilla-norvegica',
#    'genus': '/api/v1/genus/potentilla'}},
#  {'id': 108770,
#   'common_name': 'Green spleenwort',
#   'slug': 'asplenium-viride',
#   'scientific_name': 'Asplenium viride',
#   'year': 1762,
#   'bibliography': 'Fl. Angl.: 385 (1762)',
#   'author': 'Huds.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Spleenwort family',
#   'genus_id': 747,
#   'image_url': 'https://bs.plantnet.org/image/o/3bc8b704391a0b12b76509bfb87f49aea16b5a94',
#   'synonyms': ['Asplenium trichomanes-ramosum',
#    'Trichomanes viride',
#    'Chamaefilix ramosa',
#    'Asplenium vogesiacum',
#    'Asplenium viride subsp. incisum',
#    'Asplenium viride var. robustum'],
#   'genus': 'Asplenium',
#   'family': 'Aspleniaceae',
#   'links': {'self': '/api/v1/species/asplenium-viride',
#    'plant': '/api/v1/plants/asplenium-viride',
#    'genus': '/api/v1/genus/asplenium'}},
#  {'id': 952928,
#   'common_name': None,
#   'slug': 'elymus-athericus',
#   'scientific_name': 'Elymus athericus',
#   'year': 1983,
#   'bibliography': 'Lejeunia, n.s., 110: 57 (1983)',
#   'author': '(Link) Kerguélen',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2703,
#   'image_url': 'https://d2seqvvyy3b8p2.cloudfront.net/1925a596491ac2ecb3e0b296e6a6bd9a.jpg',
#   'synonyms': ['Agropyron littorale',
#    'Elytrigia atherica',
#    'Elytrigia laxula',
#    'Elymus pycnanthus var. setiger',
#    'Elytrigia atherica f. setigera',
#    'Agropyron concinnum',
#    'Triticum athericum',
#    'Elymus laxulus',
#    'Triticum litorale',
#    'Agropyron athericum',
#    'Psammopyrum athericum',
#    'Elytrigia littoralis'],
#   'genus': 'Elymus',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/elymus-athericus',
#    'plant': '/api/v1/plants/elymus-athericus',
#    'genus': '/api/v1/genus/elymus'}},
#  {'id': 191418,
#   'common_name': 'Green field speedwell',
#   'slug': 'veronica-agrestis',
#   'scientific_name': 'Veronica agrestis',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 13 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 3419,
#   'image_url': 'https://bs.plantnet.org/image/o/6e8fe06255953c73b10d1fbf185049b285addedb',
#   'synonyms': ['Pocilla agrestis',
#    'Cochlidiosperma agreste',
#    'Veronica versicolor',
#    'Veronica calycida',
#    'Veronica friesii',
#    'Veronica obscura',
#    'Veronica friesiana',
#    'Veronica alba',
#    'Cardia agrestis'],
#   'genus': 'Veronica',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/veronica-agrestis',
#    'plant': '/api/v1/plants/veronica-agrestis',
#    'genus': '/api/v1/genus/veronica'}},
#  {'id': 169878,
#   'common_name': 'Northern hollyfern',
#   'slug': 'polystichum-lonchitis',
#   'scientific_name': 'Polystichum lonchitis',
#   'year': 1799,
#   'bibliography': 'Tent. Fl. Germ. 3(1): 71 (1799)',
#   'author': '(L.) Roth',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Polypody family',
#   'genus_id': 2266,
#   'image_url': 'https://bs.plantnet.org/image/o/0f9b4988b38940d2344da74f8dff60145abb5988',
#   'synonyms': ['Aspidium asperum',
#    'Dryopteris lonchitis',
#    'Hypopeltis lonchitis',
#    'Aetopteron lonchitis',
#    'Polystichum lonchitis f. marginale',
#    'Aspidium lonchitis',
#    'Polypodium lonchitis',
#    'Polystichum asperum'],
#   'genus': 'Polystichum',
#   'family': 'Polypodiaceae',
#   'links': {'self': '/api/v1/species/polystichum-lonchitis',
#    'plant': '/api/v1/plants/polystichum-lonchitis',
#    'genus': '/api/v1/genus/polystichum'}},
#  {'id': 143188,
#   'common_name': 'Seaside sandplant',
#   'slug': 'honckenya-peploides',
#   'scientific_name': 'Honckenya peploides',
#   'year': 1783,
#   'bibliography': 'Neues Mag. Aerzte 5: 206 (1783)',
#   'author': '(L.) Ehrh.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 3607,
#   'image_url': 'https://bs.plantnet.org/image/o/6ea0a23c3b5417e5f08565d5a751e7fc88af216c',
#   'synonyms': ['Arenaria peploides',
#    'Arenaria peploides f. lamoureuxii',
#    'Cerastium succulentum',
#    'Arenaria portulacea',
#    'Ammonalia peploides',
#    'Ammodenia peploides',
#    'Halianthus peploides',
#    'Honckenya maritima',
#    'Arenaria peploides var. diffusa',
#    'Honckenya frigida',
#    'Minuartia peploides subsp. latifolia',
#    'Arenaria sitchensis',
#    'Ammodenia peploides var. diffusa',
#    'Minuartia peploides',
#    'Ammodenia peploides subsp. maritima',
#    'Ammodenia maritima',
#    'Holosteum succulentum',
#    'Adenarium maritimum',
#    'Adenarium marinum',
#    'Minuartia peploides var. diffusa',
#    'Merckia peploides',
#    'Arenaria littoralis',
#    'Adenarium peploides',
#    'Honckenya peploides var. latifolia',
#    'Honckenya diffusa',
#    'Honckenya peploides var. diffusa',
#    'Alsine peploides'],
#   'genus': 'Honckenya',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/honckenya-peploides',
#    'plant': '/api/v1/plants/honckenya-peploides',
#    'genus': '/api/v1/genus/honckenya'}},
#  {'id': 146779,
#   'common_name': 'Sharpleaf cancerwort',
#   'slug': 'kickxia-elatine',
#   'scientific_name': 'Kickxia elatine',
#   'year': 1827,
#   'bibliography': 'Fl. Belg.: 35 (1827)',
#   'author': '(L.) Dumort.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 3888,
#   'image_url': 'https://bs.plantnet.org/image/o/ce8421114b03f9624ae674ed9c9b02a33fe3e2e7',
#   'synonyms': ['Linaria elatine',
#    'Antirrhinum elatine',
#    'Elatine hastata',
#    'Linaria auriculata',
#    'Anarrhinum elatum',
#    'Linaria × brebissonii',
#    'Antirrhinum auriculatum',
#    'Tursitis elatine',
#    'Antirrhinum cymbalaria',
#    'Tursitis filifera',
#    'Tursitis flexuosa',
#    'Linaria commutata',
#    'Antirrhinum elatiniflorum',
#    'Cymbalaria commuta',
#    'Linaria crenifolia',
#    'Elatinoides elatine',
#    'Simbuleta elata',
#    'Cymbalaria elatine'],
#   'genus': 'Kickxia',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/kickxia-elatine',
#    'plant': '/api/v1/plants/kickxia-elatine',
#    'genus': '/api/v1/genus/kickxia'}},
#  {'id': 239777,
#   'common_name': 'Alpine thistle',
#   'slug': 'carduus-defloratus',
#   'scientific_name': 'Carduus defloratus',
#   'year': 1759,
#   'bibliography': 'Syst. Nat. ed. 10 2: 1200 (1759)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 1461,
#   'image_url': 'https://bs.plantnet.org/image/o/b36c24b92180cd61ac672af8ecd7af141aa4ca00',
#   'synonyms': ['Carduus carlinifolius',
#    'Carduus crassifolius',
#    'Carduus transalpinus',
#    'Carduus montosus',
#    'Carduus leptophyllus',
#    'Cirsium defloratum',
#    'Carduus tenuifolius',
#    'Cirsium pauciflorum',
#    'Carduus pannonicus',
#    'Carduus cirsioides',
#    'Carduus glaucophyllus',
#    'Carduus argemonoides',
#    'Carduus viridis',
#    'Pternix deflorata',
#    'Cirsium leucostylum',
#    'Carduus spinulosus',
#    'Carduus pectinatus'],
#   'genus': 'Carduus',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/carduus-defloratus',
#    'plant': '/api/v1/plants/carduus-defloratus',
#    'genus': '/api/v1/genus/carduus'}},
#  {'id': 106589,
#   'common_name': 'Woolly burdock',
#   'slug': 'arctium-tomentosum',
#   'scientific_name': 'Arctium tomentosum',
#   'year': 1768,
#   'bibliography': 'Gard. Dict. ed. 8: n.º 3 (1768)',
#   'author': 'Mill.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 588,
#   'image_url': 'https://bs.plantnet.org/image/o/caffbfbc018c3798d28607ef04010d8cde7a64c7',
#   'synonyms': ['Arctium leptophyllum',
#    'Lappa tomentosa',
#    'Arctium lappa var. tomentosum'],
#   'genus': 'Arctium',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/arctium-tomentosum',
#    'plant': '/api/v1/plants/arctium-tomentosum',
#    'genus': '/api/v1/genus/arctium'}},
#  {'id': 178677,
#   'common_name': 'Rock soapwort',
#   'slug': 'saponaria-ocymoides',
#   'scientific_name': 'Saponaria ocymoides',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 409 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 3342,
#   'image_url': 'https://bs.plantnet.org/image/o/3a6df46121e90ab4ccd6db2d545888536e4a254a',
#   'synonyms': ['Silene ocymoides',
#    'Silene alsinoides',
#    'Saponaria repens',
#    'Bootia ocymoides',
#    'Lychnis ocymoides'],
#   'genus': 'Saponaria',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/saponaria-ocymoides',
#    'plant': '/api/v1/plants/saponaria-ocymoides',
#    'genus': '/api/v1/genus/saponaria'}},
#  {'id': 181814,
#   'common_name': 'Common catchfly',
#   'slug': 'silene-gallica',
#   'scientific_name': 'Silene gallica',
#   'year': 1753,
#   'bibliography': 'Sp. Pl.: 417 (1753)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 4327,
#   'image_url': 'https://bs.plantnet.org/image/o/d1a86b468db6551895eff0099d044d5190d3f677',
#   'synonyms': ['Silene anglica',
#    'Silene rigidula',
#    'Silene cerastoides',
#    'Silene quinquevulnera',
#    'Silene lusitanica',
#    'Silene cruentata',
#    'Silene suboccultata',
#    'Cucubalus variegatus',
#    'Corone agrestina',
#    'Corone gallica',
#    'Silene bohemica',
#    'Silene chia',
#    'Silene rosella',
#    'Silene glomerata',
#    'Silene myloptera',
#    'Silene rostrata',
#    'Lychnis vulnerata',
#    'Silene spathulata',
#    'Silene pygmaea',
#    'Silene occitanica',
#    'Silene sylvestris',
#    'Silene clusii',
#    'Silene jucunda',
#    'Silene spatulata',
#    'Silene cantabrica',
#    'Silene distycha',
#    'Silene candollei',
#    'Silene gallica var. quinquevulnera',
#    'Silene parvula',
#    'Silene transtagana',
#    'Silene vernalis',
#    'Silene sciotica',
#    'Silene linophila',
#    'Cucubalus sylvestris',
#    'Silene semiglabra',
#    'Silene haenkeana',
#    'Corone quinquevulnera',
#    'Lychnis cerastoides',
#    'Silene agrestina',
#    'Silene minutiflora',
#    'Silene reflexa',
#    'Silene agricola',
#    'Silene cuneifolia',
#    'Silene tergestina',
#    'Silene marginata',
#    'Silene sardoa',
#    'Oncerum gallicum',
#    'Silene ledebourii'],
#   'genus': 'Silene',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/silene-gallica',
#    'plant': '/api/v1/plants/silene-gallica',
#    'genus': '/api/v1/genus/silene'}},
#  {'id': 162791,
#   'common_name': 'Dallisgrass',
#   'slug': 'paspalum-dilatatum',
#   'scientific_name': 'Paspalum dilatatum',
#   'year': 1804,
#   'bibliography': 'J.B.A.M.de Lamarck, Encycl. 5: 35 (1804)',
#   'author': 'Poir.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2451,
#   'image_url': 'https://bs.plantnet.org/image/o/4d598e0790de0b4edd515714dcd3c775d034c932',
#   'synonyms': ['Paspalum pedunculare',
#    'Paspalum ovatum',
#    'Paspalum dilatatum f. paucispica',
#    'Paspalum selloi',
#    'Paspalum moluccanum',
#    'Paspalum ovatum var. grandiflorum',
#    'Digitaria dilatata',
#    'Paspalum platense',
#    'Paspalum dilatatum var. sacchariferum',
#    'Panicum platense',
#    'Paspalum dilatatum var. decumbens',
#    'Paspalum dilatatum subsp. flavescens'],
#   'genus': 'Paspalum',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/paspalum-dilatatum',
#    'plant': '/api/v1/plants/paspalum-dilatatum',
#    'genus': '/api/v1/genus/paspalum'}},
#  {'id': 191969,
#   'common_name': 'Mung bean',
#   'slug': 'vigna-radiata',
#   'scientific_name': 'Vigna radiata',
#   'year': 1954,
#   'bibliography': 'Fl. Congo Belge 6: 286 (1954)',
#   'author': '(L.) R.Wilczek',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 6303,
#   'image_url': 'https://bs.plantnet.org/image/o/0457e52a60ae8a99c399730f8d3719b937c37f13',
#   'synonyms': ['Phaseolus radiatus',
#    'Pueraria chanetii',
#    'Azukia radiata',
#    'Phaseolus aureus',
#    'Phaseolus trinervius',
#    'Vigna perrieriana',
#    'Phasellus roseus',
#    'Phasellus farinosus',
#    'Vigna brachycarpa',
#    'Phasellus lanatus',
#    'Vigna trinervia',
#    'Phaseolus farinosus',
#    'Phaseolus bundoo',
#    'Phaseolus opisotrichus',
#    'Phaseolus citrinus',
#    'Rudua aurea',
#    'Phaseolus abyssinicus'],
#   'genus': 'Vigna',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/vigna-radiata',
#    'plant': '/api/v1/plants/vigna-radiata',
#    'genus': '/api/v1/genus/vigna'}},
#  {'id': 641928,
#   'common_name': 'Spiny broom',
#   'slug': 'calicotome-villosa',
#   'scientific_name': 'Calicotome villosa',
#   'year': 1808,
#   'bibliography': 'Neues J. Bot. 2(2): 51 (1808)',
#   'author': '(Poir.) Link',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 13040,
#   'image_url': 'https://bs.plantnet.org/image/o/6032fde46086a376650901a94fea7aab2277684f',
#   'synonyms': ['Cytisus laniger',
#    'Genista lanigera',
#    'Spartium lanigerum',
#    'Spartium villosum',
#    'Lygoplis villosum',
#    'Laburnum lanigerum',
#    'Cytisus preslii'],
#   'genus': 'Calicotome',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/calicotome-villosa',
#    'plant': '/api/v1/plants/calicotome-villosa',
#    'genus': '/api/v1/genus/calicotome'}},
#  {'id': 131643,
#   'common_name': 'Fewflower spikerush',
#   'slug': 'eleocharis-quinqueflora',
#   'scientific_name': 'Eleocharis quinqueflora',
#   'year': 1949,
#   'bibliography': 'Mitt. Thüring. Bot. Ges. 1: 89 (1949)',
#   'author': '(Hartmann) O.Schwarz',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Sedge family',
#   'genus_id': 2672,
#   'image_url': None,
#   'synonyms': ['Scirpus campestris',
#    'Eleocharis pauciflora',
#    'Scirpus quinqueflorus',
#    'Scirpus pauciflorus',
#    'Eleocharis pauciflora var. fernaldii',
#    'Cyperus pauciflorus',
#    'Eleocharis meridionalis',
#    'Eleocharis atacamensis',
#    'Eleocharis obscura',
#    'Scirpus graecus',
#    'Trichophorum pauciflorum',
#    'Eleocharis vierhapperi',
#    'Baeothryon halleri',
#    'Scirpus sepium',
#    'Isolepis andina',
#    'Eleocharis czernjajevi',
#    'Scirpus pauciflorus var. fernaldii',
#    'Eleocharis quinqueflora subsp. meridionalis',
#    'Eleocharis fernaldii',
#    'Trichophorum vierhapperi',
#    'Limnochloa baeothryon',
#    'Clavula boeotryon',
#    'Limnochloa pauciflora',
#    'Scirpus baeothryon',
#    'Baeothryon pauciflorum',
#    'Scirpus cespitosus',
#    'Eleocharis baeothryon',
#    'Scirpus atacamensis',
#    'Eleocharis quinqueflora subsp. fernaldii'],
#   'genus': 'Eleocharis',
#   'family': 'Cyperaceae',
#   'links': {'self': '/api/v1/species/eleocharis-quinqueflora',
#    'plant': '/api/v1/plants/eleocharis-quinqueflora',
#    'genus': '/api/v1/genus/eleocharis'}},
#  {'id': 409980,
#   'common_name': 'Woolly thistle',
#   'slug': 'cirsium-eriophorum',
#   'scientific_name': 'Cirsium eriophorum',
#   'year': 1771,
#   'bibliography': 'Fl. Carniol., ed. 2, 2: 130 (1771)',
#   'author': '(L.) Scop.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 1787,
#   'image_url': 'https://bs.plantnet.org/image/o/723f243bd0d20ff006a4f0799fab593eecc97cb5',
#   'synonyms': ['Cirsium ligulare var. bosniacum',
#    'Tetralix eriophora',
#    'Cynara eriocephala',
#    'Carduus tomentosus',
#    'Cnicus velenowskyi',
#    'Cirsium longebracteatum',
#    'Cirsium velenowskyi',
#    'Carduus spurius',
#    'Cirsium eriophorum subsp. degenii',
#    'Cirsium corbariense',
#    'Cirsium eriophorum subsp. chodatii',
#    'Cirsium vandasii',
#    'Cirsium chodatii',
#    'Cnicus eriophorus',
#    'Cirsium eriophorum var. bosniacum',
#    'Cirsium insubricum',
#    'Cirsium eriophorum var. costae',
#    'Cirsium corbariense var. costae'],
#   'genus': 'Cirsium',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/cirsium-eriophorum',
#    'plant': '/api/v1/plants/cirsium-eriophorum',
#    'genus': '/api/v1/genus/cirsium'}}]

# %%
len(hasbiblio)
# Out:
# 994

# %%
linnaeans = [plant['bibliography'] for plant in hasbiblio if 'Linnaeus' in plant['bibliography']]
linnaeans
# Out:
# ['Linnaeus, C. (1753). Species plantarum, exhibentes plantas rite cognitas ad genera relatas cum differentiis specificis, nominibus trivialibus, synonymis selectis, locis natalibus, secundum systema sexuale digestas. Stockholm.']

# %%
len(linnaeans)
# Out:
# 1

# %% [markdown]
# # Matching Author and Bibliography

# %% [markdown]
# In fact, _Species Plantarum_ (1753) was written by Linnaeus, and "Sp. Pl." in these bibliographies is a reference to that master work. Let's check to see who the author is for these records whose bibliographies start with "Sp. Pl.":

# %%
sps = []
for plant in hasbiblio:
    if plant['bibliography'].startswith('Sp. Pl.'):
        sps.append(plant)

# %%
sps2 = []
for plant in hasbiblio:
    if "Sp. Pl." in plant['bibliography']:
        sps2.append(plant)

# %%
len(sps)
# Out:
# 445

# %%
len(sps2)
# Out:
# 448

# %%
sp_authors = [sp['author'] for sp in sps2]

# %%
sp_authors
# Out:
# ['L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(L.) L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(J.Presl & C.Presl) Parl.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'Willd.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  None,
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(L.) L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'A.Haines (Linnaeus)',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.']

# %%
uniq_auth = list(set(sp_authors))
uniq_auth
# Out:
# ['(J.Presl & C.Presl) Parl.',
#  '(L.) L.',
#  'L.',
#  None,
#  'A.Haines (Linnaeus)',
#  'Willd.']

# %%
uniq_auth[0]
# Out:
# '(J.Presl & C.Presl) Parl.'

# %%
counts = []
for author in uniq_auth:
    counts.append(sp_authors.count(author))

# %%
counts
# Out:
# [1, 2, 442, 1, 1, 1]

# %%
dict(zip(uniq_auth, counts))
# Out:
# {'(J.Presl & C.Presl) Parl.': 1,
#  '(L.) L.': 2,
#  'L.': 442,
#  None: 1,
#  'A.Haines (Linnaeus)': 1,
#  'Willd.': 1}

# %% [markdown]
# ## Exercise

# %% [markdown]
# Change the author to 'L.' (for 'Linnaeus') for all of these records.

# %%
sps2 = []
for plant in hasbiblio:
    if "Sp. Pl." in plant['bibliography']:
        sps2.append(plant)

# %%
sps = []
for plant in hasbiblio:
    if "Sp. Pl." in plant['bibliography']:
        sps.append(plant)

# %%
sp_authors = set([sp['author'] for sp in sps])
sp_authors
# Out:
# {'(J.Presl & C.Presl) Parl.',
#  '(L.) L.',
#  'A.Haines (Linnaeus)',
#  'L.',
#  None,
#  'Willd.'}

# %%
len(sps)
# Out:
# 448

# %% [markdown]
# <details>
#     <summary>
#         Answer
#     </summary>
#
# ```python
# for plant in plants:
#     try:
#         if plant['bibliography'].startswith('Sp. Pl.'):
#             plant['author'] = 'L.'
#     except:
#         continue
# ```
# </details>

# %% [markdown]
# # Teaser: Bringing in `pandas`: Back to Synonyms

# %% [markdown]
# Let's take advantage of the DataFrame tools from `pandas`:

# %%
# Need to first import pandas
import pandas as pd

# %%
plants_df = pd.DataFrame(plants)

# %%
plants[0]
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %%
plants_df.head()
# Out:
#        id          common_name                  slug       scientific_name  \
# 0  678281        Evergreen oak  quercus-rotundifolia  Quercus rotundifolia
# 1  190500      Stinging nettle         urtica-dioica         Urtica dioica
# 2  126957         Orchardgrass    dactylis-glomerata    Dactylis glomerata
# 3  167888  Narrowleaf plantain   plantago-lanceolata   Plantago lanceolata
# 4  173327          English oak         quercus-robur         Quercus robur
#
#      year           bibliography author    status     rank family_common_name  \
# 0  1785.0  Encycl. 1: 723 (1785)   Lam.  accepted  species       Beech family
# 1  1753.0    Sp. Pl.: 984 (1753)     L.  accepted  species      Nettle family
# 2  1753.0     Sp. Pl.: 71 (1753)     L.  accepted  species       Grass family
# 3  1753.0    Sp. Pl.: 113 (1753)     L.  accepted  species    Plantain family
# 4  1753.0    Sp. Pl.: 996 (1753)     L.  accepted  species       Beech family
#
#    genus_id                                          image_url  \
# 0      5778  https://bs.plantnet.org/image/o/1a03948baf0300...
# 1      1028  https://bs.plantnet.org/image/o/85256a1c2c098e...
# 2      2284  https://bs.plantnet.org/image/o/428f40dadfa028...
# 3      5418  https://bs.plantnet.org/image/o/78a8374f009e6e...
# 4      5778  https://bs.plantnet.org/image/o/2292b670683abd...
#
#                                             synonyms     genus  \
# 0  [Quercus lyauteyi, Quercus rotundifolia f. cra...   Quercus
# 1  [Urtica major, Urtica tibetica, Urtica sicula,...    Urtica
# 2  [Koeleria dactylis, Festuca glomerata, Trachyp...  Dactylis
# 3  [Plantago lanceolata var. sphaerostachya, Plan...  Plantago
# 4  [Quercus longaeva, Quercus salicifolia, Quercu...   Quercus
#
#            family                                              links
# 0        Fagaceae  {'self': '/api/v1/species/quercus-rotundifolia...
# 1      Urticaceae  {'self': '/api/v1/species/urtica-dioica', 'pla...
# 2         Poaceae  {'self': '/api/v1/species/dactylis-glomerata',...
# 3  Plantaginaceae  {'self': '/api/v1/species/plantago-lanceolata'...
# 4        Fagaceae  {'self': '/api/v1/species/quercus-robur', 'pla...

# %%
plants_df.loc[plants_df['author'] == "L."]
# Out:
#          id            common_name                  slug  \
# 1    190500        Stinging nettle         urtica-dioica
# 2    126957           Orchardgrass    dactylis-glomerata
# 3    167888    Narrowleaf plantain   plantago-lanceolata
# 4    173327            English oak         quercus-robur
# 5    137025             Red fescue         festuca-rubra
# ..      ...                    ...                   ...
# 984  170694   Norwegian cinquefoil  potentilla-norvegica
# 987  191418  Green field speedwell     veronica-agrestis
# 991  239777         Alpine thistle    carduus-defloratus
# 993  178677          Rock soapwort   saponaria-ocymoides
# 994  181814        Common catchfly        silene-gallica
#
#           scientific_name    year                      bibliography author  \
# 1           Urtica dioica  1753.0               Sp. Pl.: 984 (1753)     L.
# 2      Dactylis glomerata  1753.0                Sp. Pl.: 71 (1753)     L.
# 3     Plantago lanceolata  1753.0               Sp. Pl.: 113 (1753)     L.
# 4           Quercus robur  1753.0               Sp. Pl.: 996 (1753)     L.
# 5           Festuca rubra  1753.0               Sp. pl. 1:74.  1753     L.
# ..                    ...     ...                               ...    ...
# 984  Potentilla norvegica  1753.0               Sp. Pl.: 499 (1753)     L.
# 987     Veronica agrestis  1753.0                Sp. Pl.: 13 (1753)     L.
# 991    Carduus defloratus  1759.0  Syst. Nat. ed. 10 2: 1200 (1759)     L.
# 993   Saponaria ocymoides  1753.0               Sp. Pl.: 409 (1753)     L.
# 994        Silene gallica  1753.0               Sp. Pl.: 417 (1753)     L.
#
#        status     rank family_common_name  genus_id  \
# 1    accepted  species      Nettle family      1028
# 2    accepted  species       Grass family      2284
# 3    accepted  species    Plantain family      5418
# 4    accepted  species       Beech family      5778
# 5    accepted  species       Grass family      1102
# ..        ...      ...                ...       ...
# 984  accepted  species        Rose family       618
# 987  accepted  species    Plantain family      3419
# 991  accepted  species       Aster family      1461
# 993  accepted  species        Pink family      3342
# 994  accepted  species        Pink family      4327
#
#                                              image_url  \
# 1    https://bs.plantnet.org/image/o/85256a1c2c098e...
# 2    https://bs.plantnet.org/image/o/428f40dadfa028...
# 3    https://bs.plantnet.org/image/o/78a8374f009e6e...
# 4    https://bs.plantnet.org/image/o/2292b670683abd...
# 5    https://bs.plantnet.org/image/o/0b932c8a275efc...
# ..                                                 ...
# 984  https://bs.plantnet.org/image/o/e0cafb7c39026c...
# 987  https://bs.plantnet.org/image/o/6e8fe06255953c...
# 991  https://bs.plantnet.org/image/o/b36c24b92180cd...
# 993  https://bs.plantnet.org/image/o/3a6df46121e90a...
# 994  https://bs.plantnet.org/image/o/d1a86b468db655...
#
#                                               synonyms       genus  \
# 1    [Urtica major, Urtica tibetica, Urtica sicula,...      Urtica
# 2    [Koeleria dactylis, Festuca glomerata, Trachyp...    Dactylis
# 3    [Plantago lanceolata var. sphaerostachya, Plan...    Plantago
# 4    [Quercus longaeva, Quercus salicifolia, Quercu...     Quercus
# 5    [Festuca rubra var. arenaria, Bromus secundus,...     Festuca
# ..                                                 ...         ...
# 984  [Potentilla monspeliensis, Potentilla norvegic...  Potentilla
# 987  [Pocilla agrestis, Cochlidiosperma agreste, Ve...    Veronica
# 991  [Carduus carlinifolius, Carduus crassifolius, ...     Carduus
# 993  [Silene ocymoides, Silene alsinoides, Saponari...   Saponaria
# 994  [Silene anglica, Silene rigidula, Silene ceras...      Silene
#
#               family                                              links
# 1         Urticaceae  {'self': '/api/v1/species/urtica-dioica', 'pla...
# 2            Poaceae  {'self': '/api/v1/species/dactylis-glomerata',...
# 3     Plantaginaceae  {'self': '/api/v1/species/plantago-lanceolata'...
# 4           Fagaceae  {'self': '/api/v1/species/quercus-robur', 'pla...
# 5            Poaceae  {'self': '/api/v1/species/festuca-rubra', 'pla...
# ..               ...                                                ...
# 984         Rosaceae  {'self': '/api/v1/species/potentilla-norvegica...
# 987   Plantaginaceae  {'self': '/api/v1/species/veronica-agrestis', ...
# 991       Asteraceae  {'self': '/api/v1/species/carduus-defloratus',...
# 993  Caryophyllaceae  {'self': '/api/v1/species/saponaria-ocymoides'...
# 994  Caryophyllaceae  {'self': '/api/v1/species/silene-gallica', 'pl...
#
# [518 rows x 16 columns]

# %%
pd.read_json('data/new_releases.json')
# Out:
#                                                      albums
# href      https://api.spotify.com/v1/browse/new-releases...
# items     [{'album_type': 'album', 'artists': [{'externa...
# limit                                                    20
# next      https://api.spotify.com/v1/browse/new-releases...
# offset                                                    0
# previous                                               None
# total                                                   100

# %%
pd.DataFrame(albums)
# Out:
#    album_type                                            artists  \
# 0       album  [{'external_urls': {'spotify': 'https://open.s...
# 1      single  [{'external_urls': {'spotify': 'https://open.s...
# 2       album  [{'external_urls': {'spotify': 'https://open.s...
# 3      single  [{'external_urls': {'spotify': 'https://open.s...
# 4       album  [{'external_urls': {'spotify': 'https://open.s...
# 5      single  [{'external_urls': {'spotify': 'https://open.s...
# 6       album  [{'external_urls': {'spotify': 'https://open.s...
# 7      single  [{'external_urls': {'spotify': 'https://open.s...
# 8       album  [{'external_urls': {'spotify': 'https://open.s...
# 9       album  [{'external_urls': {'spotify': 'https://open.s...
# 10     single  [{'external_urls': {'spotify': 'https://open.s...
# 11     single  [{'external_urls': {'spotify': 'https://open.s...
# 12      album  [{'external_urls': {'spotify': 'https://open.s...
# 13     single  [{'external_urls': {'spotify': 'https://open.s...
# 14      album  [{'external_urls': {'spotify': 'https://open.s...
# 15     single  [{'external_urls': {'spotify': 'https://open.s...
# 16      album  [{'external_urls': {'spotify': 'https://open.s...
# 17     single  [{'external_urls': {'spotify': 'https://open.s...
# 18     single  [{'external_urls': {'spotify': 'https://open.s...
# 19     single  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  \
# 0   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 2   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 3   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 5   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 6   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 7   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 8   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 9   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 10  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 11  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 12  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 13  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 14  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 15  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 16  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 17  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 18  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 19  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/album/4b...
# 1   {'spotify': 'https://open.spotify.com/album/3L...
# 2   {'spotify': 'https://open.spotify.com/album/2Z...
# 3   {'spotify': 'https://open.spotify.com/album/2m...
# 4   {'spotify': 'https://open.spotify.com/album/39...
# 5   {'spotify': 'https://open.spotify.com/album/0i...
# 6   {'spotify': 'https://open.spotify.com/album/3a...
# 7   {'spotify': 'https://open.spotify.com/album/3l...
# 8   {'spotify': 'https://open.spotify.com/album/6d...
# 9   {'spotify': 'https://open.spotify.com/album/2k...
# 10  {'spotify': 'https://open.spotify.com/album/3P...
# 11  {'spotify': 'https://open.spotify.com/album/5L...
# 12  {'spotify': 'https://open.spotify.com/album/6C...
# 13  {'spotify': 'https://open.spotify.com/album/5X...
# 14  {'spotify': 'https://open.spotify.com/album/5V...
# 15  {'spotify': 'https://open.spotify.com/album/3c...
# 16  {'spotify': 'https://open.spotify.com/album/5G...
# 17  {'spotify': 'https://open.spotify.com/album/3t...
# 18  {'spotify': 'https://open.spotify.com/album/7r...
# 19  {'spotify': 'https://open.spotify.com/album/2J...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/albums/4bNPOFOzxGhF...  4bNPOFOzxGhF5jhfIK6lit
# 1   https://api.spotify.com/v1/albums/3LhriqAiHJYw...  3LhriqAiHJYw7rxvtlkvQc
# 2   https://api.spotify.com/v1/albums/2Zg5xZo3WwIo...  2Zg5xZo3WwIoAZys8OcUpG
# 3   https://api.spotify.com/v1/albums/2m5J1DUH7hJp...  2m5J1DUH7hJpPSOromIqpN
# 4   https://api.spotify.com/v1/albums/39xhYyNNDatQ...  39xhYyNNDatQtgKw2KdXMz
# 5   https://api.spotify.com/v1/albums/0i96PtPJV65d...  0i96PtPJV65ddxsfMfo45F
# 6   https://api.spotify.com/v1/albums/3a9qH2VEsSiO...  3a9qH2VEsSiOZvMrjaS0Nu
# 7   https://api.spotify.com/v1/albums/3lalGt6k7JM3...  3lalGt6k7JM3tIji1Xbgmk
# 8   https://api.spotify.com/v1/albums/6daEdTBi1hyF...  6daEdTBi1hyFQgmsnR7oRr
# 9   https://api.spotify.com/v1/albums/2kx4l1OQNT2J...  2kx4l1OQNT2JXLld9HJDIh
# 10  https://api.spotify.com/v1/albums/3PASWLvNfvfM...  3PASWLvNfvfMF68dDznEgK
# 11  https://api.spotify.com/v1/albums/5LK5cCx0Xdni...  5LK5cCx0XdniivfZ91vOSv
# 12  https://api.spotify.com/v1/albums/6CIslPQSknp8...  6CIslPQSknp875cigkhKJC
# 13  https://api.spotify.com/v1/albums/5XvXf3mdhShy...  5XvXf3mdhShyLZhoJYR74q
# 14  https://api.spotify.com/v1/albums/5VKKXDvYuJmR...  5VKKXDvYuJmRc2UQHCwNQK
# 15  https://api.spotify.com/v1/albums/3cVy1WTjSAVp...  3cVy1WTjSAVpzUc7MVCTLu
# 16  https://api.spotify.com/v1/albums/5Gn3fFzlWL89...  5Gn3fFzlWL89j0hGumtXb5
# 17  https://api.spotify.com/v1/albums/3tOe6XM8LmRA...  3tOe6XM8LmRA5vDAaMqp8e
# 18  https://api.spotify.com/v1/albums/7rcMHNqNbQxF...  7rcMHNqNbQxF5TaPMHFoKu
# 19  https://api.spotify.com/v1/albums/2JQbWWpYG6kK...  2JQbWWpYG6kKppiD6z2FwL
#
#                                                images  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                             name release_date  \
# 0                                  High Off Life   2020-05-15
# 1                                  Lose Somebody   2020-05-15
# 2                               SCOOB! The Album   2020-05-15
# 3                                        Daisies   2020-05-15
# 4                                       THE GOAT   2020-05-15
# 5                                             XV   2020-05-15
# 6                            how i'm feeling now   2020-05-15
# 7                             Temperature Rising   2020-05-15
# 8               Set My Heart On Fire Immediately   2020-05-15
# 9   Good Intentions (Brown Boy 2 Deluxe Version)   2020-05-11
# 10                                Racks 2 Skinny   2020-05-11
# 11                             One Of Them Girls   2020-05-15
# 12                           The London Sessions   2020-05-15
# 13                             The Album, Pt. II   2020-05-15
# 14                          Like A House On Fire   2020-05-15
# 15                                          Riot   2020-05-13
# 16                         THE END OF EVERYTHING   2020-05-15
# 17                                  Will (Remix)   2020-05-15
# 18                                    Excitement   2020-05-15
# 19                  Zen (with K.Flay & grandson)   2020-05-15
#
#    release_date_precision  total_tracks   type  \
# 0                     day            21  album
# 1                     day             1  album
# 2                     day            12  album
# 3                     day             1  album
# 4                     day            16  album
# 5                     day             2  album
# 6                     day            11  album
# 7                     day             1  album
# 8                     day            13  album
# 9                     day            32  album
# 10                    day             1  album
# 11                    day             2  album
# 12                    day            13  album
# 13                    day             4  album
# 14                    day            15  album
# 15                    day             1  album
# 16                    day             8  album
# 17                    day             1  album
# 18                    day             1  album
# 19                    day             1  album
#
#                                      uri
# 0   spotify:album:4bNPOFOzxGhF5jhfIK6lit
# 1   spotify:album:3LhriqAiHJYw7rxvtlkvQc
# 2   spotify:album:2Zg5xZo3WwIoAZys8OcUpG
# 3   spotify:album:2m5J1DUH7hJpPSOromIqpN
# 4   spotify:album:39xhYyNNDatQtgKw2KdXMz
# 5   spotify:album:0i96PtPJV65ddxsfMfo45F
# 6   spotify:album:3a9qH2VEsSiOZvMrjaS0Nu
# 7   spotify:album:3lalGt6k7JM3tIji1Xbgmk
# 8   spotify:album:6daEdTBi1hyFQgmsnR7oRr
# 9   spotify:album:2kx4l1OQNT2JXLld9HJDIh
# 10  spotify:album:3PASWLvNfvfMF68dDznEgK
# 11  spotify:album:5LK5cCx0XdniivfZ91vOSv
# 12  spotify:album:6CIslPQSknp875cigkhKJC
# 13  spotify:album:5XvXf3mdhShyLZhoJYR74q
# 14  spotify:album:5VKKXDvYuJmRc2UQHCwNQK
# 15  spotify:album:3cVy1WTjSAVpzUc7MVCTLu
# 16  spotify:album:5Gn3fFzlWL89j0hGumtXb5
# 17  spotify:album:3tOe6XM8LmRA5vDAaMqp8e
# 18  spotify:album:7rcMHNqNbQxF5TaPMHFoKu
# 19  spotify:album:2JQbWWpYG6kKppiD6z2FwL

# %% [markdown]
# ## Exercises for Later

# %% [markdown]
# 1. Add the number of synonyms as a new column called "num_syn".
# 2. Sort the DataFrame by number of synonyms in descending order.
# 3. Grab the Image URL of the plant that has the fourth-highest number of synonyms.
# 4. Paste it into your browser and take a look!

# %% [markdown]
# <details>
#     <summary>Answer here
#     </summary>
#
# ```python
# plants_df['num_syn'] = plants_df['synonyms'].map(len)
# sorted = plants_df.sort_values('num_syn', ascending=False)
# sorted.loc[3, 'image_url']
# ```
# </details>

# %% [markdown]
# # Year

# %% [markdown]
# The year is an indication of when a valid name for the plant first appeared in print. Let's build a simple histogram of these years:

# %%
fig, ax = plt.subplots()

ax.hist(plants_df[plants_df['year'] > 0]['year'], color='darkgreen');

# %% [markdown]
# ## Exercise

# %% [markdown]
# How many plants have first been written about just in the last 20 years? Make a bar chart or pie chart that shows the distribution by family of these plants.

# %% [markdown]
# <details>
#     <summary>
#         One answer here
#     </summary>
#
# ```python
# recent = plants_df[plants_df['year'] >= 2001]
# fig, ax = plt.subplots(1, 2, figsize=(14, 6)
# ax[0].bar(recent['family_common_name'].value_counts().index,
#        recent['family_common_name'].value_counts(),
#       color='darkgreen')
# ax[1].pie(recent['family_common_name'].value_counts(),
#       labels=recent['family_common_name'].value_counts().index,
#       radius=1.2, labeldistance=0.4, rotatelabels=True);
# ```
# </details>
